# %% [markdown]
# # $\text{AR}(1)$ with Offset
#
# $\text{AR}(1)$ with a constant offset is defined by,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \mu^* + \sigma \varepsilon_t
# \end{align}
# $
#
# where, $\varepsilon \sim \text{Normal}(0,1)$
#
# The stationarity requires $\lvert \varphi \rvert < 1$. The stationary mean and variance are given by,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}(X_t) = \frac{\mu^*}{1 - \varphi} \\
# &\lim_{t \to \infty} \text{Var}(X_t) = \frac{\sigma^2}{1 - \varphi^2}
# \end{align}
# $
#
# It follows that $X_t$ has distribution,
#
# $
# \begin{align}
# X_t \sim \text{Normal}\left(  \frac{\mu}{1 - \varphi} ,  \frac{\sigma^2}{1 - \varphi^2} \right)
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib.models import arima
from lib import (ARIMA, Stats, Est, PlotType)
from lib import (stack, fpoints, fcurve, curve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
σ = 1.0
nsample = 1000

def cumu_mean_plot(φ, σ, μ, nsample):
    ar = ARIMA.Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    mean = Stats.Func.CUMU_MEAN.apply(ar)
    ar1_mean = ARIMA.Func.AR1_OFFSET_MEAN.apply(ar, φ=φ, μ=μ)
    fcurve(data=mean, func=ar1_mean, title_offset=1.025, plot_type=PlotType.XLOG)
    
def cumu_sd_plot(φ, σ, μ, nsample):
    ar = ARIMA.Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    sd = Stats.Func.CUMU_SD.apply(ar)
    ar1_sd = ARIMA.Func.AR1_OFFSET_SD.apply(ar, φ=φ, σ=σ)
    fcurve(data=sd, func=ar1_sd, title_offset=1.025, plot_type=PlotType.XLOG)
    
def comparison_plot_μ(μ_vals, ylim, title, *params):
    labels = [r"$μ^*=$" + f"{val}" for val in μ_vals]
    scan = ARIMA.Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    
def comparison_plot_φ(φ_vals, ylim, title, *params):
    labels = [f"φ={val}" for val in φ_vals] 
    scan = ARIMA.Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)

# %% [markdown]
# ## Simulation $\varphi$ Scan

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: $σ={{{σ}}}$, $μ^*={{{μ}}}$"
φ_vals = [0.1, 0.5, 0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [0.0, 60.0], title, *params)

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: σ={σ}, " + r"$μ^*$=" + f"{μ}"
φ_vals = [-0.1, -0.5, -0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [-5.0, 10.0], title, *params)

# %% [markdown]
# ## Simulation $\mu^*$ Scan

# %%
φ = 0.5
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [2.0, 5.0, 10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-5.0, 25.0], title, *params)

# %%
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [-2.0, -5.0, -10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-25.0, 5.0], title, *params)

# %% [markdown]
# ## Mean

# %%
φ = 0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.1
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = -0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Standard Deviation

# %%
φ = 0.9
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.2
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Parameter Estimation

# %%
φ = 0.5
μ = 5.0
σ = 2.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -2117.066
# Date:                Sun, 19 Jun 2022   AIC                           4240.132
# Time:                        13:06:29   BIC                           4254.855
# Sample:                             0   HQIC                          4245.728
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.0032      0.123     81.031      0.000       9.761      10.245
# ar.L1          0.4876      0.027     18.300      0.000       0.435       0.540
# sigma2         4.0389      0.174     23.273      0.000       3.699       4.379
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 8.16
# Prob(Q):                              0.89   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.82   Skew:                            -0.19
# Prob(H) (two-sided):                  0.08   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:06:29',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-29b1260c-a85b-456c-b837-9ea6fd45e6bc',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 5.0, 'σ': 2.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': {'Estimate': 10.003167481345036,
#      'Error': 0.1234493641232588,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.4875990193385519,
#       'Error': 0.026645191199236005,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 4.038913297939,
#      'Error': 0.17354437988656338,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = 0.9
μ = 10.0
σ = 5.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3056.067
# Date:                Sun, 19 Jun 2022   AIC                           6118.133
# Time:                        13:06:29   BIC                           6132.856
# Sample:                             0   HQIC                          6123.729
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         96.6664      2.840     34.043      0.000      91.101     102.232
# ar.L1          0.9447      0.005    195.380      0.000       0.935       0.954
# sigma2        26.3650      1.105     23.853      0.000      24.199      28.531
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                85.97
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                            -0.12
# Prob(H) (two-sided):                  0.19   Kurtosis:                         4.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:06:29',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-54bd406e-7a20-4acd-84fa-b9c343ab7ae7',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.9], 'μ': 10.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': {'Estimate': 96.6664195558423,
#      'Error': 2.839555285970898,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.9446800741452348,
#       'Error': 0.004835085117320991,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 26.36501208976223,
#      'Error': 1.105328483618883,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = -0.5
μ = 5.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3028.955
# Date:                Sun, 19 Jun 2022   AIC                           6063.909
# Time:                        13:06:30   BIC                           6078.632
# Sample:                             0   HQIC                          6069.505
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0320      0.104     29.122      0.000       2.828       3.236
# ar.L1         -0.5231      0.026    -20.266      0.000      -0.574      -0.472
# sigma2        25.0211      1.130     22.147      0.000      22.807      27.235
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                 1.06
# Prob(Q):                              0.20   Prob(JB):                         0.59
# Heteroskedasticity (H):               1.03   Skew:                            -0.08
# Prob(H) (two-sided):                  0.76   Kurtosis:                         2.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:06:30',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-9ba21a91-cb6b-49f6-9a84-0abb06138580',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'μ': 5.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': {'Estimate': 3.0319862548988072,
#      'Error': 0.10411374114044177,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': -0.5230697784013726,
#       'Error': 0.025810640784704006,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 25.02111241421988,
#      'Error': 1.1297635619662822,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
