# %% [markdown]
# # $\text{AR}(1)$ with Offset
#
# $\text{AR}(1)$ with a constant offset is defined by,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \mu^* + \sigma \varepsilon_t
# \end{align}
# $
#
# where, $\varepsilon \sim \text{Normal}(0,1)$
#
# The stationarity requires $\lvert \varphi \rvert < 1$. The stationary mean and variance are given by,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}(X_t) = \frac{\mu^*}{1 - \varphi} \\
# &\lim_{t \to \infty} \text{Var}(X_t) = \frac{\sigma^2}{1 - \varphi^2}
# \end{align}
# $
#
# It follows that $X_t$ has distribution,
#
# $
# \begin{align}
# X_t \sim \text{Normal}\left(  \frac{\mu}{1 - \varphi} ,  \frac{\sigma^2}{1 - \varphi^2} \right)
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib.models import arima
from lib import (ARIMA, Stats, PlotType)
from lib import (stack, fpoints, fcurve, curve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
σ = 1.0
nsample = 1000

def cumu_mean_plot(φ, σ, μ, nsample):
    ar = ARIMA.Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    mean = Stats.Func.CUMU_MEAN.apply(ar)
    ar1_mean = ARIMA.Func.AR1_OFFSET_MEAN.apply(ar, φ=φ, μ=μ)
    fcurve(data=mean, func=ar1_mean, title_offset=1.025, plot_type=PlotType.XLOG)
    
def cumu_sd_plot(φ, σ, μ, nsample):
    ar = ARIMA.Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    sd = Stats.Func.CUMU_SD.apply(ar)
    ar1_sd = ARIMA.Func.AR1_OFFSET_SD.apply(ar, φ=φ, σ=σ)
    fcurve(data=sd, func=ar1_sd, title_offset=1.025, plot_type=PlotType.XLOG)
    
def comparison_plot_μ(μ_vals, ylim, title, *params):
    labels = [r"$μ^*=$" + f"{val}" for val in μ_vals]
    scan = ARIMA.Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    
def comparison_plot_φ(φ_vals, ylim, title, *params):
    labels = [f"φ={val}" for val in φ_vals] 
    scan = ARIMA.Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)

# %% [markdown]
# ## Simulation $\varphi$ Scan

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: $σ={{{σ}}}$, $μ^*={{{μ}}}$"
φ_vals = [0.1, 0.5, 0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [0.0, 60.0], title, *params)

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: σ={σ}, " + r"$μ^*$=" + f"{μ}"
φ_vals = [-0.1, -0.5, -0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [-5.0, 10.0], title, *params)

# %% [markdown]
# ## Simulation $\mu^*$ Scan

# %%
φ = 0.5
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [2.0, 5.0, 10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-5.0, 25.0], title, *params)

# %%
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [-2.0, -5.0, -10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-25.0, 5.0], title, *params)

# %% [markdown]
# ## Mean

# %%
φ = 0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.1
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = -0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Standard Deviation

# %%
φ = 0.9
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.2
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Parameter Estimation

# %%
φ = 0.5
μ = 5.0
σ = 2.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = ARIMA.Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -2131.540
# Date:                Sat, 20 Aug 2022   AIC                           4269.080
# Time:                        10:34:23   BIC                           4283.803
# Sample:                             0   HQIC                          4274.676
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.8258      0.119     82.861      0.000       9.593      10.058
# ar.L1          0.4604      0.028     16.395      0.000       0.405       0.515
# sigma2         4.1578      0.184     22.587      0.000       3.797       4.519
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.51   Jarque-Bera (JB):                 0.76
# Prob(Q):                              0.47   Prob(JB):                         0.68
# Heteroskedasticity (H):               1.00   Skew:                            -0.06
# Prob(H) (two-sided):                  0.98   Kurtosis:                         3.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:34:23',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-26495575-8924-47dc-b4d5-e553da0c68e4',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 5.0, 'σ': 2.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Estimate Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 9.825753991820322,
#      'Error': 0.11858173645857471,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.46041061751984247,
#       'Error': 0.028082777567926376,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 4.157813266804567,
#      'Error': 0.18408206466138446,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = 0.9
μ = 10.0
σ = 5.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = ARIMA.Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3061.540
# Date:                Sat, 20 Aug 2022   AIC                           6129.080
# Time:                        10:34:23   BIC                           6143.803
# Sample:                             0   HQIC                          6134.676
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         98.6665      3.382     29.177      0.000      92.039     105.295
# ar.L1          0.9545      0.005    209.154      0.000       0.946       0.963
# sigma2        26.6497      1.207     22.085      0.000      24.285      29.015
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                30.23
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.99   Skew:                            -0.11
# Prob(H) (two-sided):                  0.95   Kurtosis:                         3.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:34:23',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-fa297b7e-2aa2-493a-a686-a1a3c2f21aaf',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.9], 'μ': 10.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Estimate Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 98.66651077595783,
#      'Error': 3.3816915992194705,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.9544683731172146,
#       'Error': 0.0045634770447741104,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 26.64971599128196,
#      'Error': 1.2066816273147563,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = -0.5
μ = 5.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = ARIMA.Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3033.893
# Date:                Sat, 20 Aug 2022   AIC                           6073.786
# Time:                        10:34:23   BIC                           6088.509
# Sample:                             0   HQIC                          6079.382
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4014      0.104     32.556      0.000       3.197       3.606
# ar.L1         -0.5259      0.028    -18.978      0.000      -0.580      -0.472
# sigma2        25.2696      1.071     23.602      0.000      23.171      27.368
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                 4.36
# Prob(Q):                              0.82   Prob(JB):                         0.11
# Heteroskedasticity (H):               0.90   Skew:                             0.11
# Prob(H) (two-sided):                  0.32   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:34:23',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-67acbbb7-b474-4e7b-9c86-b1af747a52bc',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'μ': 5.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Estimate Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 3.4013773241506997,
#      'Error': 0.10447735422976936,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': -0.5258892170661759,
#       'Error': 0.027710400339771662,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 25.269582256072304,
#      'Error': 1.070660529203382,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
