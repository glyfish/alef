# %% [markdown]
# # $\text{AR}(1)$ with Offset
#
# $\text{AR}(1)$ with a constant offset is defined by,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \mu^* + \sigma \varepsilon_t
# \end{align}
# $
#
# where, $\varepsilon \sim \text{Normal}(0,1)$
#
# The stationarity requires $\lvert \varphi \rvert < 1$. The stationary mean and variance are given by,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}(X_t) = \frac{\mu^*}{1 - \varphi} \\
# &\lim_{t \to \infty} \text{Var}(X_t) = \frac{\sigma^2}{1 - \varphi^2}
# \end{align}
# $
#
# It follows that $X_t$ has distribution,
#
# $
# \begin{align}
# X_t \sim \text{Normal}\left(  \frac{\mu}{1 - \varphi} ,  \frac{\sigma^2}{1 - \varphi^2} \right)
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib.models import arima
from lib import (ARIMA, Stats, PlotType)
from lib import (stack, fpoints, fcurve, curve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
σ = 1.0
nsample = 1000

def cumu_mean_plot(φ, σ, μ, nsample):
    ar = ARIMA.Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    mean = Stats.Func.CUMU_MEAN.apply(ar)
    ar1_mean = ARIMA.Func.AR1_OFFSET_MEAN.apply(ar, φ=φ, μ=μ)
    fcurve(data=mean, func=ar1_mean, title_offset=1.025, plot_type=PlotType.XLOG)
    
def cumu_sd_plot(φ, σ, μ, nsample):
    ar = ARIMA.Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    sd = Stats.Func.CUMU_SD.apply(ar)
    ar1_sd = ARIMA.Func.AR1_OFFSET_SD.apply(ar, φ=φ, σ=σ)
    fcurve(data=sd, func=ar1_sd, title_offset=1.025, plot_type=PlotType.XLOG)
    
def comparison_plot_μ(μ_vals, ylim, title, *params):
    labels = [r"$μ^*=$" + f"{val}" for val in μ_vals]
    scan = ARIMA.Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    
def comparison_plot_φ(φ_vals, ylim, title, *params):
    labels = [f"φ={val}" for val in φ_vals] 
    scan = ARIMA.Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)

# %% [markdown]
# ## Simulation $\varphi$ Scan

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: $σ={{{σ}}}$, $μ^*={{{μ}}}$"
φ_vals = [0.1, 0.5, 0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [0.0, 60.0], title, *params)

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: σ={σ}, " + r"$μ^*$=" + f"{μ}"
φ_vals = [-0.1, -0.5, -0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [-5.0, 10.0], title, *params)

# %% [markdown]
# ## Simulation $\mu^*$ Scan

# %%
φ = 0.5
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [2.0, 5.0, 10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-5.0, 25.0], title, *params)

# %%
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [-2.0, -5.0, -10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-25.0, 5.0], title, *params)

# %% [markdown]
# ## Mean

# %%
φ = 0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.1
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = -0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Standard Deviation

# %%
φ = 0.9
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.2
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Parameter Estimation

# %%
φ = 0.5
μ = 5.0
σ = 2.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = ARIMA.Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -2129.955
# Date:                Mon, 20 Jun 2022   AIC                           4265.911
# Time:                        14:54:01   BIC                           4280.634
# Sample:                             0   HQIC                          4271.507
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.9381      0.123     80.507      0.000       9.696      10.180
# ar.L1          0.4832      0.027     17.963      0.000       0.430       0.536
# sigma2         4.1444      0.171     24.287      0.000       3.810       4.479
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                 6.19
# Prob(Q):                              0.82   Prob(JB):                         0.05
# Heteroskedasticity (H):               1.01   Skew:                             0.05
# Prob(H) (two-sided):                  0.89   Kurtosis:                         3.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:54:01',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-35ab9d1b-fe29-4e54-9b6e-13a08e88a7f2',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 5.0, 'σ': 2.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Estimate Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 9.938111543659488,
#      'Error': 0.12344468047528656,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.4831740429412546,
#       'Error': 0.02689846075731944,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 4.144418281613424,
#      'Error': 0.170643961013923,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = 0.9
μ = 10.0
σ = 5.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = ARIMA.Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3037.703
# Date:                Mon, 20 Jun 2022   AIC                           6081.406
# Time:                        14:54:01   BIC                           6096.130
# Sample:                             0   HQIC                          6087.002
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         94.2149      2.955     31.880      0.000      88.423     100.007
# ar.L1          0.9491      0.005    201.829      0.000       0.940       0.958
# sigma2        25.4128      1.116     22.779      0.000      23.226      27.599
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.11   Jarque-Bera (JB):                48.10
# Prob(Q):                              0.29   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.96   Skew:                            -0.12
# Prob(H) (two-sided):                  0.71   Kurtosis:                         4.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:54:01',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-b2fccece-6223-4367-9b21-6b9f18347ed4',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.9], 'μ': 10.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Estimate Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 94.21488675125586,
#      'Error': 2.955252928431335,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.9491464880532952,
#       'Error': 0.00470272602001314,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 25.412750622527,
#      'Error': 1.115606678093805,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = -0.5
μ = 5.0
nsample = 1000
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = ARIMA.Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3024.534
# Date:                Mon, 20 Jun 2022   AIC                           6055.067
# Time:                        14:54:01   BIC                           6069.791
# Sample:                             0   HQIC                          6060.663
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3312      0.104     32.044      0.000       3.127       3.535
# ar.L1         -0.5167      0.028    -18.229      0.000      -0.572      -0.461
# sigma2        24.8011      1.078     23.003      0.000      22.688      26.914
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.37   Jarque-Bera (JB):                 1.05
# Prob(Q):                              0.54   Prob(JB):                         0.59
# Heteroskedasticity (H):               1.01   Skew:                            -0.05
# Prob(H) (two-sided):                  0.96   Kurtosis:                         3.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:54:01',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-958d7a9c-296d-48e4-9491-c98b0b29570e',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'μ': 5.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Estimate Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 3.331238885051086,
#      'Error': 0.10395667804521477,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': -0.5167093402722325,
#       'Error': 0.02834570799745578,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 24.80109906449539,
#      'Error': 1.07815568877515,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
