# %% [markdown]
# # $\text{AR}(1)$ with Offset
#
# $\text{AR}(1)$ with a constant offset is defined by,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \mu^* + \sigma \varepsilon_t
# \end{align}
# $
#
# where, $\varepsilon \sim \text{Normal}(0,1)$
#
# The stationarity requires $\lvert \varphi \rvert < 1$. The stationary mean and variance are given by,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}(X_t) = \frac{\mu^*}{1 - \varphi} \\
# &\lim_{t \to \infty} \text{Var}(X_t) = \frac{\sigma^2}{1 - \varphi^2}
# \end{align}
# $
#
# It follows that $X_t$ has distribution,
#
# $
# \begin{align}
# X_t \sim \text{Normal}\left(  \frac{\mu}{1 - \varphi} ,  \frac{\sigma^2}{1 - \varphi^2} \right)
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib.models import arima
from lib import (Func, Source, Est, PlotType)
from lib import (stack, fpoints, fcurve, curve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
σ = 1.0
nsample = 1000

def cumu_mean_plot(φ, σ, μ, nsample):
    ar = Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    mean = Func.CUMU_MEAN.apply(ar)
    ar1_mean = Func.AR1_OFFSET_MEAN.apply(ar, φ=φ, μ=μ)
    fcurve(data=mean, func=ar1_mean, title_offset=1.025, plot_type=PlotType.XLOG)
    
def cumu_sd_plot(φ, σ, μ, nsample):
    ar = Source.AR_OFFSET.create(φ=[φ], σ=σ, μ=μ, npts=nsample)
    sd = Func.CUMU_SD.apply(ar)
    ar1_sd = Func.AR1_OFFSET_SD.apply(ar, φ=φ, σ=σ)
    fcurve(data=sd, func=ar1_sd, title_offset=1.025, plot_type=PlotType.XLOG)
    
def comparison_plot_μ(μ_vals, ylim, title, *params):
    labels = [r"$μ^*=$" + f"{val}" for val in μ_vals]
    scan = Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    
def comparison_plot_φ(φ_vals, ylim, title, *params):
    labels = [f"φ={val}" for val in φ_vals] 
    scan = Source.AR_OFFSET.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)

# %% [markdown]
# ## Simulation $\varphi$ Scan

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: $σ={{{σ}}}$, $μ^*={{{μ}}}$"
φ_vals = [0.1, 0.5, 0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [0.0, 60.0], title, *params)

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: σ={σ}, " + r"$μ^*$=" + f"{μ}"
φ_vals = [-0.1, -0.5, -0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [-5.0, 10.0], title, *params)

# %% [markdown]
# ## Simulation $\mu^*$ Scan

# %%
φ = 0.5
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [2.0, 5.0, 10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-5.0, 25.0], title, *params)

# %%
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [-2.0, -5.0, -10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "npts": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-25.0, 5.0], title, *params)

# %% [markdown]
# ## Mean

# %%
φ = 0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = 0.1
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %%
φ = -0.9
μ = 5.0
nsample = 100000
cumu_mean_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Standard Deviation

# %%
φ = 0.9
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.5
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %%
φ = 0.2
nsample = 100000
cumu_sd_plot(φ, σ, μ, nsample)

# %% [markdown]
# ## Parameter Estimation

# %%
φ = 0.5
μ = 5.0
σ = 2.0
nsample = 1000
df = Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -2130.645
# Date:                Sun, 05 Jun 2022   AIC                           4267.290
# Time:                        17:08:25   BIC                           4282.014
# Sample:                             0   HQIC                          4272.886
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.0650      0.137     73.347      0.000       9.796      10.334
# ar.L1          0.5342      0.026     20.661      0.000       0.484       0.585
# sigma2         4.1498      0.183     22.625      0.000       3.790       4.509
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):                 4.91
# Prob(Q):                              0.60   Prob(JB):                         0.09
# Heteroskedasticity (H):               0.92   Skew:                            -0.16
# Prob(H) (two-sided):                  0.45   Kurtosis:                         3.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '05/06/2022 17:08:25',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-b400c175-00b9-4e92-9965-cf404ce3eb3e',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 5.0, 'σ': 2.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': {'Estimate': 10.065013931119093,
#      'Error': 0.1372252397940086,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.5342366724747171,
#       'Error': 0.025857858024157125,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 4.14983159231071,
#      'Error': 0.18341555691838013,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = 0.9
μ = 10.0
σ = 5.0
nsample = 1000
df = Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3075.130
# Date:                Sun, 05 Jun 2022   AIC                           6156.260
# Time:                        17:08:26   BIC                           6170.983
# Sample:                             0   HQIC                          6161.855
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         95.7789      3.447     27.787      0.000      89.023     102.535
# ar.L1          0.9556      0.005    207.893      0.000       0.947       0.965
# sigma2        27.3837      1.160     23.610      0.000      25.111      29.657
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                39.81
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                            -0.14
# Prob(H) (two-sided):                  0.39   Kurtosis:                         3.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '05/06/2022 17:08:25',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-b969aa4c-1a82-4d4d-a7ea-6fba7a81fce4',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.9], 'μ': 10.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': {'Estimate': 95.77893752714898,
#      'Error': 3.446856380391126,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.9555650340159262,
#       'Error': 0.004596436953474151,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 27.383731793139333,
#      'Error': 1.1598170032005923,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %%
φ = -0.5
μ = 5.0
nsample = 1000
df = Source.AR_OFFSET.create(φ=[φ], μ=μ, σ=σ, npts=nsample)
curve(df)

# %%
results = Est.AR_OFFSET.perform(df, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3018.296
# Date:                Sun, 05 Jun 2022   AIC                           6042.593
# Time:                        17:08:26   BIC                           6057.316
# Sample:                             0   HQIC                          6048.188
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3356      0.104     32.042      0.000       3.132       3.540
# ar.L1         -0.5055      0.028    -18.008      0.000      -0.561      -0.450
# sigma2        24.4939      1.108     22.099      0.000      22.322      26.666
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 0.09
# Prob(Q):                              0.70   Prob(JB):                         0.96
# Heteroskedasticity (H):               1.00   Skew:                            -0.00
# Prob(H) (two-sided):                  0.98   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '05/06/2022 17:08:26',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-41c6cc30-f0d2-4609-8a7e-73fa42c01cac',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'μ': 5.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <Est.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': {'Estimate': 3.3355793400809977,
#      'Error': 0.1041008013099278,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': -0.5054921295712401,
#       'Error': 0.028069826477564667,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 24.493949516314753,
#      'Error': 1.1083758286954153,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
