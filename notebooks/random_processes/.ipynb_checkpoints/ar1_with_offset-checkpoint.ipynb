# %% [markdown]
# # $\text{AR}(1)$ with Offset
#
# $\text{AR}(1)$ with a constant offset is defined by,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \mu^* + \sigma \varepsilon_t
# \end{align}
# $
#
# where, $\varepsilon \sim \text{Normal}(0,1)$
#
# The stationarity requires $\lvert \varphi \rvert < 1$. The stationary mean and variance are given by,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}(X_t) = \frac{\mu^*}{1 - \varphi} \\
# &\lim_{t \to \infty} \text{Var}(X_t) = \frac{\sigma^2}{1 - \varphi^2}
# \end{align}
# $
#
# It follows that $X_t$ has distribution,
#
# $
# \begin{align}
# X_t \sim \text{Normal}\left(  \frac{\mu}{1 - \varphi} ,  \frac{\sigma^2}{1 - \varphi^2} \right)
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib.models import arima
from lib import (DataType, DataSchema, DataFunc, SourceType, DataSource, perform_est, EstType)
from lib import (stack, FuncPlotType, fpoints, fcurve, curve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## Helpers

# %%
σ = 1.0
nsample = 1000

def cumu_mean_plot(φ, σ, μ, nsample):
    ar = DataSource.create_source_type(SourceType.AR_OFFSET, φ=[φ], σ=σ, μ=μ, xmax=nsample)
    ar = DataFunc.apply_func_type(ar, DataType.CUMU_MEAN)
    ar = DataFunc.apply_func_type(ar, DataType.AR1_OFFSET_MEAN, φ=φ, μ=μ)
    fcurve(ar, FuncPlotType.AR1_CUMU_OFFSET_MEAN, title_offset=1.025)
    
def cumu_sd_plot(φ, σ, μ, nsample):
    ar = DataSource.create_source_type(SourceType.AR_OFFSET, φ=[φ], σ=σ, μ=μ, xmax=nsample)
    ar = DataFunc.apply_func_type(ar, DataType.CUMU_SD)
    ar = DataFunc.apply_func_type(ar, DataType.AR1_OFFSET_SD, φ=φ, σ=σ)
    fcurve(ar, FuncPlotType.AR1_CUMU_OFFSET_SD, title_offset=1.025)
    
def comparison_plot_μ(μ_vals, ylim, title, *params):
    labels = [r"$μ^*=$" + f"{val}" for val in μ_vals]
    scan = DataSource.create_parameter_scan(SourceType.AR_OFFSET, *params)
    stack(scan, ylim=ylim, title=title, labels=labels, data_type=DataType.TIME_SERIES)
    
def comparison_plot_φ(φ_vals, ylim, title, *params):
    labels = [f"φ={val}" for val in φ_vals] 
    scan = DataSource.create_parameter_scan(SourceType.AR_OFFSET, *params)
    stack(scan, ylim=ylim, title=title, labels=labels, data_type=DataType.TIME_SERIES)

# %% [markdown]
# ## Simulation $\varphi$ Scan

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: σ={σ}, " + r"$μ^*$=" + f"{μ}"
φ_vals = [0.1, 0.5, 0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "xmax": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [0.0, 60.0], title, *params)

# %%
μ = 5.0
title = f"AR(1) Series Comparison φ Scan: σ={σ}, " + r"$μ^*$=" + f"{μ}"
φ_vals = [-0.1, -0.5, -0.9]
params = [{"φ": [φ], "σ": σ, "μ": μ, "xmax": nsample} for φ in φ_vals]
comparison_plot_φ(φ_vals, [-5.0, 10.0], title, *params)

# %% [markdown]
# ## Simulation $\mu^*$ Scan

# %%
φ = 0.5
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [2.0, 5.0, 10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "xmax": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-5.0, 25.0], title, *params)

# %%
title = f"AR(1) Series Comparison " + r"$\mu^*$" + f" Scan: σ={σ}, φ={φ}"
μ_vals = [-2.0, -5.0, -10.0]
params = [{"φ": [φ], "σ": σ, "μ": μ, "xmax": nsample} for μ in μ_vals]
comparison_plot_μ(μ_vals, [-25.0, 5.0], title, *params)

# %% [markdown]
# ## Mean

# %%
φ = 0.9
μ = 5.0
nsample = 100000
title = f"AR(1) Cumulative Mean σ={σ}, φ={φ}, " + r"$\mu^*=$" + f"{μ}"
cumu_mean_plot(φ, σ, μ, nsample, title)

# %%
φ = 0.5
μ = 5.0
nsample = 100000
title = f"AR(1) Cumulative Mean σ={σ}, φ={φ}, " + r"$\mu^*=$" + f"{μ}"
cumu_mean_plot(φ, σ, μ, nsample, title)

# %%
φ = 0.1
μ = 5.0
nsample = 100000
title = f"AR(1) Cumulative Mean σ={σ}, φ={φ}, " + r"$\mu^*=$" + f"{μ}"
cumu_mean_plot(φ, σ, μ, nsample, title)

# %%
φ = -0.9
μ = 5.0
nsample = 100000
title = f"AR(1) Cumulative Mean σ={σ}, φ={φ}, " + r"$\mu^*=$" + f"{μ}"
cumu_mean_plot(φ, σ, μ, nsample, title)

# %% [markdown]
# ## Standard Deviation

# %%
φ = 0.9
nsample = 100000
title = f"AR(1) Cumulative Standard Deviation σ={σ}, φ={φ}, " + r"$\mu^*=$" + f"{μ}"
cumu_sd_plot(φ, σ, μ, nsample, title)

# %%
φ = 0.5
nsample = 100000
title = f"AR(1) Cumulative Standard Deviation σ={σ}, φ={φ}, " + r"$\mu^*=$" + f"{μ}"
cumu_sd_plot(φ, σ, μ, nsample, title)

# %%
φ = 0.2
nsample = 100000
title = f"AR(1) Cumulative Standard Deviation σ={σ}, φ={φ}, " + r"$\mu^*=$" + f"{μ}"
cumu_sd_plot(φ, σ, μ, nsample, title)

# %% [markdown]
# ## Parameter Estimation

# %%
φ = 0.5
μ = 5.0
σ = 2.0
nsample = 1000
df = DataSource.create_source_type(SourceType.AR_OFFSET, φ=[φ], μ=μ, σ=σ, xmax=nsample)
curve(df, data_type=DataType.TIME_SERIES)

# %%
results = perform_est(df, EstType.AR_OFFSET, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -2134.076
# Date:                Sun, 15 May 2022   AIC                           4274.153
# Time:                        18:05:16   BIC                           4288.879
# Sample:                             0   HQIC                          4279.749
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.9256      0.138     71.940      0.000       9.655      10.196
# ar.L1          0.5359      0.026     20.804      0.000       0.485       0.586
# sigma2         4.1606      0.188     22.141      0.000       3.792       4.529
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 0.58
# Prob(Q):                              0.87   Prob(JB):                         0.75
# Heteroskedasticity (H):               1.04   Skew:                            -0.06
# Prob(H) (two-sided):                  0.69   Kurtosis:                         2.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 5.0, 'σ': 2.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <EstType.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': [9.925637122130116, 0.13797168346323335],
#     'Parameters': [[0.5358816273058297, 0.025758903042509645]],
#     'Sigma2': [4.160616955256058, 0.18791375352938808]}},
#   'Tests': {}},
#  'Date': '15/05/2022 18:05:05',
#  'Name': 'AR(1)-Simulation-53c2e23c-8c6d-43af-9d80-e89301f1e01e'}

# %%
φ = 0.9
μ = 10.0
σ = 5.0
nsample = 1000
df = DataSource.create_source_type(SourceType.AR_OFFSET, φ=[φ], μ=μ, σ=σ, xmax=nsample)
curve(df, data_type=DataType.TIME_SERIES)

# %%
results = perform_est(df, EstType.AR_OFFSET, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3081.326
# Date:                Sun, 15 May 2022   AIC                           6168.652
# Time:                        18:05:57   BIC                           6183.378
# Sample:                             0   HQIC                          6174.249
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         97.4312      2.779     35.064      0.000      91.985     102.877
# ar.L1          0.9425      0.005    191.398      0.000       0.933       0.952
# sigma2        27.5620      1.186     23.245      0.000      25.238      29.886
# ===================================================================================
# Ljung-Box (L1) (Q):                   6.18   Jarque-Bera (JB):                89.36
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.63   Skew:                            -0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.9], 'μ': 10.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <EstType.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': [97.43123272337739, 2.778694453023979],
#     'Parameters': [[0.9424562897715307, 0.0049240741169282376]],
#     'Sigma2': [27.561957991369397, 1.1857208064461302]}},
#   'Tests': {}},
#  'Date': '15/05/2022 18:05:54',
#  'Name': 'AR(1)-Simulation-66044c93-57d9-40f5-9c0a-f4547fac9fbe'}

# %%
φ = -0.5
μ = 5.0
nsample = 1000
df = DataSource.create_source_type(SourceType.AR_OFFSET, φ=[φ], μ=μ, σ=σ, xmax=nsample)
curve(df, data_type=DataType.TIME_SERIES)

# %%
results = perform_est(df, EstType.AR_OFFSET, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3030.054
# Date:                Sun, 15 May 2022   AIC                           6066.108
# Time:                        18:06:24   BIC                           6080.834
# Sample:                             0   HQIC                          6071.704
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4099      0.104     32.856      0.000       3.207       3.613
# ar.L1         -0.5208      0.029    -18.245      0.000      -0.577      -0.465
# sigma2        24.9249      1.120     22.263      0.000      22.731      27.119
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.42   Jarque-Bera (JB):                 0.06
# Prob(Q):                              0.52   Prob(JB):                         0.97
# Heteroskedasticity (H):               1.05   Skew:                            -0.02
# Prob(H) (two-sided):                  0.67   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df.attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'μ': 5.0, 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR_OFFSET(1)': {'Type': <EstType.AR_OFFSET: 'AR_OFFSET'>,
#     'Const': [3.4099118604910594, 0.10378302455160311],
#     'Parameters': [[-0.5207654668277041, 0.028542207750949615]],
#     'Sigma2': [24.924916560049297, 1.1195830974585692]}},
#   'Tests': {}},
#  'Date': '15/05/2022 18:06:21',
#  'Name': 'AR(1)-Simulation-d5e738dc-4055-4186-b82e-f4dc5f932bc3'}
