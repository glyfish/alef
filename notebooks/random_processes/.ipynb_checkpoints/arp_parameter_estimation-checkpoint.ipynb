# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (ARIMA, Est)
from lib import (stack, fpoints, fcurve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
nsample = 1000

def comparison(φ_vals, σ, ylim, *params):
    title = "AR(p) Comparison Plot"
    labels = [f"φ={val}" for val in φ_vals] 
    scan = ARIMA.Source.AR.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    return scan

# %% [markdown]
# ## Simulations

# %%
σ = 1.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-7.5, 7.5], *params)

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example $\varphi = 0.2$

# %%
df = ARIMA.Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.234829

# %%
results = ARIMA.Est.AR.perform(ar[0], order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1434.009
# Date:                Sat, 20 Aug 2022   AIC                           2874.018
# Time:                        10:33:42   BIC                           2888.745
# Sample:                             0   HQIC                          2879.615
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0114      0.042     -0.270      0.787      -0.094       0.071
# ar.L1          0.2389      0.032      7.374      0.000       0.175       0.302
# sigma2         1.0276      0.042     24.206      0.000       0.944       1.111
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 7.11
# Prob(Q):                              0.89   Prob(JB):                         0.03
# Heteroskedasticity (H):               1.05   Skew:                            -0.07
# Prob(H) (two-sided):                  0.67   Kurtosis:                         3.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:33:42',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-6d8a5c28-70e6-4ade-84e1-750d6332f865',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': -0.011384860373625358,
#      'Error': 0.04214129429824945,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.23888168073679944,
#       'Error': 0.03239684782482438,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 1.0275808483762587,
#      'Error': 0.04245116469055617,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example $\varphi = [0.2, 0.4]$

# %%
df = ARIMA.Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.173017
# 2  2.0  0.340394

# %%
results = ARIMA.Est.AR.perform(ar[1], order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1421.332
# Date:                Sat, 20 Aug 2022   AIC                           2850.663
# Time:                        10:33:42   BIC                           2870.298
# Sample:                             0   HQIC                          2858.126
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0300      0.065     -0.461      0.645      -0.158       0.098
# ar.L1          0.1727      0.030      5.707      0.000       0.113       0.232
# ar.L2          0.3407      0.031     11.140      0.000       0.281       0.401
# sigma2         1.0016      0.045     22.489      0.000       0.914       1.089
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.64
# Prob(Q):                              0.99   Prob(JB):                         0.44
# Heteroskedasticity (H):               1.07   Skew:                            -0.10
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:33:42',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-ee15c120-a3af-4c65-a661-c58eb1bbdd19',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': -0.029997678449560947,
#      'Error': 0.06513652461399298,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.17266645511473916,
#       'Error': 0.030256948446855923,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.34073887073590137,
#       'Error': 0.030588064626915632,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 1.0016270895012653,
#      'Error': 0.044538330390031314,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example $\varphi = [0.2, 0.3, 0.3]$

# %%
df = ARIMA.Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.140305
# 2  2.0  0.318568
# 3  3.0  0.313225

# %%
results = ARIMA.Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -1446.876
# Date:                Sat, 20 Aug 2022   AIC                           2903.751
# Time:                        10:33:43   BIC                           2928.295
# Sample:                             0   HQIC                          2913.079
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2507      0.142      1.761      0.078      -0.028       0.530
# ar.L1          0.1397      0.029      4.789      0.000       0.083       0.197
# ar.L2          0.3187      0.028     11.516      0.000       0.264       0.373
# ar.L3          0.3130      0.029     10.611      0.000       0.255       0.371
# sigma2         1.0535      0.047     22.511      0.000       0.962       1.145
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.62   Jarque-Bera (JB):                 1.62
# Prob(Q):                              0.43   Prob(JB):                         0.44
# Heteroskedasticity (H):               1.01   Skew:                            -0.09
# Prob(H) (two-sided):                  0.95   Kurtosis:                         3.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:33:42',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-77a1d893-e0b4-4351-8185-cd573573533f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 0.250724591903864,
#      'Error': 0.14238869306829213,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.13971754488874263,
#       'Error': 0.02917219834523422,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3187146169083817,
#       'Error': 0.027674702673181617,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.312975178736835,
#       'Error': 0.02949431884058911,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 1.053496116094867,
#      'Error': 0.046799601061001395,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
σ = 5.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-20.0, 20.0], *params)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
df = ARIMA.Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.228808

# %%
results = ARIMA.Est.AR.perform(ar[0], order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3011.092
# Date:                Sat, 20 Aug 2022   AIC                           6028.183
# Time:                        10:33:43   BIC                           6042.910
# Sample:                             0   HQIC                          6033.780
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2546      0.202     -1.263      0.207      -0.650       0.141
# ar.L1          0.2287      0.032      7.141      0.000       0.166       0.291
# sigma2        24.0038      1.039     23.106      0.000      21.968      26.040
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 3.78
# Prob(Q):                              0.89   Prob(JB):                         0.15
# Heteroskedasticity (H):               0.87   Skew:                             0.13
# Prob(H) (two-sided):                  0.20   Kurtosis:                         3.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:33:43',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-3a4951a5-62b3-4996-bcf4-119b23aa98d2',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': -0.25458919139260555,
#      'Error': 0.20165437680093468,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.22871111460381904,
#       'Error': 0.03202777756321677,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 24.00375513555744,
#      'Error': 1.0388612115470295,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
df = ARIMA.Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.154411
# 2  2.0  0.443901

# %%
results = ARIMA.Est.AR.perform(ar[1], order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -3010.448
# Date:                Sat, 20 Aug 2022   AIC                           6028.896
# Time:                        10:33:43   BIC                           6048.531
# Sample:                             0   HQIC                          6036.358
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0053      0.389     -0.014      0.989      -0.767       0.757
# ar.L1          0.1544      0.028      5.584      0.000       0.100       0.209
# ar.L2          0.4437      0.028     15.600      0.000       0.388       0.499
# sigma2        23.9625      1.073     22.335      0.000      21.860      26.065
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.14   Jarque-Bera (JB):                 1.95
# Prob(Q):                              0.71   Prob(JB):                         0.38
# Heteroskedasticity (H):               0.86   Skew:                             0.11
# Prob(H) (two-sided):                  0.18   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:33:43',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-a2b224db-4cd8-487d-b472-5b02133ca3a6',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 5.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': -0.005338287125879573,
#      'Error': 0.3887418093117759,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.15440197561303054,
#       'Error': 0.02765304466728818,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.44367887519107285,
#       'Error': 0.028441121363574302,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 23.962518526138343,
#      'Error': 1.0728529573077723,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
df = ARIMA.Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.160617
# 2  2.0  0.312320
# 3  3.0  0.326007

# %%
results = ARIMA.Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -2997.070
# Date:                Sat, 20 Aug 2022   AIC                           6004.140
# Time:                        10:33:43   BIC                           6028.684
# Sample:                             0   HQIC                          6013.468
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2016      0.760     -0.265      0.791      -1.692       1.289
# ar.L1          0.1596      0.031      5.104      0.000       0.098       0.221
# ar.L2          0.3120      0.028     11.040      0.000       0.257       0.367
# ar.L3          0.3265      0.031     10.387      0.000       0.265       0.388
# sigma2        23.3199      0.987     23.633      0.000      21.386      25.254
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 6.70
# Prob(Q):                              0.76   Prob(JB):                         0.04
# Heteroskedasticity (H):               1.09   Skew:                             0.14
# Prob(H) (two-sided):                  0.44   Kurtosis:                         3.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/08/2022 10:33:43',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-c0d79e5d-8142-4801-b8c6-e935bc99ed66',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 5.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': -0.20156042844543082,
#      'Error': 0.7603340962722572,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.1595996404242391,
#       'Error': 0.0312665763886119,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3120277729570526,
#       'Error': 0.028262995918608508,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.3264693917178422,
#       'Error': 0.031429159788573725,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 23.31991769294211,
#      'Error': 0.986760812795735,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
