# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (ARIMA, Est)
from lib import (stack, fpoints, fcurve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
nsample = 1000

def comparison(φ_vals, σ, ylim, *params):
    title = "AR(p) Comparison Plot"
    labels = [f"φ={val}" for val in φ_vals] 
    scan = ARIMA.Source.AR.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    return scan

# %% [markdown]
# ## Simulations

# %%
σ = 1.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-7.5, 7.5], *params)

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example $\varphi = 0.2$

# %%
df = ARIMA.Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.147269

# %%
results = Est.AR.perform(ar[0], order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1411.251
# Date:                Sun, 19 Jun 2022   AIC                           2828.501
# Time:                        13:14:04   BIC                           2843.227
# Sample:                             0   HQIC                          2834.098
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0286      0.037      0.775      0.438      -0.044       0.101
# ar.L1          0.1474      0.032      4.549      0.000       0.084       0.211
# sigma2         0.9819      0.047     20.740      0.000       0.889       1.075
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 3.44
# Prob(Q):                              0.99   Prob(JB):                         0.18
# Heteroskedasticity (H):               1.20   Skew:                            -0.03
# Prob(H) (two-sided):                  0.10   Kurtosis:                         2.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:14:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-15f39de3-26fc-4bbb-83e8-30457981f3b1',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.02858484228023563,
#      'Error': 0.03687645076399541,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.1473879535124751,
#       'Error': 0.03239931787222009,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 0.9819400321977535,
#      'Error': 0.04734468677374768,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example $\varphi = [0.2, 0.4]$

# %%
df = ARIMA.Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.193083
# 2  2.0  0.399705

# %%
results = Est.AR.perform(ar[1], order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1451.288
# Date:                Sun, 19 Jun 2022   AIC                           2910.577
# Time:                        13:14:04   BIC                           2930.212
# Sample:                             0   HQIC                          2918.039
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0808      0.080      1.010      0.312      -0.076       0.238
# ar.L1          0.1924      0.028      6.912      0.000       0.138       0.247
# ar.L2          0.4002      0.029     13.778      0.000       0.343       0.457
# sigma2         1.0633      0.051     21.021      0.000       0.964       1.162
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.27   Jarque-Bera (JB):                 2.22
# Prob(Q):                              0.60   Prob(JB):                         0.33
# Heteroskedasticity (H):               1.00   Skew:                            -0.02
# Prob(H) (two-sided):                  0.98   Kurtosis:                         2.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:14:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-37d2f3b7-34f0-4605-b1c4-c58db50cce59',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.0808268303060468,
#      'Error': 0.080007409167464,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.19244299607436285,
#       'Error': 0.02783998642276358,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.40022531806247247,
#       'Error': 0.02904875743841637,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 1.0632811920796266,
#      'Error': 0.050581410731782815,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example $\varphi = [0.2, 0.3, 0.3]$

# %%
df = ARIMA.Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.133824
# 2  2.0  0.309709
# 3  3.0  0.306884

# %%
results = Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -1394.772
# Date:                Sun, 19 Jun 2022   AIC                           2799.544
# Time:                        13:14:04   BIC                           2824.087
# Sample:                             0   HQIC                          2808.872
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2415      0.125      1.939      0.053      -0.003       0.486
# ar.L1          0.1325      0.027      4.835      0.000       0.079       0.186
# ar.L2          0.3120      0.029     10.789      0.000       0.255       0.369
# ar.L3          0.3087      0.029     10.488      0.000       0.251       0.366
# sigma2         0.9494      0.043     21.881      0.000       0.864       1.034
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.37   Jarque-Bera (JB):                 0.54
# Prob(Q):                              0.55   Prob(JB):                         0.76
# Heteroskedasticity (H):               0.97   Skew:                            -0.05
# Prob(H) (two-sided):                  0.79   Kurtosis:                         2.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:14:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-28b42d57-67ef-4fad-9a95-6dc1ee167eca',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.24153548283733106,
#      'Error': 0.12457882416920525,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.13250468284403952,
#       'Error': 0.027405652010078,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3119705129019857,
#       'Error': 0.028915796828362646,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.3086756317168705,
#       'Error': 0.02943085691215807,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 0.949378527536576,
#      'Error': 0.043387829635026985,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
σ = 5.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-20.0, 20.0], *params)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
df = ARIMA.Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.220494

# %%
results = Est.AR.perform(ar[0], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3073.199
# Date:                Sun, 19 Jun 2022   AIC                           6156.399
# Time:                        13:14:05   BIC                           6180.942
# Sample:                             0   HQIC                          6165.726
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0180      0.202     -0.089      0.929      -0.414       0.378
# ar.L1          0.2311      0.032      7.216      0.000       0.168       0.294
# ar.L2         -0.0382      0.033     -1.173      0.241      -0.102       0.026
# ar.L3         -0.0110      0.031     -0.353      0.724      -0.072       0.050
# sigma2        27.1719      1.379     19.703      0.000      24.469      29.875
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 7.99
# Prob(Q):                              1.00   Prob(JB):                         0.02
# Heteroskedasticity (H):               1.17   Skew:                             0.01
# Prob(H) (two-sided):                  0.15   Kurtosis:                         2.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:14:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-3731ee3e-2256-4180-86bc-ec3bcac5a96f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.0179705489231274,
#      'Error': 0.2021133780140661,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.23111402586312704,
#       'Error': 0.032027495342317414,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': -0.03817874629557903,
#       'Error': 0.032534125552461046,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': -0.010967792447320598,
#       'Error': 0.031109228818462835,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 27.171911693969328,
#      'Error': 1.3790876211213525,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
df = ARIMA.Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.172562
# 2  2.0  0.413093

# %%
results = Est.AR.perform(ar[1], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3016.091
# Date:                Sun, 19 Jun 2022   AIC                           6042.182
# Time:                        13:14:05   BIC                           6066.726
# Sample:                             0   HQIC                          6051.510
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1337      0.376     -0.356      0.722      -0.870       0.603
# ar.L1          0.1722      0.033      5.206      0.000       0.107       0.237
# ar.L2          0.4146      0.030     13.867      0.000       0.356       0.473
# ar.L3         -0.0019      0.034     -0.056      0.955      -0.068       0.064
# sigma2        24.2352      1.083     22.384      0.000      22.113      26.357
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.28
# Prob(Q):                              0.98   Prob(JB):                         0.32
# Heteroskedasticity (H):               0.94   Skew:                             0.12
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:14:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-a0c2b015-c5b2-4e4c-9e38-068471ecac49',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 5.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.1337266735426923,
#      'Error': 0.3756820479366545,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.1722232310726318,
#       'Error': 0.03308278513664766,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.4145533882849574,
#       'Error': 0.029895377266093374,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': -0.0018842906147060088,
#       'Error': 0.033602584178594457,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 24.235151745725823,
#      'Error': 1.0827136294524888,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
df = ARIMA.Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.197560
# 2  2.0  0.291144
# 3  3.0  0.298448

# %%
results = Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3045.217
# Date:                Sun, 19 Jun 2022   AIC                           6100.435
# Time:                        13:14:05   BIC                           6124.979
# Sample:                             0   HQIC                          6109.763
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4912      0.752      0.653      0.514      -0.982       1.965
# ar.L1          0.1973      0.031      6.418      0.000       0.137       0.258
# ar.L2          0.2907      0.029      9.962      0.000       0.234       0.348
# ar.L3          0.2983      0.030      9.970      0.000       0.240       0.357
# sigma2        25.6757      1.080     23.767      0.000      23.558      27.793
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.19   Jarque-Bera (JB):                 2.92
# Prob(Q):                              0.66   Prob(JB):                         0.23
# Heteroskedasticity (H):               1.37   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:14:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-d94b4c07-75e7-4e1b-a1a4-0a5c3fc79951',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 5.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.49120613674172625,
#      'Error': 0.7517788234895959,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.19734533387794267,
#       'Error': 0.030747956837578395,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.2907464507688392,
#       'Error': 0.02918423912867184,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.29825072071235564,
#       'Error': 0.029913988418110063,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 25.675709512741193,
#      'Error': 1.080299670045278,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
