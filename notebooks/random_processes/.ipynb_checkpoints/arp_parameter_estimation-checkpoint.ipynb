# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (ARIMA, Est)
from lib import (stack, fpoints, fcurve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
nsample = 1000

def comparison(φ_vals, σ, ylim, *params):
    title = "AR(p) Comparison Plot"
    labels = [f"φ={val}" for val in φ_vals] 
    scan = ARIMA.Source.AR.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    return scan

# %% [markdown]
# ## Simulations

# %%
σ = 1.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-7.5, 7.5], *params)

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example $\varphi = 0.2$

# %%
df = ARIMA.Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.186445

# %%
results = ARIMA.Est.AR.perform(ar[0], order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1415.103
# Date:                Mon, 20 Jun 2022   AIC                           2836.206
# Time:                        16:15:04   BIC                           2850.932
# Sample:                             0   HQIC                          2841.802
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0111      0.039      0.287      0.774      -0.065       0.087
# ar.L1          0.1866      0.031      6.003      0.000       0.126       0.247
# sigma2         0.9895      0.046     21.552      0.000       0.900       1.079
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 1.60
# Prob(Q):                              0.84   Prob(JB):                         0.45
# Heteroskedasticity (H):               0.94   Skew:                            -0.07
# Prob(H) (two-sided):                  0.58   Kurtosis:                         2.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 16:15:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-04952107-a11c-44a2-bdf5-7e1e961fe24f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 0.01110322916010119,
#      'Error': 0.03869084755088304,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.18656483442547805,
#       'Error': 0.0310777336535067,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 0.9895072586512672,
#      'Error': 0.04591249736725568,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example $\varphi = [0.2, 0.4]$

# %%
df = ARIMA.Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.270188
# 2  2.0  0.380601

# %%
results = ARIMA.Est.AR.perform(ar[1], order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1416.186
# Date:                Mon, 20 Jun 2022   AIC                           2840.373
# Time:                        16:15:04   BIC                           2860.008
# Sample:                             0   HQIC                          2847.835
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0440      0.090      0.486      0.627      -0.133       0.221
# ar.L1          0.2698      0.028      9.616      0.000       0.215       0.325
# ar.L2          0.3828      0.029     13.244      0.000       0.326       0.439
# sigma2         0.9912      0.044     22.394      0.000       0.904       1.078
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.25
# Prob(Q):                              0.96   Prob(JB):                         0.88
# Heteroskedasticity (H):               0.95   Skew:                            -0.04
# Prob(H) (two-sided):                  0.67   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 16:15:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-f1755f52-a46c-4e18-9588-f7d08e57c1d1',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 0.04398733878370821,
#      'Error': 0.09049826495374028,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.2698430813705792,
#       'Error': 0.028061444413131253,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3828132104297411,
#       'Error': 0.02890526240696696,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 0.9911674420594477,
#      'Error': 0.04426028889264101,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example $\varphi = [0.2, 0.3, 0.3]$

# %%
df = ARIMA.Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.154602
# 2  2.0  0.314914
# 3  3.0  0.269500

# %%
results = ARIMA.Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -1400.548
# Date:                Mon, 20 Jun 2022   AIC                           2811.097
# Time:                        16:15:04   BIC                           2835.641
# Sample:                             0   HQIC                          2820.425
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0796      0.120     -0.665      0.506      -0.314       0.155
# ar.L1          0.1529      0.032      4.821      0.000       0.091       0.215
# ar.L2          0.3162      0.030     10.622      0.000       0.258       0.375
# ar.L3          0.2709      0.031      8.662      0.000       0.210       0.332
# sigma2         0.9605      0.043     22.317      0.000       0.876       1.045
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.07
# Prob(Q):                              0.95   Prob(JB):                         0.35
# Heteroskedasticity (H):               0.92   Skew:                             0.11
# Prob(H) (two-sided):                  0.43   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 16:15:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-6019f8c1-da85-4fc0-805d-10a2a554dbea',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': -0.0795913043858855,
#      'Error': 0.11976447906972888,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.15288475966669768,
#       'Error': 0.03171152044198467,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3162418618026902,
#       'Error': 0.02977102102592555,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.27089813238885935,
#       'Error': 0.031273945909842955,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 0.9604786566685233,
#      'Error': 0.04303717691984296,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
σ = 5.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-20.0, 20.0], *params)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
df = ARIMA.Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.191407

# %%
results = ARIMA.Est.AR.perform(ar[0], order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -3025.888
# Date:                Mon, 20 Jun 2022   AIC                           6057.776
# Time:                        16:15:04   BIC                           6072.503
# Sample:                             0   HQIC                          6063.373
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3787      0.195      1.941      0.052      -0.004       0.761
# ar.L1          0.1913      0.030      6.379      0.000       0.133       0.250
# sigma2        24.7246      1.150     21.502      0.000      22.471      26.978
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                 2.78
# Prob(Q):                              0.67   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.98   Skew:                            -0.11
# Prob(H) (two-sided):                  0.87   Kurtosis:                         2.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 16:15:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-1d9c1420-53e5-4ff4-94ac-b6b0ce41842e',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 0.37872609488406056,
#      'Error': 0.19512917630690566,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.1913132557773813,
#       'Error': 0.029989553431952476,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 24.724573056691998,
#      'Error': 1.149867969463018,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
df = ARIMA.Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.211228
# 2  2.0  0.356862

# %%
results = ARIMA.Est.AR.perform(ar[1], order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -3017.580
# Date:                Mon, 20 Jun 2022   AIC                           6043.159
# Time:                        16:15:04   BIC                           6062.794
# Sample:                             0   HQIC                          6050.622
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0825      0.364      0.226      0.821      -0.632       0.797
# ar.L1          0.2111      0.031      6.900      0.000       0.151       0.271
# ar.L2          0.3589      0.029     12.258      0.000       0.302       0.416
# sigma2        24.3097      1.099     22.116      0.000      22.155      26.464
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 5.91
# Prob(Q):                              0.79   Prob(JB):                         0.05
# Heteroskedasticity (H):               1.00   Skew:                            -0.19
# Prob(H) (two-sided):                  0.99   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 16:15:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-e078fbb4-ef2b-4cb5-a5c9-696ebd7cd69b',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 5.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': 0.08246490335073998,
#      'Error': 0.36449687697629385,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.21105287381546606,
#       'Error': 0.030587666580198233,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3589144799956916,
#       'Error': 0.029280382498394104,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 24.309684282761694,
#      'Error': 1.099179259116401,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
df = ARIMA.Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.206096
# 2  2.0  0.328573
# 3  3.0  0.248298

# %%
results = ARIMA.Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3009.960
# Date:                Mon, 20 Jun 2022   AIC                           6029.920
# Time:                        16:15:05   BIC                           6054.464
# Sample:                             0   HQIC                          6039.248
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.9501      0.714     -1.330      0.183      -2.350       0.450
# ar.L1          0.2047      0.031      6.635      0.000       0.144       0.265
# ar.L2          0.3287      0.030     11.084      0.000       0.271       0.387
# ar.L3          0.2495      0.030      8.246      0.000       0.190       0.309
# sigma2        23.9314      1.063     22.514      0.000      21.848      26.015
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.85
# Prob(Q):                              0.98   Prob(JB):                         0.65
# Heteroskedasticity (H):               1.06   Skew:                             0.07
# Prob(H) (two-sided):                  0.59   Kurtosis:                         3.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 16:15:04',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-f2b55ee3-ebbf-4cf1-88cb-3a4f0124207e',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 5.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Estimate Type': <Est.AR: 'AR'>,
#     'Model Type': <EstModel.ARMA: 'ARMA'>,
#     'Const': {'Estimate': -0.950086078224385,
#      'Error': 0.7142286104684303,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.204667552621979,
#       'Error': 0.030848014607737968,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3287490868479029,
#       'Error': 0.0296610740547251,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.24950683104802318,
#       'Error': 0.030256998360381662,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 23.931397445542437,
#      'Error': 1.062974163684827,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
