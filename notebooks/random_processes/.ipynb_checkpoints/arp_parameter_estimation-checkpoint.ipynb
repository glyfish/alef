# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (Func, Source, Est)
from lib import (stack, fpoints, fcurve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
nsample = 1000

def comparison(φ_vals, σ, ylim, *params):
    title = "AR(p) Comparison Plot"
    labels = [f"φ={val}" for val in φ_vals] 
    scan = Source.AR.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    return scan

# %% [markdown]
# ## Simulations

# %%
σ = 1.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-7.5, 7.5], *params)

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example $\varphi = 0.2$

# %%
df = Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.157138

# %%
results = Est.AR.perform(ar[0], order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1432.837
# Date:                Sat, 04 Jun 2022   AIC                           2871.673
# Time:                        12:11:37   BIC                           2886.399
# Sample:                             0   HQIC                          2877.270
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0224      0.038     -0.589      0.556      -0.097       0.052
# ar.L1          0.1570      0.029      5.403      0.000       0.100       0.214
# sigma2         1.0252      0.044     23.206      0.000       0.939       1.112
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 1.09
# Prob(Q):                              0.70   Prob(JB):                         0.58
# Heteroskedasticity (H):               1.07   Skew:                            -0.02
# Prob(H) (two-sided):                  0.56   Kurtosis:                         3.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '04/06/2022 12:11:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-87064891-b3bc-4da9-b890-fcfef9c078cf',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.02235531172553965,
#      'Error': 0.03798276801942402,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.1570190384404674,
#       'Error': 0.029063118539775546,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 1.0252106834252457,
#      'Error': 0.04417820096933423,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example $\varphi = [0.2, 0.4]$

# %%
df = Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.172009
# 2  2.0  0.393446

# %%
results = Est.AR.perform(ar[1], order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1414.926
# Date:                Sat, 04 Jun 2022   AIC                           2837.852
# Time:                        12:11:37   BIC                           2857.487
# Sample:                             0   HQIC                          2845.314
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2323      0.073     -3.179      0.001      -0.376      -0.089
# ar.L1          0.1718      0.031      5.518      0.000       0.111       0.233
# ar.L2          0.3929      0.029     13.419      0.000       0.336       0.450
# sigma2         0.9888      0.044     22.223      0.000       0.902       1.076
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 4.86
# Prob(Q):                              0.81   Prob(JB):                         0.09
# Heteroskedasticity (H):               1.01   Skew:                             0.17
# Prob(H) (two-sided):                  0.96   Kurtosis:                         3.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '04/06/2022 12:11:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-6db68243-6478-4b68-a177-3a4a356b4900',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.2323388994792555,
#      'Error': 0.0730911053208814,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.17180082266484423,
#       'Error': 0.031136322187729878,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.39293393794983705,
#       'Error': 0.02928254774546827,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 0.9887888869542009,
#      'Error': 0.04449381604596843,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example $\varphi = [0.2, 0.3, 0.3]$

# %%
df = Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.199651
# 2  2.0  0.307160
# 3  3.0  0.289768

# %%
results = Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -1421.766
# Date:                Sat, 04 Jun 2022   AIC                           2853.532
# Time:                        12:11:37   BIC                           2878.076
# Sample:                             0   HQIC                          2862.860
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0814      0.155     -0.525      0.600      -0.385       0.223
# ar.L1          0.1996      0.030      6.719      0.000       0.141       0.258
# ar.L2          0.3062      0.030     10.267      0.000       0.248       0.365
# ar.L3          0.2899      0.031      9.248      0.000       0.228       0.351
# sigma2         1.0019      0.045     22.473      0.000       0.914       1.089
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.15
# Prob(Q):                              0.94   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.93   Skew:                            -0.03
# Prob(H) (two-sided):                  0.50   Kurtosis:                         3.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '04/06/2022 12:11:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-a2db5dde-9e7d-439d-a077-dc01579254d7',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.08139683315975306,
#      'Error': 0.1551289481748103,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.1996333945040929,
#       'Error': 0.029712275909931397,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3062285272964098,
#       'Error': 0.029826047638347168,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.2898573113162875,
#       'Error': 0.03134253458611067,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 1.0018753839892238,
#      'Error': 0.04458062296553606,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
σ = 5.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-20.0, 20.0], *params)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
df = Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.212627

# %%
results = Est.AR.perform(ar[0], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3061.037
# Date:                Sat, 04 Jun 2022   AIC                           6132.073
# Time:                        12:11:38   BIC                           6156.617
# Sample:                             0   HQIC                          6141.401
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1596      0.193      0.826      0.409      -0.219       0.538
# ar.L1          0.2269      0.033      6.868      0.000       0.162       0.292
# ar.L2         -0.0683      0.032     -2.147      0.032      -0.131      -0.006
# ar.L3         -0.0057      0.031     -0.183      0.855      -0.067       0.055
# sigma2        26.5233      1.249     21.241      0.000      24.076      28.971
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.88
# Prob(Q):                              1.00   Prob(JB):                         0.39
# Heteroskedasticity (H):               0.87   Skew:                             0.05
# Prob(H) (two-sided):                  0.21   Kurtosis:                         2.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '04/06/2022 12:11:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-c04bfead-1587-4705-9567-5bb11c4a8fe4',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.15959473065721447,
#      'Error': 0.19328065177207784,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.2268946626352421,
#       'Error': 0.033036431172901545,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': -0.06829087388932462,
#       'Error': 0.0318065917342339,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': -0.005677071820246013,
#       'Error': 0.031102366713136962,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 26.523259643959864,
#      'Error': 1.2486843653969093,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
df = Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.241544
# 2  2.0  0.348251

# %%
results = Est.AR.perform(ar[1], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3029.893
# Date:                Sat, 04 Jun 2022   AIC                           6069.785
# Time:                        12:11:38   BIC                           6094.329
# Sample:                             0   HQIC                          6079.113
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0345      0.395      0.088      0.930      -0.739       0.808
# ar.L1          0.2347      0.032      7.229      0.000       0.171       0.298
# ar.L2          0.3449      0.031     10.971      0.000       0.283       0.407
# ar.L3          0.0191      0.032      0.602      0.547      -0.043       0.081
# sigma2        24.9143      1.106     22.534      0.000      22.747      27.081
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.35
# Prob(Q):                              0.99   Prob(JB):                         0.84
# Heteroskedasticity (H):               0.94   Skew:                            -0.04
# Prob(H) (two-sided):                  0.60   Kurtosis:                         3.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '04/06/2022 12:11:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-b2d96cd9-90ec-49d7-96cf-ec083b60f0fb',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 5.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.03453922628218652,
#      'Error': 0.3945145905242995,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.23473649800390875,
#       'Error': 0.032469971135177175,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.344929769355482,
#       'Error': 0.03144116962225054,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.0191498928977959,
#       'Error': 0.031801084932724155,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 24.914301091472687,
#      'Error': 1.1056536091692548,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
df = Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.197709
# 2  2.0  0.335036
# 3  3.0  0.289526

# %%
results = Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3020.088
# Date:                Sat, 04 Jun 2022   AIC                           6050.175
# Time:                        12:11:38   BIC                           6074.719
# Sample:                             0   HQIC                          6059.503
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4496      0.884      0.509      0.611      -1.283       2.182
# ar.L1          0.1963      0.029      6.686      0.000       0.139       0.254
# ar.L2          0.3356      0.029     11.733      0.000       0.280       0.392
# ar.L3          0.2909      0.030      9.541      0.000       0.231       0.351
# sigma2        24.4164      1.159     21.063      0.000      22.144      26.688
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 4.00
# Prob(Q):                              0.81   Prob(JB):                         0.14
# Heteroskedasticity (H):               1.09   Skew:                             0.12
# Prob(H) (two-sided):                  0.44   Kurtosis:                         2.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '04/06/2022 12:11:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-ad1ea892-ad97-4800-be29-1df6b9d25b65',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 5.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.44957092217537425,
#      'Error': 0.8838766782798905,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.19627007498779617,
#       'Error': 0.02935442354726226,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.335646622048068,
#       'Error': 0.028605900161564203,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.29092263213906683,
#       'Error': 0.030491160292822294,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 24.416400552821315,
#      'Error': 1.159215031370257,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
