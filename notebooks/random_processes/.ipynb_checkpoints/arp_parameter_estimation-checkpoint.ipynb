# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (Func, Source, Est)
from lib import (stack, fpoints, fcurve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
nsample = 1000

def comparison(φ_vals, σ, ylim, *params):
    title = "AR(p) Comparison Plot"
    labels = [f"φ={val}" for val in φ_vals] 
    scan = Source.AR.create_parameter_scan(*params)
    stack(scan, ylim=ylim, title=title, labels=labels)
    return scan

# %% [markdown]
# ## Simulations

# %%
σ = 1.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-7.5, 7.5], *params)

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example $\varphi = 0.2$

# %%
df = Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.221115

# %%
results = Est.AR.perform(ar[0], order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1430.342
# Date:                Fri, 17 Jun 2022   AIC                           2866.684
# Time:                        12:22:10   BIC                           2881.410
# Sample:                             0   HQIC                          2872.280
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0657      0.041     -1.602      0.109      -0.146       0.015
# ar.L1          0.2211      0.029      7.553      0.000       0.164       0.279
# sigma2         1.0201      0.043     23.634      0.000       0.935       1.105
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 2.32
# Prob(Q):                              0.91   Prob(JB):                         0.31
# Heteroskedasticity (H):               1.15   Skew:                            -0.01
# Prob(H) (two-sided):                  0.20   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:22:10',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-f5cb8f90-9a4d-4940-9f73-b0f583b861c0',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.06566485744712326,
#      'Error': 0.04099347850865057,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.22112052442213193,
#       'Error': 0.029276092767189274,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 1.0200913537533902,
#      'Error': 0.04316214295102932,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example $\varphi = [0.2, 0.4]$

# %%
df = Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.156400
# 2  2.0  0.362292

# %%
results = Est.AR.perform(ar[1], order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1395.030
# Date:                Fri, 17 Jun 2022   AIC                           2798.061
# Time:                        12:22:11   BIC                           2817.696
# Sample:                             0   HQIC                          2805.523
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0153      0.064     -0.238      0.812      -0.141       0.111
# ar.L1          0.1563      0.032      4.959      0.000       0.095       0.218
# ar.L2          0.3618      0.029     12.517      0.000       0.305       0.418
# sigma2         0.9503      0.045     20.923      0.000       0.861       1.039
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 3.63
# Prob(Q):                              0.84   Prob(JB):                         0.16
# Heteroskedasticity (H):               1.18   Skew:                            -0.09
# Prob(H) (two-sided):                  0.13   Kurtosis:                         2.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:22:10',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-fb1ef919-ac0f-4d2a-a817-4f38ab702d1b',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.015291454965859617,
#      'Error': 0.06429463476256124,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.1563425655220838,
#       'Error': 0.0315268951685948,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.36177397529709704,
#       'Error': 0.028903329495409014,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 0.950324769616727,
#      'Error': 0.04542051370216444,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example $\varphi = [0.2, 0.3, 0.3]$

# %%
df = Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.223754
# 2  2.0  0.305520
# 3  3.0  0.268006

# %%
results = Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -1454.627
# Date:                Fri, 17 Jun 2022   AIC                           2919.255
# Time:                        12:22:11   BIC                           2943.799
# Sample:                             0   HQIC                          2928.583
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1526      0.160     -0.951      0.341      -0.467       0.162
# ar.L1          0.2233      0.030      7.412      0.000       0.164       0.282
# ar.L2          0.3044      0.029     10.389      0.000       0.247       0.362
# ar.L3          0.2686      0.031      8.640      0.000       0.208       0.330
# sigma2         1.0699      0.049     21.615      0.000       0.973       1.167
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.98   Prob(JB):                         0.71
# Heteroskedasticity (H):               1.11   Skew:                            -0.02
# Prob(H) (two-sided):                  0.32   Kurtosis:                         2.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:22:10',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-a6de8a3c-2c7b-4fd2-a6a5-537728632bad',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.15262878133888802,
#      'Error': 0.16042389228428008,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.22327776115547188,
#       'Error': 0.030124658965145344,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.30440915368087107,
#       'Error': 0.029301162346677075,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.26859568924570554,
#       'Error': 0.03108864628631905,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 1.0698906059879247,
#      'Error': 0.04949859367641951,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
σ = 5.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-20.0, 20.0], *params)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
df = Func.PACF.apply(ar[0], nlags=1)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.243726

# %%
results = Est.AR.perform(ar[0], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3036.995
# Date:                Fri, 17 Jun 2022   AIC                           6083.991
# Time:                        12:22:11   BIC                           6108.534
# Sample:                             0   HQIC                          6093.319
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1654      0.223      0.741      0.459      -0.272       0.603
# ar.L1          0.2307      0.033      7.039      0.000       0.166       0.295
# ar.L2          0.0574      0.033      1.734      0.083      -0.007       0.122
# ar.L3         -0.0007      0.033     -0.023      0.982      -0.065       0.063
# sigma2        25.2800      1.138     22.215      0.000      23.050      27.510
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.53
# Prob(Q):                              0.99   Prob(JB):                         0.47
# Heteroskedasticity (H):               1.27   Skew:                            -0.10
# Prob(H) (two-sided):                  0.03   Kurtosis:                         2.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:22:11',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-a401508b-f9af-4e54-9b09-944b33afff4e',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 0.16541460377394798,
#      'Error': 0.2233765793547736,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.23068602738416213,
#       'Error': 0.03277486685722886,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.05735957726370068,
#       'Error': 0.03307986523380989,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': -0.0007498997538313786,
#       'Error': 0.03270798447443221,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 25.280036075960737,
#      'Error': 1.1379539268245924,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
df = Func.PACF.apply(ar[1], nlags=2)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.169848
# 2  2.0  0.395851

# %%
results = Est.AR.perform(ar[1], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3038.037
# Date:                Fri, 17 Jun 2022   AIC                           6086.075
# Time:                        12:22:11   BIC                           6110.619
# Sample:                             0   HQIC                          6095.403
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1275      0.374     -0.341      0.733      -0.861       0.606
# ar.L1          0.1607      0.031      5.191      0.000       0.100       0.221
# ar.L2          0.3928      0.030     12.936      0.000       0.333       0.452
# ar.L3          0.0209      0.032      0.649      0.516      -0.042       0.084
# sigma2        25.3211      1.147     22.082      0.000      23.074      27.569
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.26
# Prob(Q):                              0.98   Prob(JB):                         0.88
# Heteroskedasticity (H):               0.90   Skew:                            -0.03
# Prob(H) (two-sided):                  0.34   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:22:11',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-873b2022-43ce-4bf4-8aff-d38cde5401d0',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 5.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': -0.12746252162765112,
#      'Error': 0.3740636783156536,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.16074963388860253,
#       'Error': 0.03096466104757421,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3928148559972312,
#       'Error': 0.030365624239949193,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.020945880553991814,
#       'Error': 0.03227927266397157,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 25.321096493631085,
#      'Error': 1.1466733655839665,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
df = Func.PACF.apply(ar[2], nlags=3)
df.head()
# Out:
#      τ      ρ(τ)
# 1  1.0  0.202694
# 2  2.0  0.317218
# 3  3.0  0.318665

# %%
results = Est.AR.perform(ar[2], order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3023.652
# Date:                Fri, 17 Jun 2022   AIC                           6057.304
# Time:                        12:22:11   BIC                           6081.848
# Sample:                             0   HQIC                          6066.632
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1978      0.978      1.225      0.220      -0.718       3.114
# ar.L1          0.2000      0.032      6.347      0.000       0.138       0.262
# ar.L2          0.3181      0.029     10.988      0.000       0.261       0.375
# ar.L3          0.3203      0.031     10.179      0.000       0.259       0.382
# sigma2        24.5867      1.041     23.627      0.000      22.547      26.626
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 2.24
# Prob(Q):                              0.91   Prob(JB):                         0.33
# Heteroskedasticity (H):               0.98   Skew:                            -0.00
# Prob(H) (two-sided):                  0.86   Kurtosis:                         3.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:22:11',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-6e06c2bb-9eb2-40eb-bf7c-506833f6f57b',
#  'SchemaIterations': None,
#  'AR': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 5.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <Est.AR: 'AR'>,
#     'Const': {'Estimate': 1.1978141002119722,
#      'Error': 0.9775606980874363,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.20000169484733854,
#       'Error': 0.0315104882358152,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3181446977593924,
#       'Error': 0.028954742461827058,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.3202567910131537,
#       'Error': 0.03146124895963975,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 24.586730569068838,
#      'Error': 1.0406155095201504,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}}}
