# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (DataType, DataSchema, DataFunc, SourceType, DataSource, perform_est, EstType)
from lib import (stack, FuncPlotType, fpoints, fcurve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
nsample = 1000

def comparison(φ_vals, σ, *params):
    title = "AR(p) Comparison Plot"
    labels = [f"φ={val}" for val in φ_vals] 
    scan = DataSource.create_parameter_scan(SourceType.AR, *params)
    stack(scan, ylim=[-7.5, 7.5], title=title, labels=labels, data_type=DataType.TIME_SERIES)
    return scan

# %% [markdown]
# ## Simulations

# %%
σ = 1.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, *params)
# Out:
# {'φ': [0.2], 'σ': 1.0, 'xmax': 1000} {'φ': [0.2, 0.4], 'σ': 1.0, 'xmax': 1000} {'φ': [0.2, 0.3, 0.3], 'σ': 1.0, 'xmax': 1000}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hc/xc94zvls2pq_pw366sdbqlhr0000gn/T/ipykernel_2237/4190512137.py in <module>
#       3 params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
#       4 print(*params)
# ----> 5 ar = comparison(φ_vals, σ, *params)
#
# /var/folders/hc/xc94zvls2pq_pw366sdbqlhr0000gn/T/ipykernel_2237/169704293.py in comparison(φ_vals, *params)
#       5     title = "AR(p) Comparison Plot"
#       6     labels = [f"φ={val}" for val in φ_vals]
# ----> 7     scan = DataSource.create_parameter_scan(SourceType.AR, *params)
#       8     stack(scan, ylim=[-7.5, 7.5], title=title, labels=labels, data_type=DataType.TIME_SERIES)
#       9     return scan
#
# ~/Develop/gly.fish/alef/lib/data/source.py in create_parameter_scan(source_type, *args)
#     112         dfs = []
#     113         for kwargs in args:
# --> 114             print(**kwargs)
#     115             dfs.append(create_data_source(source_type, **kwargs))
#     116         return dfs
#
# TypeError: print() argument after ** must be a mapping, not float

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example $\varphi = 0.2$

# %%
df = DataFunc.apply_func_type(ar[0], DataType.PACF, nlags=1)
df["PACF"][1]
# Out:
# 0.2206928520697859

# %%
results = perform_est(ar[0], EstType.AR, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1424.514
# Date:                Tue, 17 May 2022   AIC                           2855.027
# Time:                        19:59:38   BIC                           2869.754
# Sample:                             0   HQIC                          2860.624
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0154      0.041     -0.377      0.706      -0.095       0.065
# ar.L1          0.2206      0.032      6.883      0.000       0.158       0.283
# sigma2         1.0083      0.047     21.425      0.000       0.916       1.101
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 1.12
# Prob(Q):                              0.84   Prob(JB):                         0.57
# Heteroskedasticity (H):               0.94   Skew:                             0.01
# Prob(H) (two-sided):                  0.55   Kurtosis:                         2.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Type': <EstType.AR: 'AR'>,
#     'Const': [-0.015382044122423147, 0.04081417437784221],
#     'Parameters': [[0.220604830462788, 0.03205000818006875]],
#     'Sigma2': [1.0082808962091034, 0.04706125312246288]}},
#   'Tests': {}},
#  'Date': '17/05/2022 19:59:38',
#  'Name': 'AR(1)-Simulation-74a996ba-c20b-42e1-b691-623033847825',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(2) Example $\varphi = [0.2, 0.4]$

# %%
df = DataFunc.apply_func_type(ar[1], DataType.PACF, nlags=2)
df["PACF"][1:3]
# Out:
# 1    0.209187
# 2    0.445429
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[1], EstType.AR, order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1411.429
# Date:                Tue, 17 May 2022   AIC                           2830.857
# Time:                        19:59:38   BIC                           2850.492
# Sample:                             0   HQIC                          2838.320
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.091      0.025      0.980      -0.176       0.181
# ar.L1          0.2086      0.027      7.645      0.000       0.155       0.262
# ar.L2          0.4456      0.029     15.163      0.000       0.388       0.503
# sigma2         0.9817      0.043     22.970      0.000       0.898       1.065
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):                 3.60
# Prob(Q):                              0.58   Prob(JB):                         0.17
# Heteroskedasticity (H):               0.95   Skew:                            -0.12
# Prob(H) (two-sided):                  0.65   Kurtosis:                         3.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Type': <EstType.AR: 'AR'>,
#     'Const': [0.0022856424477676472, 0.09097403873721471],
#     'Parameters': [[0.20860272455876938, 0.027285781316706958],
#      [0.4456055555743883, 0.029387031154339983]],
#     'Sigma2': [0.9817201697506043, 0.04273844634500574]}},
#   'Tests': {}},
#  'Date': '17/05/2022 19:59:38',
#  'Name': 'AR(2)-Simulation-03cddb7a-f2fe-426c-98c3-63a650f2cf1a',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(3) Example $\varphi = [0.2, 0.3, 0.3]$

# %%
df = DataFunc.apply_func_type(ar[2], DataType.PACF, nlags=3)
df["PACF"][1:4]
# Out:
# 1    0.235685
# 2    0.237070
# 3    0.331045
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[2], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -1376.570
# Date:                Tue, 17 May 2022   AIC                           2763.139
# Time:                        19:59:39   BIC                           2787.683
# Sample:                             0   HQIC                          2772.467
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0522      0.153     -0.342      0.732      -0.351       0.247
# ar.L1          0.2360      0.031      7.709      0.000       0.176       0.296
# ar.L2          0.2343      0.030      7.703      0.000       0.175       0.294
# ar.L3          0.3344      0.031     10.795      0.000       0.274       0.395
# sigma2         0.9153      0.043     21.462      0.000       0.832       0.999
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                 1.23
# Prob(Q):                              0.74   Prob(JB):                         0.54
# Heteroskedasticity (H):               1.06   Skew:                             0.06
# Prob(H) (two-sided):                  0.58   Kurtosis:                         2.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': [-0.052224738797453256, 0.15265306343414928],
#     'Parameters': [[0.23604089720629862, 0.030617062346767573],
#      [0.23427230817547995, 0.030413130902026676],
#      [0.3343715469080647, 0.030974532056605487]],
#     'Sigma2': [0.9153312750565243, 0.04264824464573087]}},
#   'Tests': {}},
#  'Date': '17/05/2022 19:59:38',
#  'Name': 'AR(3)-Simulation-5fdda485-cf22-4333-bf54-d2d665a7d090',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
σ = 5.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = DataSource.create_parameter_scan(SourceType.AR, , *params)

# %%
stack(ar, ylim=[-20.0, 20.0], title=title, labels=labels, data_type=DataType.TIME_SERIES)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
df = DataFunc.apply_func_type(ar[0], DataType.PACF, nlags=1)
df["PACF"][1]
# Out:
# 0.19747214336134356

# %%
results = perform_est(ar[0], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3014.307
# Date:                Tue, 17 May 2022   AIC                           6038.613
# Time:                        19:59:39   BIC                           6063.157
# Sample:                             0   HQIC                          6047.941
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2745      0.195      1.409      0.159      -0.107       0.656
# ar.L1          0.2013      0.035      5.829      0.000       0.134       0.269
# ar.L2         -0.0221      0.032     -0.694      0.488      -0.084       0.040
# ar.L3          0.0228      0.029      0.786      0.432      -0.034       0.080
# sigma2        24.1595      1.080     22.360      0.000      22.042      26.277
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.01
# Prob(Q):                              0.97   Prob(JB):                         0.99
# Heteroskedasticity (H):               0.95   Skew:                             0.01
# Prob(H) (two-sided):                  0.65   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': [0.27451660348660956, 0.19483888499994725],
#     'Parameters': [[0.2012980134979857, 0.03453636478443806],
#      [-0.022083108651824536, 0.03183882721659679],
#      [0.022787144365170917, 0.028978062907570504]],
#     'Sigma2': [24.159515658691586, 1.0804877070683188]}},
#   'Tests': {}},
#  'Date': '17/05/2022 19:59:39',
#  'Name': 'AR(1)-Simulation-e5ce9b26-3fb3-4e01-b30e-cae73b237de6',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
df = DataFunc.apply_func_type(ar[1], DataType.PACF, nlags=2)
df["PACF"][1:3]
# Out:
# 1    0.178884
# 2    0.359413
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[1], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3039.644
# Date:                Tue, 17 May 2022   AIC                           6089.289
# Time:                        19:59:39   BIC                           6113.833
# Sample:                             0   HQIC                          6098.617
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3187      0.332     -0.959      0.338      -0.970       0.333
# ar.L1          0.1923      0.032      6.008      0.000       0.130       0.255
# ar.L2          0.3660      0.030     12.402      0.000       0.308       0.424
# ar.L3         -0.0384      0.032     -1.217      0.224      -0.100       0.023
# sigma2        25.4055      1.153     22.036      0.000      23.146      27.665
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.78
# Prob(Q):                              0.98   Prob(JB):                         0.68
# Heteroskedasticity (H):               1.12   Skew:                             0.06
# Prob(H) (two-sided):                  0.29   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 5.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': [-0.3186694776257299, 0.3322776309592558],
#     'Parameters': [[0.1922977394556019, 0.032006085720566964],
#      [0.36600922089153876, 0.029511127560095315],
#      [-0.03840928486684007, 0.031573076292889725]],
#     'Sigma2': [25.405462826907982, 1.1529061439093156]}},
#   'Tests': {}},
#  'Date': '17/05/2022 19:59:39',
#  'Name': 'AR(2)-Simulation-d0dab914-4432-4def-8ae9-5febc5926c86',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
df = DataFunc.apply_func_type(ar[2], DataType.PACF, nlags=3)
df["PACF"][1:4]
# Out:
# 1    0.209776
# 2    0.277488
# 3    0.307162
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[2], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3015.802
# Date:                Tue, 17 May 2022   AIC                           6041.604
# Time:                        19:59:39   BIC                           6066.148
# Sample:                             0   HQIC                          6050.932
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5708      0.755      0.756      0.450      -0.910       2.051
# ar.L1          0.2095      0.031      6.797      0.000       0.149       0.270
# ar.L2          0.2768      0.031      8.916      0.000       0.216       0.338
# ar.L3          0.3066      0.032      9.552      0.000       0.244       0.370
# sigma2        24.2097      1.011     23.950      0.000      22.228      26.191
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 3.83
# Prob(Q):                              1.00   Prob(JB):                         0.15
# Heteroskedasticity (H):               1.24   Skew:                             0.01
# Prob(H) (two-sided):                  0.05   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 5.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': [0.5707966917586396, 0.7554142917024277],
#     'Parameters': [[0.20951815500448473, 0.0308260634116509],
#      [0.2767988324049452, 0.031043545628668193],
#      [0.3066201507813283, 0.03210120803128455]],
#     'Sigma2': [24.209706008706437, 1.0108583338884192]}},
#   'Tests': {}},
#  'Date': '17/05/2022 19:59:39',
#  'Name': 'AR(3)-Simulation-898ac9af-4ad9-4aad-b552-e83d4f81d6aa',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}
