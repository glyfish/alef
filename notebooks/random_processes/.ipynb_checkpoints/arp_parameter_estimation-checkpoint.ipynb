# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (DataType, DataSchema, DataFunc, SourceType, DataSource, EstType)
from lib import (stack, fpoints, fcurve, perform_est)

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## Helpers

# %%
nsample = 1000

def comparison(φ_vals, σ, ylim, *params):
    title = "AR(p) Comparison Plot"
    labels = [f"φ={val}" for val in φ_vals] 
    scan = DataSource.create_parameter_scan(SourceType.AR, *params)
    stack(scan, ylim=ylim, title=title, labels=labels, data_type=DataType.TIME_SERIES)
    return scan

# %% [markdown]
# ## Simulations

# %%
σ = 1.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-7.5, 7.5], *params)

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example $\varphi = 0.2$

# %%
df = DataFunc.apply_func_type(ar[0], DataType.PACF, nlags=1)
df["PACF"][1]
# Out:
# 0.201704695013471

# %%
results = perform_est(ar[0], EstType.AR, order=1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(1, 0, 0)   Log Likelihood               -1427.283
# Date:                Tue, 24 May 2022   AIC                           2860.565
# Time:                        09:51:03   BIC                           2875.292
# Sample:                             0   HQIC                          2866.162
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0635      0.040      1.591      0.112      -0.015       0.142
# ar.L1          0.2019      0.032      6.344      0.000       0.140       0.264
# sigma2         1.0139      0.045     22.559      0.000       0.926       1.102
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.14
# Prob(Q):                              0.91   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.99   Skew:                             0.02
# Prob(H) (two-sided):                  0.95   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(1)': {'Type': <EstType.AR: 'AR'>,
#     'Const': {'Estimate': 0.06350312966441986,
#      'Error': 0.039917366518041474,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.20193848668736605,
#       'Error': 0.031833445352574694,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'}],
#     'Sigma2': {'Estimate': 1.013885293491339,
#      'Error': 0.044944178077391324,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}},
#  'Date': '24/05/2022 09:51:03',
#  'Name': 'AR(1)-Simulation-aa5cfba0-fd94-4762-aa12-1c79971b2ca2',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(2) Example $\varphi = [0.2, 0.4]$

# %%
df = DataFunc.apply_func_type(ar[1], DataType.PACF, nlags=2)
df["PACF"][1:3]
# Out:
# 1    0.192129
# 2    0.352469
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[1], EstType.AR, order=2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1417.791
# Date:                Tue, 24 May 2022   AIC                           2843.583
# Time:                        09:51:03   BIC                           2863.218
# Sample:                             0   HQIC                          2851.045
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0239      0.069      0.346      0.730      -0.112       0.160
# ar.L1          0.1920      0.029      6.652      0.000       0.135       0.249
# ar.L2          0.3519      0.028     12.718      0.000       0.298       0.406
# sigma2         0.9945      0.043     23.311      0.000       0.911       1.078
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 2.70
# Prob(Q):                              0.78   Prob(JB):                         0.26
# Heteroskedasticity (H):               1.02   Skew:                             0.08
# Prob(H) (two-sided):                  0.85   Kurtosis:                         3.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(2)': {'Type': <EstType.AR: 'AR'>,
#     'Const': {'Estimate': 0.02394642801294127,
#      'Error': 0.06926840865383603,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.19195438645880228,
#       'Error': 0.028857422898414264,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.3518933609838987,
#       'Error': 0.027668934058020324,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'}],
#     'Sigma2': {'Estimate': 0.994508328655933,
#      'Error': 0.042662250778786596,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}},
#  'Date': '24/05/2022 09:51:03',
#  'Name': 'AR(2)-Simulation-d3bc8325-c26d-4895-bb30-66afc149e7a2',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(3) Example $\varphi = [0.2, 0.3, 0.3]$

# %%
df = DataFunc.apply_func_type(ar[2], DataType.PACF, nlags=3)
df["PACF"][1:4]
# Out:
# 1    0.215763
# 2    0.262005
# 3    0.318365
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[2], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -1428.933
# Date:                Tue, 24 May 2022   AIC                           2867.867
# Time:                        09:51:03   BIC                           2892.410
# Sample:                             0   HQIC                          2877.194
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1528      0.158      0.970      0.332      -0.156       0.462
# ar.L1          0.2147      0.031      6.938      0.000       0.154       0.275
# ar.L2          0.2634      0.030      8.756      0.000       0.204       0.322
# ar.L3          0.3203      0.031     10.243      0.000       0.259       0.382
# sigma2         1.0163      0.046     22.059      0.000       0.926       1.107
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.33   Jarque-Bera (JB):                 0.41
# Prob(Q):                              0.56   Prob(JB):                         0.82
# Heteroskedasticity (H):               0.92   Skew:                             0.04
# Prob(H) (two-sided):                  0.45   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': {'Estimate': 0.1528059533852686,
#      'Error': 0.15760128410068933,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.21469756352147903,
#       'Error': 0.030944977892962352,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.263415781773572,
#       'Error': 0.030085128687595684,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.32031500475258656,
#       'Error': 0.03127226601402447,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 1.0163087516119371,
#      'Error': 0.0460713073412935,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}},
#  'Date': '24/05/2022 09:51:03',
#  'Name': 'AR(3)-Simulation-a5e722bd-354b-42e9-b120-8e8790ea1a8b',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
σ = 5.0
φ_vals = [[0.2], [0.2, 0.4], [0.2, 0.3, 0.3]]
params = [{"φ": φ, "σ": σ, "xmax": nsample} for φ in φ_vals]
ar = comparison(φ_vals, σ, [-20.0, 20.0], *params)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
df = DataFunc.apply_func_type(ar[0], DataType.PACF, nlags=1)
df["PACF"][1]
# Out:
# 0.19796051704057455

# %%
results = perform_est(ar[0], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3009.695
# Date:                Tue, 24 May 2022   AIC                           6029.390
# Time:                        09:51:03   BIC                           6053.934
# Sample:                             0   HQIC                          6038.718
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1252      0.187      0.669      0.504      -0.242       0.492
# ar.L1          0.1954      0.031      6.243      0.000       0.134       0.257
# ar.L2          0.0265      0.033      0.798      0.425      -0.039       0.092
# ar.L3         -0.0516      0.034     -1.510      0.131      -0.119       0.015
# sigma2        23.9372      1.066     22.447      0.000      21.847      26.027
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.44
# Prob(Q):                              0.92   Prob(JB):                         0.80
# Heteroskedasticity (H):               1.07   Skew:                            -0.05
# Prob(H) (two-sided):                  0.51   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[0].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2], 'σ': 5.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': {'Estimate': 0.1252350069151518,
#      'Error': 0.1873270532990391,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.19543149783865896,
#       'Error': 0.03130587337516357,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.026506490462242772,
#       'Error': 0.03321548351828307,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': -0.051580523517041274,
#       'Error': 0.03416547417575348,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 23.937154617390647,
#      'Error': 1.0663948153288825,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}},
#  'Date': '24/05/2022 09:51:03',
#  'Name': 'AR(1)-Simulation-bda6b9b1-7e43-4dc7-b129-8710ba6d4db3',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
df = DataFunc.apply_func_type(ar[1], DataType.PACF, nlags=2)
df["PACF"][1:3]
# Out:
# 1    0.205170
# 2    0.398474
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[1], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3089.582
# Date:                Tue, 24 May 2022   AIC                           6189.164
# Time:                        09:51:03   BIC                           6213.707
# Sample:                             0   HQIC                          6198.492
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0518      0.415      0.125      0.901      -0.762       0.866
# ar.L1          0.2122      0.030      7.045      0.000       0.153       0.271
# ar.L2          0.4040      0.031     13.146      0.000       0.344       0.464
# ar.L3         -0.0195      0.034     -0.577      0.564      -0.086       0.047
# sigma2        28.0660      1.256     22.338      0.000      25.603      30.529
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.01
# Prob(Q):                              0.97   Prob(JB):                         1.00
# Heteroskedasticity (H):               1.19   Skew:                            -0.00
# Prob(H) (two-sided):                  0.12   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[1].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.4], 'σ': 5.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': {'Estimate': 0.0517534877210336,
#      'Error': 0.41540965339982777,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.2121732173895818,
#       'Error': 0.030116263552386398,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.40399070258277314,
#       'Error': 0.030731132347706313,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': -0.019534172766303436,
#       'Error': 0.03383170688163567,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 28.065993621005326,
#      'Error': 1.2564226842100605,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}},
#  'Date': '24/05/2022 09:51:03',
#  'Name': 'AR(2)-Simulation-acaa8d5c-8d49-49a5-94bc-536c070f2e83',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
df = DataFunc.apply_func_type(ar[2], DataType.PACF, nlags=3)
df["PACF"][1:4]
# Out:
# 1    0.210249
# 2    0.296193
# 3    0.278001
# Name: PACF, dtype: float64

# %%
results = perform_est(ar[2], EstType.AR, order=3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   S(t)   No. Observations:                 1001
# Model:                 ARIMA(3, 0, 0)   Log Likelihood               -3041.010
# Date:                Tue, 24 May 2022   AIC                           6092.020
# Time:                        09:51:04   BIC                           6116.563
# Sample:                             0   HQIC                          6101.347
#                                - 1001
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5842      0.744     -0.785      0.433      -2.043       0.875
# ar.L1          0.2089      0.031      6.825      0.000       0.149       0.269
# ar.L2          0.2971      0.030      9.919      0.000       0.238       0.356
# ar.L3          0.2792      0.031      8.903      0.000       0.218       0.341
# sigma2        25.4621      1.134     22.456      0.000      23.240      27.684
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                 0.97
# Prob(Q):                              0.71   Prob(JB):                         0.61
# Heteroskedasticity (H):               1.01   Skew:                             0.07
# Prob(H) (two-sided):                  0.89   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
ar[2].attrs
# Out:
# {'S(t)': {'npts': 1001,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 5.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {'AR(3)': {'Type': <EstType.AR: 'AR'>,
#     'Const': {'Estimate': -0.5842068220662309,
#      'Error': 0.7443235481745836,
#      'Estimate Label': '$\\hat{\\mu^*}$',
#      'Error Label': '$\\sigma_{\\hat{\\mu^*}}$'},
#     'Parameters': [{'Estimate': 0.20889509668987924,
#       'Error': 0.030608526387256862,
#       'Estimate Label': '$\\hat{\\phi_{0}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{0}}}$'},
#      {'Estimate': 0.29710705747991195,
#       'Error': 0.029953351973246646,
#       'Estimate Label': '$\\hat{\\phi_{1}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{1}}}$'},
#      {'Estimate': 0.2791704025717268,
#       'Error': 0.03135811813347001,
#       'Estimate Label': '$\\hat{\\phi_{2}}$',
#       'Error Label': '$\\sigma_{$\\hat{\\phi_{2}}}$'}],
#     'Sigma2': {'Estimate': 25.462115966337198,
#      'Error': 1.1338519042382613,
#      'Estimate Label': '$\\hat{\\sigma^2}$',
#      'Error Label': '$\\sigma_{\\hat{\\sigma^2}}$'}}},
#   'Tests': {}},
#  'Date': '24/05/2022 09:51:03',
#  'Name': 'AR(3)-Simulation-2bf10bca-3ded-41c4-8f0b-e0458ee49558',
#  'SourceSchema': DataSchema(xcol=(Time), ycol=(S(t)), data_type=(DataType.TIME_SERIES))}
