# %% [markdown]
# # AR(p) Parameter Estimation
#
# The $\text{AR}(p)$ process is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^p \varphi_i X_{t-i} + \varepsilon_{t}
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}(0, \sigma^2)
# \end{align}
# $
#
# The Yule-Walker equations are relate the AR(p) parameters $\varphi_i$ to the autocorrelation function. If zero mean is</br>
# assumed it follows that,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t-n}]}{\text{E}[X_t^2]}
# \end{align}
# $
#
# The autocorrelation functions can be shown to have the following properties,
#
# $
# \begin{align}
# &\rho_0 = 1 \\
# &\rho_n \leq 1 \\
# &\rho_n = \rho_{-n}
# \end{align}
# $
#
# Define the matrices,
#
# $
# \begin{align}
# \hat{r} =
# \begin{bmatrix}
# \rho_1 \\
# \rho_2 \\
# \rho_3 \\
# \vdots \\
# \rho_{n-1} \\
# \rho_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{\Phi} =
# \begin{bmatrix}
# \varphi_1 \\
# \varphi_2 \\
# \varphi_3 \\
# \vdots \\
# \varphi_{n-1} \\
# \varphi_{n}
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \hat{R} =
# \begin{bmatrix}
# 1 & \rho_1 & \rho_2 & \cdots & \rho_{n-2} & \rho_{n-1} \\
# \rho_1 & 1 & \rho_1 & \cdots & \rho_{n-3} & \rho_{n-2} \\
# \rho_2 & \rho_1 & 1 & \cdots & \rho_{n-4} & \rho_{n-3} \\
# \vdots & \vdots  & \vdots & \ddots & \vdots & \vdots \\
# \rho_{n-2} & \rho_{n-3} & \rho_{n-4} & \cdots & 1 & \rho_1 \\
# \rho_{n-1} & \rho_{n-2} & \rho_{n-3} & \cdots & \rho_1 & 1 \\
# \end{bmatrix}
# \end{align}
# $
#
# Then the Yule-Walker equations are given by,
#
# $
# \begin{align}
# \hat{\Phi} = \hat{R}^{-1} \hat{r}
# \end{align}
# $
#
# ## Examples
#
# The Yule-Walker equations for $\text{AR}(1)$ is given by,
#
# $
# \begin{align}
# \varphi_1 = \rho_1
# \end{align}
# $
#
# This is the OLS solution.
#
# For $\text{AR}(2)$,
#
# $
# \begin{align}
# \varphi_1 &= \frac{\rho_1 - \rho_1 \rho_2}{1 - \rho_1^2} \\
# \varphi_2 &= \frac{\rho_2 - \rho_1^2}{1 - \rho_1^2}
# \end{align}
# $
#
# ## Stationaity
#
# Stationarity of an $\text{AR}(p)$ leads to convergence of the moments as $t \to \infty$. Recall the shift operator, $L$, defined by,
#
# $
# \begin{align}
# &L X_t = X_{t-1} \\
# &L^2 X_t = X_{t-2} \\
# &L^3 X_t = X_{t-3} \\
# &\vdots
# \end{align}
# $
#
# An $\text{AR}(p)$ process can be written as,
#
# $
# \begin{align}
# \varepsilon_t = (1 - \varphi L - \varphi^2 L^2 - \varphi^3 L^3 - \cdots - \varphi^p L^p) X_t
# \end{align}
# $
#
# The characteristic equation is obtained by replacing $L$ with the variable $z$ and setting the result to zero,
#
# $
# \begin{align}
# 1 - \varphi z - \varphi^2 z^2 - \varphi^3 z^3 - \cdots - \varphi^p z^p = 0
# \end{align}
# $
#
# Stationarity requires that $\lvert z \rvert > 1$. To see this consider $\text{AR}(1)$. The characteristic equation is,
#
# $
# \begin{align}
# 1 - \varphi z = 0
# \end{align}
# $
#
# The solution is $z = \frac{1}{\varphi}$. It follows that stationarity requires,
#
# $
# \begin{align}
# \lvert \varphi \rvert < 1
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import plots
from lib import config
from lib import arima
from lib import stats
from lib.plot_config import DataPlotType

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Simulations

# %%
nsample = 10000

φ1 = numpy.array([0.2])
ar1 = arima.arp(φ1, nsample)

φ2 = numpy.array([0.2, 0.4])
ar2 = arima.arp(φ2, nsample)

φ3 = numpy.array([0.2, 0.3, 0.3])
ar3 = arima.arp(φ3, nsample)

# %%
labels = [r"$\varphi=$"+f"{numpy.array2string(φ1, precision=2, separator=',')}",
          r"$\varphi=$"+f"{numpy.array2string(φ2, precision=2, separator=',')}",
          r"$\varphi=$"+f"{numpy.array2string(φ3, precision=2, separator=',')}"]
title = "AR(p) Comparison"
samples = [ar1[:500], ar2[:500], ar3[:500]]
plots.stack(samples, ylim=[-5.0, 5.0], title=title, labels=labels, plot_type=DataPlotType.TIME_SERIES)

# %% [markdown]
# ## Estimation of $\text{AR}(p)$ Parameters ($\sigma = 1$)
#
# $\text{AR}(p)$ parameters are estimated using two methods. The Yule-Walker ACF and `statsmodels.tsa.arima_model.ARMA`

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
arima.yw(ar1, 1)
# Out:
# array([0.18546313])

# %%
result = arima.ar_estimate(ar1, 1)
result.polynomial_ar, result.bse
# Out:
# (array([ 1.        , -0.18548338]),
#  array([0.01230004, 0.00980134, 0.01404348]))

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood              -14204.567
# Date:                Mon, 11 Apr 2022   AIC                          28415.135
# Time:                        10:11:13   BIC                          28436.766
# Sample:                             0   HQIC                         28422.457
#                               - 10000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0048      0.012     -0.388      0.698      -0.029       0.019
# ar.L1          0.1855      0.010     18.924      0.000       0.166       0.205
# sigma2         1.0031      0.014     71.426      0.000       0.976       1.031
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.92
# Prob(Q):                              0.98   Prob(JB):                         0.38
# Heteroskedasticity (H):               1.01   Skew:                            -0.03
# Prob(H) (two-sided):                  0.70   Kurtosis:                         3.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
arima.yw(ar2, 2)
# Out:
# array([0.19619826, 0.41088097])

# %%
result = arima.ar_estimate(ar2, 2)
result.polynomial_ar, result.bse
# Out:
# (array([ 1.        , -0.19623358, -0.41093997]),
#  array([0.02561821, 0.00918664, 0.00919698, 0.01475306]))

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10000
# Model:                 ARIMA(2, 0, 0)   Log Likelihood              -14251.153
# Date:                Mon, 11 Apr 2022   AIC                          28510.307
# Time:                        10:11:14   BIC                          28539.148
# Sample:                             0   HQIC                         28520.069
#                               - 10000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0037      0.026     -0.144      0.885      -0.054       0.047
# ar.L1          0.1962      0.009     21.361      0.000       0.178       0.214
# ar.L2          0.4109      0.009     44.682      0.000       0.393       0.429
# sigma2         1.0124      0.015     68.620      0.000       0.983       1.041
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 6.57
# Prob(Q):                              0.91   Prob(JB):                         0.04
# Heteroskedasticity (H):               1.00   Skew:                             0.02
# Prob(H) (two-sided):                  0.91   Kurtosis:                         2.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
arima.yw(ar3, 3)
# Out:
# array([0.20416666, 0.29271492, 0.30643324])

# %%
result = arima.ar_estimate(ar3, 3)
result.polynomial_ar, result.bse
# Out:
# (array([ 1.        , -0.20420718, -0.29268784, -0.30636045]),
#  array([0.05081938, 0.00945423, 0.00914611, 0.00949886, 0.01413174]))

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10000
# Model:                 ARIMA(3, 0, 0)   Log Likelihood              -14185.723
# Date:                Mon, 11 Apr 2022   AIC                          28381.447
# Time:                        10:11:14   BIC                          28417.498
# Sample:                             0   HQIC                         28393.650
#                               - 10000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0573      0.051     -1.128      0.259      -0.157       0.042
# ar.L1          0.2042      0.009     21.600      0.000       0.186       0.223
# ar.L2          0.2927      0.009     32.001      0.000       0.275       0.311
# ar.L3          0.3064      0.009     32.252      0.000       0.288       0.325
# sigma2         0.9992      0.014     70.705      0.000       0.971       1.027
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 0.03
# Prob(Q):                              0.86   Prob(JB):                         0.99
# Heteroskedasticity (H):               1.00   Skew:                            -0.00
# Prob(H) (two-sided):                  0.91   Kurtosis:                         3.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Simulations $\sigma = 5.0$

# %%
nsample = 10000
σ = 5.0

φ1 = numpy.array([0.2])
ar1 = arima.arp(φ1, nsample, σ)

φ2 = numpy.array([0.2, 0.4])
ar2 = arima.arp(φ2, nsample, σ)

φ3 = numpy.array([0.2, 0.3, 0.3])
ar3 = arima.arp(φ3, nsample, σ)

# %%
labels = [r"$\varphi=$"+f"{numpy.array2string(φ1, precision=2, separator=',')}",
          r"$\varphi=$"+f"{numpy.array2string(φ2, precision=2, separator=',')}",
          r"$\varphi=$"+f"{numpy.array2string(φ3, precision=2, separator=',')}"]
title = "AR(p) Comparison"
samples = [ar1[:500], ar2[:500], ar3[:500]]
plots.stack(samples, ylim=[-15.0, 15.0], title=title, labels=labels, plot_type=DataPlotType.TIME_SERIES)

# %% [markdown]
# ### AR(1) Example ($\varphi = 0.2$)

# %%
arima.yw(ar1, 1)
# Out:
# array([0.20056282])

# %%
result = arima.ar_estimate(ar1, 1)
result.polynomial_ar, result.bse
# Out:
# (array([ 1.        , -0.20057833]),
#  array([0.06290366, 0.00964477, 0.35850862]))

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10000
# Model:                 ARIMA(1, 0, 0)   Log Likelihood              -30339.674
# Date:                Mon, 11 Apr 2022   AIC                          60685.347
# Time:                        10:11:14   BIC                          60706.978
# Sample:                             0   HQIC                         60692.669
#                               - 10000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0208      0.063     -0.331      0.741      -0.144       0.102
# ar.L1          0.2006      0.010     20.797      0.000       0.182       0.219
# sigma2        25.2804      0.359     70.516      0.000      24.578      25.983
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 1.10
# Prob(Q):                              0.89   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.99   Skew:                            -0.03
# Prob(H) (two-sided):                  0.79   Kurtosis:                         2.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### AR(2) Example ($\varphi = [0.2, 0.4]$)

# %%
arima.yw(ar2, 2)
# Out:
# array([0.20466672, 0.38758435])

# %%
result = arima.ar_estimate(ar2, 2)
result.polynomial_ar, result.bse
# Out:
# (array([ 1.        , -0.20466958, -0.3876643 ]),
#  array([0.12265232, 0.00910504, 0.0091746 , 0.35185293]))

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10000
# Model:                 ARIMA(2, 0, 0)   Log Likelihood              -30283.750
# Date:                Mon, 11 Apr 2022   AIC                          60575.499
# Time:                        10:11:15   BIC                          60604.341
# Sample:                             0   HQIC                         60585.262
#                               - 10000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0923      0.123      0.752      0.452      -0.148       0.333
# ar.L1          0.2047      0.009     22.479      0.000       0.187       0.223
# ar.L2          0.3877      0.009     42.254      0.000       0.370       0.406
# sigma2        24.9999      0.352     71.052      0.000      24.310      25.690
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                 0.53
# Prob(Q):                              0.67   Prob(JB):                         0.77
# Heteroskedasticity (H):               1.05   Skew:                             0.01
# Prob(H) (two-sided):                  0.15   Kurtosis:                         3.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### AR(3) Example ($\varphi = [0.2, 0.3, 0.3]$)

# %%
arima.yw(ar3, 3)
# Out:
# array([0.21097547, 0.2795096 , 0.28937123])

# %%
result = arima.ar_estimate(ar3, 3)
result.polynomial_ar, result.bse
# Out:
# (array([ 1.        , -0.21068043, -0.27974236, -0.28972782]),
#  array([0.22717547, 0.00949249, 0.00924647, 0.00944233, 0.34830995]))

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10000
# Model:                 ARIMA(3, 0, 0)   Log Likelihood              -30270.666
# Date:                Mon, 11 Apr 2022   AIC                          60551.331
# Time:                        10:11:15   BIC                          60587.383
# Sample:                             0   HQIC                         60563.535
#                               - 10000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0770      0.227     -0.339      0.735      -0.522       0.368
# ar.L1          0.2107      0.009     22.194      0.000       0.192       0.229
# ar.L2          0.2797      0.009     30.254      0.000       0.262       0.298
# ar.L3          0.2897      0.009     30.684      0.000       0.271       0.308
# sigma2        24.9372      0.348     71.595      0.000      24.255      25.620
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 3.39
# Prob(Q):                              0.73   Prob(JB):                         0.18
# Heteroskedasticity (H):               0.97   Skew:                             0.04
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
