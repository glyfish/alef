# %% [markdown]
# # Fractional Brownian Motion Ensembles
#
# Ensemble simulations that scan H values are used to validate second order moment calculations.

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (FBM, Stats, Source)
from lib import (comparison, fpoints)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
Δt = 1.0
nlags = 30
npts = 1023
nsim = 500

def source_plot(H):
    title = f"Fractional Brownian Motion Ensemble, Ensemble Size={nsim}, H = {format(H, '1.1f')}"
    fbm = Source.FBM_FFT.create_ensemble(nsim, H=H, Δx=Δt, xmax=npts)
    comparison(fbm, title=title)
    return fbm

def mean_plots(dfs):
    mean = Stats.Func.MEAN.apply_to_ensemble(dfs)
    fbm_mean = FBM.Func.MEAN.apply(mean)
    fpoints(data=mean, func=fbm_mean)
    
def sd_plot(dfs, H):
    sd = Stats.Func.SD.apply_to_ensemble(dfs)
    fbm_sd = FBM.Func.SD.apply(sd, H=H)
    fpoints(data=sd, func=fbm_sd)
    
def ac_plot(dfs, H):
    fbm_noise = Stats.Func.DIFF.apply_to_list(dfs)
    ac = Stats.Func.ACF.apply_to_ensemble(fbm_noise, nlags=nlags)
    fbm_ac = FBM.Func.ACF.apply(ac, H=H, nplot=nlags)
    fpoints(data=ac, func=fbm_ac)

# %% [markdown]
# ## H=0.5 (Brownian Motion)

# %%
H=0.5
fbm = source_plot(H)

# %%
mean_plots(fbm)

# %%
sd_plot(fbm, H)

# %%
ac_plot(fbm, H)

# %% [markdown]
# ## H = 0.7

# %%
H=0.7
fbm = source_plot(H)

# %%
mean_plots(fbm)

# %%
sd_plot(fbm, H)

# %%
ac_plot(fbm, H)

# %% [markdown]
# ## H=0.3

# %%
H=0.3
fbm = source_plot(H)

# %%
mean_plots(fbm)

# %%
sd_plot(fbm, H)

# %%
ac_plot(fbm, H)
