# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test
#
# The Augmented Dickey-Fuller identifies stationarity in an autoregressive process. This is accomplished by testing for the presence</br>
# of nonstationarity, called the unit root. For example consider the $\text{AR}(1)$ process,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0,\sigma^2)$ and independent. If $\lvert \varphi \rvert < 1$ it can be shown that $X_t$ is stationary. The unit root,</br>
# $\lvert \varphi \rvert = 1$, is equivalent to brownian motion.
#
# ### Unit Root Form of $\text{AR}(1)$
#
# The unit root form of $\text{AR}(1)$ used in the analysis is constructed as follows. Subtracting $X_{t-1}$ from both sides of the expression</br>
# for $\text{AR}(1)$ gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Recall that the lag operator, $L$, is defined by, $L X_t = X_{t-1}, L^2 X_t = X_{t-2}, L^3 X_t = X_{t-3}, \ldots$. The difference operator is then given by</br>
# $\Delta = 1 - L$ and let $\delta = \varphi - 1$. It follows that
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Stationarity implies that, $\delta < 0$, while nonstationarity, unit root, implies $\delta = 0$. If follows that ADF tests is a lower tail significance test</br>
# with null hypothesis $\delta = 0$ and alternative hypothesis $\delta < 0$. Thus if the test fails $X_t$ is stationary.
#
# The lag polynomial is defined by,
#
# $
# \begin{align}
# \Phi^1(L) = 1 - \varphi L
# \end{align}
# $
#
# It follows that,
#
# $
# \begin{align}
# \Phi^1(L)X_t = \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^1(1) =  -\delta \\
# \Rightarrow& \delta = 1 - \varphi = 0
# \end{align}
# $
#
# ### Unit Root Form of $\text{AR}(q)$
#
# Following the procedure used for $\text{AR}(1)$ the unit root form of $\text{AR}(2)$ can be constructed. The $\text{AR}(2)$ lag polynomial is given by,
#
# $
# \begin{align}
# \Phi^2(L) = 1 - \varphi_1 L - \varphi_2 L^2
# \end{align}
# $
#
# If follows that,
#
# $
# \begin{align}
# &\Phi^2(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# To obtain the unit root form subtract $X_{t-1}$ from both sides of $\text{AR}(2)$ to obtain,
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# Next add and subtract $\varphi_3 X_{t-1}$ to obtain the final result,
#
# $
# \begin{align}
# & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t - \varphi_2 X_{t-1} \\
# \Rightarrow & \Delta X_t = \left( \varphi_2 + \varphi_1 - 1 \right) X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Let $\delta = \varphi_2 + \varphi_1 - 1$ to obtain the unit root form,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^2(1) = -\delta \\
# \Rightarrow& \delta = \varphi_1 + \varphi_2 - 1 = 0
# \end{align}
# $
#
# This procedure can be repeated for autoregressive processes of arbitrary order. $\text{AR}(q)$ is defined by
#
# $
# \begin{align}
# &\Phi^q(L) = 1 - \varphi_1 L + \varphi_2 L^2 - \cdots - \varphi_q L^q \\
# \Rightarrow & \Phi^q(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \cdots + + \varphi_q X_{t-q} + \varepsilon_t
# \end{align}
# $
#
# the unit root form is given by,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + C_1 \Delta X_{t-1} + C_2 \Delta X_{t-2} + \cdots + C_{q-1} \Delta X_{t- \left( q - 1 \right)} + \varepsilon_t
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# &\delta = \varphi_1 + \varphi_2 + \cdots + \varphi_q  -1\\
# &\Phi^q(1) = -\delta \\
# &C_i = -\sum_{j=i+1}^q \varphi_j
# \end{align}
# $
#
# ### $\text{AR}(1)$ Test Statistic
#
# The OLS estimate for the $\text{AR}(1)$ coefficient $\varphi$  is given by,
#
# $
# \begin{align}
# \hat{\varphi} = \frac{\sum_{t=1}^T X_t X_{t-1}}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# Using $X_t = \Delta X_t + X_{t-1}$ and $\hat{\delta} = \hat{\varphi} - 1$ gives,
#
# $
# \begin{align}
# \hat{\delta} = \frac{\sum_{t=1}^T X_{t-1} \varepsilon_t}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# From this expression it can be shown that,
#
# $
# \begin{align}
# &\text{E}(\hat{\delta}) = 0 \\
# &\text{Var}(\hat{\delta}) = \frac{\sigma}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# The test statistic is given by,
#
# $
# \begin{align}
# t = \frac{\hat{\delta}}{\sqrt{\text{Var}({\hat{\delta}})}}
# \end{align}
# $
#
# The distribution of $t$ is not a standard distribution but has a stochastic integral representation that must be evaluated numerically, namely,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\int_0^1 B(s) dB(s)}{\sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# where $B(s)$ is a Wiener process. The numerator integral can be evaluated to obtain,
#
# $
# \begin{align}
# \int_0^1 B(s) dB(s) = \frac{1}{2} \left[ B^2(1) - 1 \right]
# \end{align}
# $
#
# The final result is given by,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# The ADF test is a lower tailed hypothesis test. If successful $\delta = 0$ and the time series is brownian motion. If testing a time series for stationarity</br>, for $\delta$ as defined,
# $\delta > 0$ is desired so the test must fail.

# %% [markdown]
# ## Includes

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (ARIMA, ADF, Stats)
from lib import (curve, bar)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## ADF Distribution
#
# The probability distribution of the ADF test statistic,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# is computed by simulation.

# %%
nstep = 100
nsim = 10000
df = ADF.Source.DF.create(nstep=nstep, nsim=nsim, npts=nsim)
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:14',
#  'Type': <Source.DF: 'DF'>,
#  'Name': 'Dickey-Fuller-Simulation-c062f6b9-6be1-4bb1-92a7-c7c7aef51058',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}}}

# %%
pdf = Stats.Func.PDF_HIST.apply(df, xmin=-4.0, xmax=8.0)
bar(pdf)
pdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-c062f6b9-6be1-4bb1-92a7-c7c7aef51058',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '16/07/2022 15:17:14',
#  'Type': <Func.PDF_HIST: 'PDF_HIST'>,
#  'Name': 'PDF_HIST-e8534c43-b038-4723-a575-f5892db61388',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %%
cdf = Stats.Func.CDF_HIST.apply(pdf)
bar(cdf, loc="rup")
cdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-c062f6b9-6be1-4bb1-92a7-c7c7aef51058',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '16/07/2022 15:17:14',
#  'Type': <Func.CDF_HIST: 'CDF_HIST'>,
#  'Name': 'CDF_HIST-368b4de1-fb3a-4982-971c-70f5f84d3de6',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}},
#  'CDF_HIST': {'npts': 49,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'CDF',
#   'ylabel': '$P(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %% [markdown]
# ## ADF Test examples

# %%
nsample = 1000

# %% [markdown]
# ### $\text{AR}(1)$
#
# $\delta = 1 - \varphi$

# %%
φ = [0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, lw=1, title=title)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.8487      │
# ├────────────────┼───────────────┤
# │ pvalue         │   5.84721e-29 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:14',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-f0b07729-4b04-4ec7-9456-4124219d49f4',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -17.848658512883237, 'Label': '$t$'},
#       'PValue': {'Value': 5.847214501787739e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.848658512883237, 'Label': '$t$'},
#       'PValue': {'Value': 5.847214501787739e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.848658512883237, 'Label': '$t$'},
#       'PValue': {'Value': 5.847214501787739e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -28.4459 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   1      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 998      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:15',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-63c61392-2d49-4cdf-8871-4d5a87c43c2f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -28.445881260443553, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -28.445881260443553, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -28.445881260443553, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.86375  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.059418 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:15',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-3ffc1370-6d3a-47cb-ac23-74070541063a',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.8637545447803625, 'Label': '$t$'},
#       'PValue': {'Value': 0.059418010129530775, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.8637545447803625, 'Label': '$t$'},
#       'PValue': {'Value': 0.059418010129530775, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -1.8637545447803625, 'Label': '$t$'},
#       'PValue': {'Value': 0.059418010129530775, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.25796  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.191802 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:15',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-594d21f6-bffa-4aec-a384-c38e8b91f20d',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.2579578081853349, 'Label': '$t$'},
#       'PValue': {'Value': 0.1918015652346693, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2579578081853349, 'Label': '$t$'},
#       'PValue': {'Value': 0.1918015652346693, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2579578081853349, 'Label': '$t$'},
#       'PValue': {'Value': 0.1918015652346693, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-1.0]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -1597.17 │
# ├────────────────┼──────────┤
# │ pvalue         │     0    │
# ├────────────────┼──────────┤
# │ Lags           │     0    │
# ├────────────────┼──────────┤
# │ Number Obs     │   999    │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:16',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-6b367315-290f-4884-82aa-48ed3ae2abd7',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -1597.1661532189617, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -1597.1661532189617, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -1597.1661532189617, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$
#
# $\delta = 1 - \varphi_1 - \varphi_2$

# %%
φ = [0.2, 0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -13.9845      │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.84664e-25 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:16',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-0bf9bc6d-3f16-4c58-a55c-ef4e111f19bd',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -13.98448471243297, 'Label': '$t$'},
#       'PValue': {'Value': 2.8466366631864303e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.98448471243297, 'Label': '$t$'},
#       'PValue': {'Value': 2.8466366631864303e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.98448471243297, 'Label': '$t$'},
#       'PValue': {'Value': 2.8466366631864303e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.3, -0.4]
samples = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(samples, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -13.9845      │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.84664e-25 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:16',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-0bf9bc6d-3f16-4c58-a55c-ef4e111f19bd',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -13.98448471243297, 'Label': '$t$'},
#       'PValue': {'Value': 2.8466366631864303e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.98448471243297, 'Label': '$t$'},
#       'PValue': {'Value': 2.8466366631864303e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.98448471243297, 'Label': '$t$'},
#       'PValue': {'Value': 2.8466366631864303e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.8]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.12078  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.722986 │
# ├────────────────┼────────────┤
# │ Lags           │   4        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 995        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:17',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-ac02f464-f9c9-45a5-a02b-7f8f4ddb6d63',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.8], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': 0.12078028869743776, 'Label': '$t$'},
#       'PValue': {'Value': 0.7229861963178006, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567990698719729, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.12078028869743776, 'Label': '$t$'},
#       'PValue': {'Value': 0.7229861963178006, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.941273316956744, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.12078028869743776, 'Label': '$t$'},
#       'PValue': {'Value': 0.7229861963178006, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.616555780923252, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(3)$
#
# $\delta = 1 - \varphi_1 - \varphi_2 - \varphi_3$

# %%
φ = [0.2, 0.3, 0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.06699     │
# ├────────────────┼───────────────┤
# │ pvalue         │   4.28638e-11 │
# ├────────────────┼───────────────┤
# │ Lags           │   3           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 996           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:17',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-a2c91eaf-596b-41ac-aa0c-5853351b9d5f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -7.0669866155898795, 'Label': '$t$'},
#       'PValue': {'Value': 4.2863794237882766e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567988435307495, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.0669866155898795, 'Label': '$t$'},
#       'PValue': {'Value': 4.2863794237882766e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412730391965518, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.0669866155898795, 'Label': '$t$'},
#       'PValue': {'Value': 4.2863794237882766e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165560435054842, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, -0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -18.7725      │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.56467e-29 │
# ├────────────────┼───────────────┤
# │ Lags           │   2           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 997           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:18',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-42696d88-999d-402c-b713-938599076d6d',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, -0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -18.77245147347163, 'Label': '$t$'},
#       'PValue': {'Value': 3.5646726901827084e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.77245147347163, 'Label': '$t$'},
#       'PValue': {'Value': 3.5646726901827084e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.77245147347163, 'Label': '$t$'},
#       'PValue': {'Value': 3.5646726901827084e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, 0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.00183  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.287371 │
# ├────────────────┼────────────┤
# │ Lags           │   2        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 997        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:19',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-b5355b60-bb8f-4acd-9adc-aeb75d2fa28f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.5], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.0018337669476083, 'Label': '$t$'},
#       'PValue': {'Value': 0.2873712338884143, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.0018337669476083, 'Label': '$t$'},
#       'PValue': {'Value': 0.2873712338884143, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.0018337669476083, 'Label': '$t$'},
#       'PValue': {'Value': 0.2873712338884143, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### AR(1) with Offset

# %%
μ = 1.0
γ = 0.0

# %%
φ = [0.5]
df = ARIMA.Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.1395      │
# ├────────────────┼───────────────┤
# │ pvalue         │   7.06068e-30 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:19',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-c21e2bb5-397c-4272-846c-ada1473d8122',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -17.139494475981085, 'Label': '$t$'},
#       'PValue': {'Value': 7.060683577320413e-30, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.139494475981085, 'Label': '$t$'},
#       'PValue': {'Value': 7.060683577320413e-30, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.139494475981085, 'Label': '$t$'},
#       'PValue': {'Value': 7.060683577320413e-30, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = ARIMA.Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -8.1922      │
# ├────────────────┼───────────────┤
# │ pvalue         │   7.61471e-13 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:19',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-0863c483-4b5f-44c4-aabe-f0f56ed7e8f7',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -8.192199858448816, 'Label': '$t$'},
#       'PValue': {'Value': 7.614713658989192e-13, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -8.192199858448816, 'Label': '$t$'},
#       'PValue': {'Value': 7.614713658989192e-13, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -8.192199858448816, 'Label': '$t$'},
#       'PValue': {'Value': 7.614713658989192e-13, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.661781 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.856402 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:20',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-255b1270-a145-486f-a5c5-3de030cb9e6b',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.6617810942676006, 'Label': '$t$'},
#       'PValue': {'Value': 0.8564023399948331, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.6617810942676006, 'Label': '$t$'},
#       'PValue': {'Value': 0.8564023399948331, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.6617810942676006, 'Label': '$t$'},
#       'PValue': {'Value': 0.8564023399948331, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(1)$ with Drift

# %%
μ = 1.0
γ = 0.01

# %%
φ = [0.5]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -14.4049      │
# ├────────────────┼───────────────┤
# │ pvalue         │   5.10429e-22 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:20',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-f0264d99-087f-4587-bb32-c82a75299c57',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -14.404855300405853, 'Label': '$t$'},
#       'PValue': {'Value': 5.104290953158918e-22, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.9678699195021783, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.404855300405853, 'Label': '$t$'},
#       'PValue': {'Value': 5.104290953158918e-22, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414898316296852, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.404855300405853, 'Label': '$t$'},
#       'PValue': {'Value': 5.104290953158918e-22, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.129644744825171, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -49.8074 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:21',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-0a8609c6-38b3-4a8b-abac-a0f4988c16da',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[-0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -49.807375997223325, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -49.807375997223325, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -49.807375997223325, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.9]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.66941     │
# ├────────────────┼───────────────┤
# │ pvalue         │   4.14828e-10 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:21',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-0fca826e-90cf-4302-937b-bc1654f73af5',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[0.9]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -7.669414484152887, 'Label': '$t$'},
#       'PValue': {'Value': 4.148280443306379e-10, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.669414484152887, 'Label': '$t$'},
#       'PValue': {'Value': 4.148280443306379e-10, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.669414484152887, 'Label': '$t$'},
#       'PValue': {'Value': 4.148280443306379e-10, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.973829 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.947536 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:22',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-51b29989-a000-4671-932f-98d1cdcd45c3',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.9738294552821126, 'Label': '$t$'},
#       'PValue': {'Value': 0.9475358304074011, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.9738294552821126, 'Label': '$t$'},
#       'PValue': {'Value': 0.9475358304074011, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.9738294552821126, 'Label': '$t$'},
#       'PValue': {'Value': 0.9475358304074011, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$ with Drift

# %%
φ = [0.2, 0.3]
df = ARIMA.Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -11.3655      │
# ├────────────────┼───────────────┤
# │ pvalue         │   4.68143e-18 │
# ├────────────────┼───────────────┤
# │ Lags           │   3           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 996           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96789 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41491 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12965 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:22',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-DRIFT-Simulation-9abd9c1d-0f98-441b-b492-8d6bdb9a6e79',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -11.365521965481395, 'Label': '$t$'},
#       'PValue': {'Value': 4.681430799822399e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.9678882504050086, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -11.365521965481395, 'Label': '$t$'},
#       'PValue': {'Value': 4.681430799822399e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.41490718677544, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -11.365521965481395, 'Label': '$t$'},
#       'PValue': {'Value': 4.681430799822399e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296499631758756, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.4, 0.6]
df = ARIMA.Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.25085  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.899554 │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '16/07/2022 15:17:23',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-DRIFT-Simulation-1c6ffd21-7486-4fc2-849d-111c5e001e0c',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.4, 0.6], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.2508532078308654, 'Label': '$t$'},
#       'PValue': {'Value': 0.8995535827598111, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.9678699195021783, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2508532078308654, 'Label': '$t$'},
#       'PValue': {'Value': 0.8995535827598111, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414898316296852, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2508532078308654, 'Label': '$t$'},
#       'PValue': {'Value': 0.8995535827598111, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.129644744825171, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}
