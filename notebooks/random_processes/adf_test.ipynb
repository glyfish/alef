# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test
#
# The Augmented Dickey-Fuller identifies stationarity in an autoregressive process. This is accomplished by testing for the presence</br>
# of nonstationarity, called the unit root. For example consider the $\text{AR}(1)$ process,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0,\sigma^2)$ and independent. If $\lvert \varphi \rvert < 1$ it can be shown that $X_t$ is stationary. The unit root,</br>
# $\lvert \varphi \rvert = 1$, is equivalent to brownian motion.
#
# ### Unit Root Form of $\text{AR}(1)$
#
# The unit root form of $\text{AR}(1)$ used in the analysis is constructed as follows. Subtracting $X_{t-1}$ from both sides of the expression</br>
# for $\text{AR}(1)$ gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Recall that the lag operator, $L$, is defined by, $L X_t = X_{t-1}, L^2 X_t = X_{t-2}, L^3 X_t = X_{t-3}, \ldots$. The difference operator is then given by</br>
# $\Delta = 1 - L$ and let $\delta = \varphi - 1$. It follows that
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Stationarity implies that, $\delta < 0$, while nonstationarity, unit root, implies $\delta = 0$. If follows that ADF tests is a lower tail significance test</br>
# with null hypothesis $\delta = 0$ and alternative hypothesis $\delta < 0$. Thus if the test fails $X_t$ is stationary.
#
# The lag polynomial is defined by,
#
# $
# \begin{align}
# \Phi^1(L) = 1 - \varphi L
# \end{align}
# $
#
# It follows that,
#
# $
# \begin{align}
# \Phi^1(L)X_t = \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^1(1) =  -\delta \\
# \Rightarrow& \delta = 1 - \varphi = 0
# \end{align}
# $
#
# ### Unit Root Form of $\text{AR}(q)$
#
# Following the procedure used for $\text{AR}(1)$ the unit root form of $\text{AR}(2)$ can be constructed. The $\text{AR}(2)$ lag polynomial is given by,
#
# $
# \begin{align}
# \Phi^2(L) = 1 - \varphi_1 L - \varphi_2 L^2
# \end{align}
# $
#
# If follows that,
#
# $
# \begin{align}
# &\Phi^2(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# To obtain the unit root form subtract $X_{t-1}$ from both sides of $\text{AR}(2)$ to obtain,
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# Next add and subtract $\varphi_3 X_{t-1}$ to obtain the final result,
#
# $
# \begin{align}
# & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t - \varphi_2 X_{t-1} \\
# \Rightarrow & \Delta X_t = \left( \varphi_2 + \varphi_1 - 1 \right) X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Let $\delta = \varphi_2 + \varphi_1 - 1$ to obtain the unit root form,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^2(1) = -\delta \\
# \Rightarrow& \delta = \varphi_1 + \varphi_2 - 1 = 0
# \end{align}
# $
#
# This procedure can be repeated for autoregressive processes of arbitrary order. $\text{AR}(q)$ is defined by
#
# $
# \begin{align}
# &\Phi^q(L) = 1 - \varphi_1 L + \varphi_2 L^2 - \cdots - \varphi_q L^q \\
# \Rightarrow & \Phi^q(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \cdots + + \varphi_q X_{t-q} + \varepsilon_t
# \end{align}
# $
#
# the unit root form is given by,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + C_1 \Delta X_{t-1} + C_2 \Delta X_{t-2} + \cdots + C_{q-1} \Delta X_{t- \left( q - 1 \right)} + \varepsilon_t
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# &\delta = \varphi_1 + \varphi_2 + \cdots + \varphi_q  -1\\
# &\Phi^q(1) = -\delta \\
# &C_i = -\sum_{j=i+1}^q \varphi_j
# \end{align}
# $
#
# ### $\text{AR}(1)$ Test Statistic
#
# The OLS estimate for the $\text{AR}(1)$ coefficient $\varphi$  is given by,
#
# $
# \begin{align}
# \hat{\varphi} = \frac{\sum_{t=1}^T X_t X_{t-1}}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# Using $X_t = \Delta X_t + X_{t-1}$ and $\hat{\delta} = \hat{\varphi} - 1$ gives,
#
# $
# \begin{align}
# \hat{\delta} = \frac{\sum_{t=1}^T X_{t-1} \varepsilon_t}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# From this expression it can be shown that,
#
# $
# \begin{align}
# &\text{E}(\hat{\delta}) = 0 \\
# &\text{Var}(\hat{\delta}) = \frac{\sigma}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# The test statistic is given by,
#
# $
# \begin{align}
# t = \frac{\hat{\delta}}{\sqrt{\text{Var}({\hat{\delta}})}}
# \end{align}
# $
#
# The distribution of $t$ is not a standard distribution but has a stochastic integral representation that must be evaluated numerically, namely,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\int_0^1 B(s) dB(s)}{\sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# where $B(s)$ is a Wiener process. The numerator integral can be evaluated to obtain,
#
# $
# \begin{align}
# \int_0^1 B(s) dB(s) = \frac{1}{2} \left[ B^2(1) - 1 \right]
# \end{align}
# $
#
# The final result is given by,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# The ADF test is a lower tailed hypothesis test. If successful $\delta = 0$ and the time series is brownian motion. If testing a time series for stationarity</br>, for $\delta$ as defined,
# $\delta > 0$ is desired so the test must fail.

# %% [markdown]
# ## Includes

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (Source, Test, Func)
from lib import (curve, bar)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## ADF Distribution
#
# The probability distribution of the ADF test statistic,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# is computed by simulation.

# %%
nstep = 100
nsim = 10000
df = Source.DF.create(nstep=nstep, nsim=nsim, npts=nsim)
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:36',
#  'Type': <Source.DF: 'DF'>,
#  'Name': 'Dickey-Fuller-Simulation-23a6c67c-ef9b-4ad3-8797-051be48e14a8',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}}}

# %%
pdf = Func.PDF_HIST.apply(df, xmin=-4.0, xmax=8.0)
bar(pdf)
pdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-23a6c67c-ef9b-4ad3-8797-051be48e14a8',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '17/06/2022 12:38:36',
#  'Type': <Func.PDF_HIST: 'PDF_HIST'>,
#  'Name': 'PDF_HIST-a281a2a0-1208-47c7-81b2-e854627e12ab',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %%
cdf = Func.CDF_HIST.apply(pdf)
bar(cdf, loc="rup")
cdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-23a6c67c-ef9b-4ad3-8797-051be48e14a8',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '17/06/2022 12:38:36',
#  'Type': <Func.CDF_HIST: 'CDF_HIST'>,
#  'Name': 'CDF_HIST-512a3caf-aae5-400e-8211-d2526ea42733',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}},
#  'CDF_HIST': {'npts': 49,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'CDF',
#   'ylabel': '$P(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %% [markdown]
# ## ADF Test examples

# %%
nsample = 1000

# %% [markdown]
# ### $\text{AR}(1)$
#
# $\delta = 1 - \varphi$

# %%
φ = [0.5]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, lw=1, title=title)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════╕
# │ Test Statistic │ -19.131 │
# ├────────────────┼─────────┤
# │ pvalue         │   0     │
# ├────────────────┼─────────┤
# │ Lags           │   0     │
# ├────────────────┼─────────┤
# │ Number Obs     │ 999     │
# ╘════════════════╧═════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-36e743b7-cbbd-40e7-9955-d84002d35b9f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -19.131008723251085, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.131008723251085, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.131008723251085, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -22.8811 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   2      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 997      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-71668799-ce27-4c32-87e4-5e1609248d8b',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -22.881148534390793, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -22.881148534390793, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -22.881148534390793, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -2.42338   │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.0148368 │
# ├────────────────┼─────────────┤
# │ Lags           │   3         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 996         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:37',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-711a9bd0-b4ed-4b1c-a930-3f331106804a',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -2.4233827035749553, 'Label': '$t$'},
#       'PValue': {'Value': 0.014836761303939553, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567988435307495, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -2.4233827035749553, 'Label': '$t$'},
#       'PValue': {'Value': 0.014836761303939553, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412730391965518, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -2.4233827035749553, 'Label': '$t$'},
#       'PValue': {'Value': 0.014836761303939553, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165560435054842, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.20787  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.208025 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:38',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-b46c8232-84d1-4fea-b41b-b2f5f262d198',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.2078713140703357, 'Label': '$t$'},
#       'PValue': {'Value': 0.2080250526874703, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2078713140703357, 'Label': '$t$'},
#       'PValue': {'Value': 0.2080250526874703, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2078713140703357, 'Label': '$t$'},
#       'PValue': {'Value': 0.2080250526874703, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-1.0]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -576.693 │
# ├────────────────┼──────────┤
# │ pvalue         │    0     │
# ├────────────────┼──────────┤
# │ Lags           │    0     │
# ├────────────────┼──────────┤
# │ Number Obs     │  999     │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:38',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-6bc5d86c-ba24-4ef1-9fe6-fc7bdeebb51e',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -576.6931038617511, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -576.6931038617511, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -576.6931038617511, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$
#
# $\delta = 1 - \varphi_1 - \varphi_2$

# %%
φ = [0.2, 0.3]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -14.2373      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.21959e-25 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:38',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-37f37ca3-ff70-47e5-86e3-e6bb1ce915a7',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -14.237260915778021, 'Label': '$t$'},
#       'PValue': {'Value': 1.2195934556828741e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.237260915778021, 'Label': '$t$'},
#       'PValue': {'Value': 1.2195934556828741e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.237260915778021, 'Label': '$t$'},
#       'PValue': {'Value': 1.2195934556828741e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.3, -0.4]
samples = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(samples, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -14.2373      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.21959e-25 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:38',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-37f37ca3-ff70-47e5-86e3-e6bb1ce915a7',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -14.237260915778021, 'Label': '$t$'},
#       'PValue': {'Value': 1.2195934556828741e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.237260915778021, 'Label': '$t$'},
#       'PValue': {'Value': 1.2195934556828741e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.237260915778021, 'Label': '$t$'},
#       'PValue': {'Value': 1.2195934556828741e-25, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.8]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.657984 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.85868  │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:39',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-5089d56c-d865-4856-b06a-ff75fb000ae2',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.8], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': 0.6579843907946291, 'Label': '$t$'},
#       'PValue': {'Value': 0.8586801282026351, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.6579843907946291, 'Label': '$t$'},
#       'PValue': {'Value': 0.8586801282026351, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.6579843907946291, 'Label': '$t$'},
#       'PValue': {'Value': 0.8586801282026351, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(3)$
#
# $\delta = 1 - \varphi_1 - \varphi_2 - \varphi_3$

# %%
φ = [0.2, 0.3, 0.3]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.07074     │
# ├────────────────┼───────────────┤
# │ pvalue         │   4.20399e-11 │
# ├────────────────┼───────────────┤
# │ Lags           │   2           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 997           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:39',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-b8b2000c-04fb-483f-bb9b-bea8a3fa1a4f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -7.0707421093937155, 'Label': '$t$'},
#       'PValue': {'Value': 4.203993480802823e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.0707421093937155, 'Label': '$t$'},
#       'PValue': {'Value': 4.203993480802823e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.0707421093937155, 'Label': '$t$'},
#       'PValue': {'Value': 4.203993480802823e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, -0.3]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════╕
# │ Test Statistic │ -19.165 │
# ├────────────────┼─────────┤
# │ pvalue         │   0     │
# ├────────────────┼─────────┤
# │ Lags           │   2     │
# ├────────────────┼─────────┤
# │ Number Obs     │ 997     │
# ╘════════════════╧═════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:40',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-596ae397-b69a-440b-a04b-9da3a9b25f5b',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, -0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -19.1650299651186, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.1650299651186, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.1650299651186, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, 0.5]
df = Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result=Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.239757 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.599059 │
# ├────────────────┼────────────┤
# │ Lags           │   2        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 997        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:40',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-856b5203-5500-46bf-b06b-df68903af6db',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.5], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.23975739485974748, 'Label': '$t$'},
#       'PValue': {'Value': 0.5990586085080097, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.23975739485974748, 'Label': '$t$'},
#       'PValue': {'Value': 0.5990586085080097, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.23975739485974748, 'Label': '$t$'},
#       'PValue': {'Value': 0.5990586085080097, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### AR(1) with Offset

# %%
μ = 1.0
γ = 0.0

# %%
φ = [0.5]
df = Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -14.2022      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.78006e-26 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43692 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:40',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-87a5d0bd-cb26-44cc-b3d3-6c6ccf793062',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -14.202166538814105, 'Label': '$t$'},
#       'PValue': {'Value': 1.7800558926743344e-26, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369193380671, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.202166538814105, 'Label': '$t$'},
#       'PValue': {'Value': 1.7800558926743344e-26, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864440383452517, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.202166538814105, 'Label': '$t$'},
#       'PValue': {'Value': 1.7800558926743344e-26, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.56831430323573, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.36712     │
# ├────────────────┼───────────────┤
# │ pvalue         │   9.17443e-11 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:41',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-51a4a61c-00f9-439b-8c31-fe94f2f6ee14',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -7.367115708553247, 'Label': '$t$'},
#       'PValue': {'Value': 9.174425819529531e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.367115708553247, 'Label': '$t$'},
#       'PValue': {'Value': 9.174425819529531e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.367115708553247, 'Label': '$t$'},
#       'PValue': {'Value': 9.174425819529531e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = Source.AR_OFFSET.create(φ=[φ], μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.423226 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.906148 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:41',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-8f1b899f-c3c6-46da-92cf-1ff55ba1d891',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.42322564696800014, 'Label': '$t$'},
#       'PValue': {'Value': 0.9061481072098543, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.42322564696800014, 'Label': '$t$'},
#       'PValue': {'Value': 0.9061481072098543, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.42322564696800014, 'Label': '$t$'},
#       'PValue': {'Value': 0.9061481072098543, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(1)$ with Drift

# %%
μ = 1.0
γ = 0.01

# %%
φ = [0.5]
df = Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -18.4166 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:41',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-75abb719-ed58-4c3e-860d-756d8fda8a14',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -18.416582346462533, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.416582346462533, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.416582346462533, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -10.5682      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.55148e-16 │
# ├────────────────┼───────────────┤
# │ Lags           │   6           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 993           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96792 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41492 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12966 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:42',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-479c43b8-2998-4cd6-b5a0-3b8070bd61e2',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[-0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -10.568188820738746, 'Label': '$t$'},
#       'PValue': {'Value': 1.5514759337482942e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967915885651428, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -10.568188820738746, 'Label': '$t$'},
#       'PValue': {'Value': 1.5514759337482942e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414920559631273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -10.568188820738746, 'Label': '$t$'},
#       'PValue': {'Value': 1.5514759337482942e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296578301765576, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.9]

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -10.5682      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.55148e-16 │
# ├────────────────┼───────────────┤
# │ Lags           │   6           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 993           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96792 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41492 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12966 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:42',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-479c43b8-2998-4cd6-b5a0-3b8070bd61e2',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[-0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -10.568188820738746, 'Label': '$t$'},
#       'PValue': {'Value': 1.5514759337482942e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967915885651428, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -10.568188820738746, 'Label': '$t$'},
#       'PValue': {'Value': 1.5514759337482942e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414920559631273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -10.568188820738746, 'Label': '$t$'},
#       'PValue': {'Value': 1.5514759337482942e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296578301765576, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.18935  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.991716 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:42',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-181a7c7e-ff4a-4c06-a170-34094174ac40',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.18934975834898607, 'Label': '$t$'},
#       'PValue': {'Value': 0.9917160508700309, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.18934975834898607, 'Label': '$t$'},
#       'PValue': {'Value': 0.9917160508700309, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.18934975834898607, 'Label': '$t$'},
#       'PValue': {'Value': 0.9917160508700309, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$ with Drift

# %%
φ = [0.2, 0.3]
df = Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -14.1229      │
# ├────────────────┼───────────────┤
# │ pvalue         │   8.56185e-22 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:43',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-Simulation-b84bdbe8-83d5-42d8-bf40-5908a84e3ff5',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -14.12286818814271, 'Label': '$t$'},
#       'PValue': {'Value': 8.56184738799149e-22, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.9678699195021783, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.12286818814271, 'Label': '$t$'},
#       'PValue': {'Value': 8.56184738799149e-22, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414898316296852, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -14.12286818814271, 'Label': '$t$'},
#       'PValue': {'Value': 8.56184738799149e-22, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.129644744825171, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.4, 0.6]
df = Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.59647  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.793812 │
# ├────────────────┼────────────┤
# │ Lags           │   5        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 994        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96791 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41492 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12966 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '17/06/2022 12:38:43',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-Simulation-61d887f4-6a9f-4f14-9426-4aa22ffda931',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.4, 0.6], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.5964701728897794, 'Label': '$t$'},
#       'PValue': {'Value': 0.7938115404868277, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967906655308904, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.5964701728897794, 'Label': '$t$'},
#       'PValue': {'Value': 0.7938115404868277, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414916093024836, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.5964701728897794, 'Label': '$t$'},
#       'PValue': {'Value': 0.7938115404868277, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296552025585007, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}
