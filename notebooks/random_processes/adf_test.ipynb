# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test
#
# The Augmented Dickey-Fuller identifies stationarity in an autoregressive process. This is accomplished by testing for the presence</br>
# of nonstationarity, called the unit root. For example consider the $\text{AR}(1)$ process,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0,\sigma^2)$ and independent. If $\lvert \varphi \rvert < 1$ it can be shown that $X_t$ is stationary. The unit root,</br>
# $\lvert \varphi \rvert = 1$, is equivalent to brownian motion.
#
# ### Unit Root Form of $\text{AR}(1)$
#
# The unit root form of $\text{AR}(1)$ used in the analysis is constructed as follows. Subtracting $X_{t-1}$ from both sides of the expression</br>
# for $\text{AR}(1)$ gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Recall that the lag operator, $L$, is defined by, $L X_t = X_{t-1}, L^2 X_t = X_{t-2}, L^3 X_t = X_{t-3}, \ldots$. The difference operator is then given by</br>
# $\Delta = 1 - L$ and let $\delta = \varphi - 1$. It follows that
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Stationarity implies that, $\delta < 0$, while nonstationarity, unit root, implies $\delta = 0$. If follows that ADF tests is a lower tail significance test</br>
# with null hypothesis $\delta = 0$ and alternative hypothesis $\delta < 0$. Thus if the test fails $X_t$ is stationary.
#
# The lag polynomial is defined by,
#
# $
# \begin{align}
# \Phi^1(L) = 1 - \varphi L
# \end{align}
# $
#
# It follows that,
#
# $
# \begin{align}
# \Phi^1(L)X_t = \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^1(1) =  -\delta \\
# \Rightarrow& \delta = 1 - \varphi = 0
# \end{align}
# $
#
# ### Unit Root Form of $\text{AR}(q)$
#
# Following the procedure used for $\text{AR}(1)$ the unit root form of $\text{AR}(2)$ can be constructed. The $\text{AR}(2)$ lag polynomial is given by,
#
# $
# \begin{align}
# \Phi^2(L) = 1 - \varphi_1 L - \varphi_2 L^2
# \end{align}
# $
#
# If follows that,
#
# $
# \begin{align}
# &\Phi^2(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# To obtain the unit root form subtract $X_{t-1}$ from both sides of $\text{AR}(2)$ to obtain,
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# Next add and subtract $\varphi_3 X_{t-1}$ to obtain the final result,
#
# $
# \begin{align}
# & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t - \varphi_2 X_{t-1} \\
# \Rightarrow & \Delta X_t = \left( \varphi_2 + \varphi_1 - 1 \right) X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Let $\delta = \varphi_2 + \varphi_1 - 1$ to obtain the unit root form,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^2(1) = -\delta \\
# \Rightarrow& \delta = \varphi_1 + \varphi_2 - 1 = 0
# \end{align}
# $
#
# This procedure can be repeated for autoregressive processes of arbitrary order. $\text{AR}(q)$ is defined by
#
# $
# \begin{align}
# &\Phi^q(L) = 1 - \varphi_1 L + \varphi_2 L^2 - \cdots - \varphi_q L^q \\
# \Rightarrow & \Phi^q(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \cdots + + \varphi_q X_{t-q} + \varepsilon_t
# \end{align}
# $
#
# the unit root form is given by,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + C_1 \Delta X_{t-1} + C_2 \Delta X_{t-2} + \cdots + C_{q-1} \Delta X_{t- \left( q - 1 \right)} + \varepsilon_t
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# &\delta = \varphi_1 + \varphi_2 + \cdots + \varphi_q  -1\\
# &\Phi^q(1) = -\delta \\
# &C_i = -\sum_{j=i+1}^q \varphi_j
# \end{align}
# $
#
# ### $\text{AR}(1)$ Test Statistic
#
# The OLS estimate for the $\text{AR}(1)$ coefficient $\varphi$  is given by,
#
# $
# \begin{align}
# \hat{\varphi} = \frac{\sum_{t=1}^T X_t X_{t-1}}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# Using $X_t = \Delta X_t + X_{t-1}$ and $\hat{\delta} = \hat{\varphi} - 1$ gives,
#
# $
# \begin{align}
# \hat{\delta} = \frac{\sum_{t=1}^T X_{t-1} \varepsilon_t}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# From this expression it can be shown that,
#
# $
# \begin{align}
# &\text{E}(\hat{\delta}) = 0 \\
# &\text{Var}(\hat{\delta}) = \frac{\sigma}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# The test statistic is given by,
#
# $
# \begin{align}
# t = \frac{\hat{\delta}}{\sqrt{\text{Var}({\hat{\delta}})}}
# \end{align}
# $
#
# The distribution of $t$ is not a standard distribution but has a stochastic integral representation that must be evaluated numerically, namely,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\int_0^1 B(s) dB(s)}{\sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# where $B(s)$ is a Wiener process. The numerator integral can be evaluated to obtain,
#
# $
# \begin{align}
# \int_0^1 B(s) dB(s) = \frac{1}{2} \left[ B^2(1) - 1 \right]
# \end{align}
# $
#
# The final result is given by,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# The ADF test is a lower tailed hypothesis test. If successful $\delta = 0$ and the time series is brownian motion. If testing a time series for stationarity</br>, for $\delta$ as defined,
# $\delta > 0$ is desired so the test must fail.

# %% [markdown]
# ## Includes

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (ARIMA, ADF, Test, Stats)
from lib import (curve, bar)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## ADF Distribution
#
# The probability distribution of the ADF test statistic,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# is computed by simulation.

# %%
nstep = 100
nsim = 10000
df = ADF.Source.DF.create(nstep=nstep, nsim=nsim, npts=nsim)
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:31',
#  'Type': <Source.DF: 'DF'>,
#  'Name': 'Dickey-Fuller-Simulation-8fe2a423-d4db-4f97-89c1-31682e9c784d',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}}}

# %%
pdf = Stats.Func.PDF_HIST.apply(df, xmin=-4.0, xmax=8.0)
bar(pdf)
pdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-8fe2a423-d4db-4f97-89c1-31682e9c784d',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '19/06/2022 13:01:31',
#  'Type': <Func.PDF_HIST: 'PDF_HIST'>,
#  'Name': 'PDF_HIST-1a5039bd-b735-45e0-8f57-c0f206d07f05',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %%
cdf = Stats.Func.CDF_HIST.apply(pdf)
bar(cdf, loc="rup")
cdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-8fe2a423-d4db-4f97-89c1-31682e9c784d',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '19/06/2022 13:01:31',
#  'Type': <Func.CDF_HIST: 'CDF_HIST'>,
#  'Name': 'CDF_HIST-fd4e4853-27b8-41d2-a85d-c5f01d68d854',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}},
#  'CDF_HIST': {'npts': 49,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'CDF',
#   'ylabel': '$P(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %% [markdown]
# ## ADF Test examples

# %%
nsample = 1000

# %% [markdown]
# ### $\text{AR}(1)$
#
# $\delta = 1 - \varphi$

# %%
φ = [0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, lw=1, title=title)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.9533      │
# ├────────────────┼───────────────┤
# │ pvalue         │   5.35933e-29 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:32',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-55f61bc4-3adb-4133-8198-24a518ac43ec',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -17.953254376160597, 'Label': '$t$'},
#       'PValue': {'Value': 5.359333291982519e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.953254376160597, 'Label': '$t$'},
#       'PValue': {'Value': 5.359333291982519e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.953254376160597, 'Label': '$t$'},
#       'PValue': {'Value': 5.359333291982519e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════╕
# │ Test Statistic │ -52.83 │
# ├────────────────┼────────┤
# │ pvalue         │   0    │
# ├────────────────┼────────┤
# │ Lags           │   0    │
# ├────────────────┼────────┤
# │ Number Obs     │ 999    │
# ╘════════════════╧════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:32',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-43ce3802-d486-4012-8c20-05006c5364fd',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -52.83004235265747, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -52.83004235265747, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -52.83004235265747, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -2.03445   │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.0401158 │
# ├────────────────┼─────────────┤
# │ Lags           │   0         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 999         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:32',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-fe4d5a88-d00b-46c8-becf-c6d5412bb2a8',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -2.0344519951669433, 'Label': '$t$'},
#       'PValue': {'Value': 0.04011579585974827, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -2.0344519951669433, 'Label': '$t$'},
#       'PValue': {'Value': 0.04011579585974827, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -2.0344519951669433, 'Label': '$t$'},
#       'PValue': {'Value': 0.04011579585974827, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.742091 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.874711 │
# ├────────────────┼────────────┤
# │ Lags           │   5        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 994        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:32',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-7f3a83b4-48a9-496b-8b95-881e74a75293',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': 0.742090917829038, 'Label': '$t$'},
#       'PValue': {'Value': 0.8747112100490426, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567992966693521, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.742090917829038, 'Label': '$t$'},
#       'PValue': {'Value': 0.8747112100490426, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412735952824909, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.742090917829038, 'Label': '$t$'},
#       'PValue': {'Value': 0.8747112100490426, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165555178180728, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-1.0]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════╕
# │ Test Statistic │ -30.161 │
# ├────────────────┼─────────┤
# │ pvalue         │   0     │
# ├────────────────┼─────────┤
# │ Lags           │   1     │
# ├────────────────┼─────────┤
# │ Number Obs     │ 998     │
# ╘════════════════╧═════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:33',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-f13f55a7-17fc-49b0-835f-920b20b8a60b',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -30.1609644844718, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -30.1609644844718, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -30.1609644844718, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$
#
# $\delta = 1 - \varphi_1 - \varphi_2$

# %%
φ = [0.2, 0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -9.36178     │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.62503e-16 │
# ├────────────────┼───────────────┤
# │ Lags           │   5           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 994           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:33',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-b3fb4bd6-8fc1-49ec-9e54-7d3b8ada555e',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -9.361778453934827, 'Label': '$t$'},
#       'PValue': {'Value': 2.625030430930227e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567992966693521, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -9.361778453934827, 'Label': '$t$'},
#       'PValue': {'Value': 2.625030430930227e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412735952824909, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -9.361778453934827, 'Label': '$t$'},
#       'PValue': {'Value': 2.625030430930227e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165555178180728, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.3, -0.4]
samples = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(samples, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -9.36178     │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.62503e-16 │
# ├────────────────┼───────────────┤
# │ Lags           │   5           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 994           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:33',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-b3fb4bd6-8fc1-49ec-9e54-7d3b8ada555e',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -9.361778453934827, 'Label': '$t$'},
#       'PValue': {'Value': 2.625030430930227e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567992966693521, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -9.361778453934827, 'Label': '$t$'},
#       'PValue': {'Value': 2.625030430930227e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412735952824909, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -9.361778453934827, 'Label': '$t$'},
#       'PValue': {'Value': 2.625030430930227e-16, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165555178180728, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.8]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.675563 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.862141 │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:34',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-60cdece8-a3a3-40ef-bfcc-eda621576e1b',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.8], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': 0.675563237825366, 'Label': '$t$'},
#       'PValue': {'Value': 0.8621410243602401, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.675563237825366, 'Label': '$t$'},
#       'PValue': {'Value': 0.8621410243602401, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.675563237825366, 'Label': '$t$'},
#       'PValue': {'Value': 0.8621410243602401, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(3)$
#
# $\delta = 1 - \varphi_1 - \varphi_2 - \varphi_3$

# %%
φ = [0.2, 0.3, 0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.36644     │
# ├────────────────┼───────────────┤
# │ pvalue         │   9.06098e-12 │
# ├────────────────┼───────────────┤
# │ Lags           │   2           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 997           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:34',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-1ac36dee-6dae-42dd-98fe-a36689beecf0',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -7.366444230111437, 'Label': '$t$'},
#       'PValue': {'Value': 9.06097926359265e-12, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.366444230111437, 'Label': '$t$'},
#       'PValue': {'Value': 9.06097926359265e-12, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.366444230111437, 'Label': '$t$'},
#       'PValue': {'Value': 9.06097926359265e-12, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, -0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -19.6165 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   2      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 997      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:34',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-505d6b67-b21f-48d7-962d-7a93d1773189',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, -0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -19.616536558639673, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.616536558639673, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.616536558639673, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, 0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result=Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │   0.0661384 │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.705843  │
# ├────────────────┼─────────────┤
# │ Lags           │   3         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 996         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:35',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-e95fe261-ba6d-47aa-bb1a-cab753237273',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.5], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': 0.0661383746693591, 'Label': '$t$'},
#       'PValue': {'Value': 0.7058428667970069, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567988435307495, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.0661383746693591, 'Label': '$t$'},
#       'PValue': {'Value': 0.7058428667970069, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412730391965518, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.0661383746693591, 'Label': '$t$'},
#       'PValue': {'Value': 0.7058428667970069, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165560435054842, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### AR(1) with Offset

# %%
μ = 1.0
γ = 0.0

# %%
φ = [0.5]
df = ARIMA.Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -16.8392      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.14173e-29 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:35',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-230f3983-a0ae-4b19-8ae6-a228678a7123',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -16.839173076293655, 'Label': '$t$'},
#       'PValue': {'Value': 1.1417331701392417e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -16.839173076293655, 'Label': '$t$'},
#       'PValue': {'Value': 1.1417331701392417e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -16.839173076293655, 'Label': '$t$'},
#       'PValue': {'Value': 1.1417331701392417e-29, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = ARIMA.Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -5.91671     │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.56271e-07 │
# ├────────────────┼───────────────┤
# │ Lags           │  16           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 983           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43702 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86448 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56834 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:36',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-911e34e4-3497-4a56-9215-5726320666dc',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -5.916705509454241, 'Label': '$t$'},
#       'PValue': {'Value': 2.562705971101825e-07, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4370198458812156, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -5.916705509454241, 'Label': '$t$'},
#       'PValue': {'Value': 2.562705971101825e-07, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864484708707697, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -5.916705509454241, 'Label': '$t$'},
#       'PValue': {'Value': 2.562705971101825e-07, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568337912084273, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.160412 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.943079 │
# ├────────────────┼────────────┤
# │ Lags           │   7        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 992        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43696 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86446 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56832 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:36',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Simulation-325a9c14-8947-43cb-9326-6e57dfafa8df',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.16041188928003786, 'Label': '$t$'},
#       'PValue': {'Value': 0.9430788325576388, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.436959175494265, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.16041188928003786, 'Label': '$t$'},
#       'PValue': {'Value': 0.9430788325576388, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.8644579524531975, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.16041188928003786, 'Label': '$t$'},
#       'PValue': {'Value': 0.9430788325576388, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568323660940752, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(1)$ with Drift

# %%
μ = 1.0
γ = 0.01

# %%
φ = [0.5]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -18.4289 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:36',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-e8506d5d-c04d-497a-8a8d-8ec9a352e8c8',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -18.42887196234881, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.42887196234881, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.42887196234881, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -22.8711 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   2      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 997      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96788 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12965 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:36',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-6e1f5c6e-be3d-4f4c-8dcf-d489ed240e4c',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[-0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -22.871117066898076, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.9678790757313824, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -22.871117066898076, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4149027470782776, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -22.871117066898076, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296473513794565, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.9]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -8.28905     │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.53544e-11 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:37',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-d573bbf0-3907-4319-8830-d15f709a29f5',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[0.9]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -8.289052738258148, 'Label': '$t$'},
#       'PValue': {'Value': 1.5354431042157628e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -8.289052738258148, 'Label': '$t$'},
#       'PValue': {'Value': 1.5354431042157628e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -8.289052738258148, 'Label': '$t$'},
#       'PValue': {'Value': 1.5354431042157628e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.11078  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.927244 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:37',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-Simulation-ffae7a24-b1c6-4bf6-a724-1f3dbdde955a',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.1107769710918503, 'Label': '$t$'},
#       'PValue': {'Value': 0.9272444660192973, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.1107769710918503, 'Label': '$t$'},
#       'PValue': {'Value': 0.9272444660192973, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.1107769710918503, 'Label': '$t$'},
#       'PValue': {'Value': 0.9272444660192973, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$ with Drift

# %%
φ = [0.2, 0.3]
df = ARIMA.Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │ -11.2465    │
# ├────────────────┼─────────────┤
# │ pvalue         │   7.707e-18 │
# ├────────────────┼─────────────┤
# │ Lags           │   4         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 995         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.9679  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41491 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12965 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:37',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-Simulation-1ebd70b3-1e28-4f26-9515-092276640aa1',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -11.246530515437914, 'Label': '$t$'},
#       'PValue': {'Value': 7.707002459886269e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.9678974435788446, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -11.246530515437914, 'Label': '$t$'},
#       'PValue': {'Value': 7.707002459886269e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4149116354152773, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -11.246530515437914, 'Label': '$t$'},
#       'PValue': {'Value': 7.707002459886269e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.129652580230259, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.4, 0.6]
df = ARIMA.Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.193759 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.995742 │
# ├────────────────┼────────────┤
# │ Lags           │   5        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 994        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96791 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41492 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12966 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '19/06/2022 13:01:38',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-Simulation-950439b2-c7aa-4854-ac67-4bd9abc4d168',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.4, 0.6], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': 0.1937594529859843, 'Label': '$t$'},
#       'PValue': {'Value': 0.9957416973155782, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967906655308904, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.1937594529859843, 'Label': '$t$'},
#       'PValue': {'Value': 0.9957416973155782, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414916093024836, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.1937594529859843, 'Label': '$t$'},
#       'PValue': {'Value': 0.9957416973155782, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296552025585007, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}
