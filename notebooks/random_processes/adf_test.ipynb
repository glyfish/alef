# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test
#
# The Augmented Dickey-Fuller identifies stationarity in an autoregressive process. This is accomplished by testing for the presence</br>
# of nonstationarity, called the unit root. For example consider the $\text{AR}(1)$ process,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0,\sigma^2)$ and independent. If $\lvert \varphi \rvert < 1$ it can be shown that $X_t$ is stationary. The unit root,</br>
# $\lvert \varphi \rvert = 1$, is equivalent to brownian motion.
#
# ### Unit Root Form of $\text{AR}(1)$
#
# The unit root form of $\text{AR}(1)$ used in the analysis is constructed as follows. Subtracting $X_{t-1}$ from both sides of the expression</br>
# for $\text{AR}(1)$ gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Recall that the lag operator, $L$, is defined by, $L X_t = X_{t-1}, L^2 X_t = X_{t-2}, L^3 X_t = X_{t-3}, \ldots$. The difference operator is then given by</br>
# $\Delta = 1 - L$ and let $\delta = \varphi - 1$. It follows that
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Stationarity implies that, $\delta < 0$, while nonstationarity, unit root, implies $\delta = 0$. If follows that ADF tests is a lower tail significance test</br>
# with null hypothesis $\delta = 0$ and alternative hypothesis $\delta < 0$. Thus if the test fails $X_t$ is stationary.
#
# The lag polynomial is defined by,
#
# $
# \begin{align}
# \Phi^1(L) = 1 - \varphi L
# \end{align}
# $
#
# It follows that,
#
# $
# \begin{align}
# \Phi^1(L)X_t = \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^1(1) =  -\delta \\
# \Rightarrow& \delta = 1 - \varphi = 0
# \end{align}
# $
#
# ### Unit Root Form of $\text{AR}(q)$
#
# Following the procedure used for $\text{AR}(1)$ the unit root form of $\text{AR}(2)$ can be constructed. The $\text{AR}(2)$ lag polynomial is given by,
#
# $
# \begin{align}
# \Phi^2(L) = 1 - \varphi_1 L - \varphi_2 L^2
# \end{align}
# $
#
# If follows that,
#
# $
# \begin{align}
# &\Phi^2(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# To obtain the unit root form subtract $X_{t-1}$ from both sides of $\text{AR}(2)$ to obtain,
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# $
#
# Next add and subtract $\varphi_3 X_{t-1}$ to obtain the final result,
#
# $
# \begin{align}
# & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t - \varphi_2 X_{t-1} \\
# \Rightarrow & \Delta X_t = \left( \varphi_2 + \varphi_1 - 1 \right) X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# Let $\delta = \varphi_2 + \varphi_1 - 1$ to obtain the unit root form,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^2(1) = -\delta \\
# \Rightarrow& \delta = \varphi_1 + \varphi_2 - 1 = 0
# \end{align}
# $
#
# This procedure can be repeated for autoregressive processes of arbitrary order. $\text{AR}(q)$ is defined by
#
# $
# \begin{align}
# &\Phi^q(L) = 1 - \varphi_1 L + \varphi_2 L^2 - \cdots - \varphi_q L^q \\
# \Rightarrow & \Phi^q(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \cdots + + \varphi_q X_{t-q} + \varepsilon_t
# \end{align}
# $
#
# the unit root form is given by,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + C_1 \Delta X_{t-1} + C_2 \Delta X_{t-2} + \cdots + C_{q-1} \Delta X_{t- \left( q - 1 \right)} + \varepsilon_t
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# &\delta = \varphi_1 + \varphi_2 + \cdots + \varphi_q  -1\\
# &\Phi^q(1) = -\delta \\
# &C_i = -\sum_{j=i+1}^q \varphi_j
# \end{align}
# $
#
# ### $\text{AR}(1)$ Test Statistic
#
# The OLS estimate for the $\text{AR}(1)$ coefficient $\varphi$  is given by,
#
# $
# \begin{align}
# \hat{\varphi} = \frac{\sum_{t=1}^T X_t X_{t-1}}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# Using $X_t = \Delta X_t + X_{t-1}$ and $\hat{\delta} = \hat{\varphi} - 1$ gives,
#
# $
# \begin{align}
# \hat{\delta} = \frac{\sum_{t=1}^T X_{t-1} \varepsilon_t}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# From this expression it can be shown that,
#
# $
# \begin{align}
# &\text{E}(\hat{\delta}) = 0 \\
# &\text{Var}(\hat{\delta}) = \frac{\sigma}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# $
#
# The test statistic is given by,
#
# $
# \begin{align}
# t = \frac{\hat{\delta}}{\sqrt{\text{Var}({\hat{\delta}})}}
# \end{align}
# $
#
# The distribution of $t$ is not a standard distribution but has a stochastic integral representation that must be evaluated numerically, namely,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\int_0^1 B(s) dB(s)}{\sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# where $B(s)$ is a Wiener process. The numerator integral can be evaluated to obtain,
#
# $
# \begin{align}
# \int_0^1 B(s) dB(s) = \frac{1}{2} \left[ B^2(1) - 1 \right]
# \end{align}
# $
#
# The final result is given by,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# The ADF test is a lower tailed hypothesis test. If successful $\delta = 0$ and the time series is brownian motion. If testing a time series for stationarity</br>, for $\delta$ as defined,
# $\delta > 0$ is desired so the test must fail.

# %% [markdown]
# ## Includes

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (ARIMA, ADF, Stats)
from lib import (curve, bar)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## ADF Distribution
#
# The probability distribution of the ADF test statistic,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# is computed by simulation.

# %%
nstep = 100
nsim = 10000
df = ADF.Source.DF.create(nstep=nstep, nsim=nsim, npts=nsim)
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:22',
#  'Type': <Source.DF: 'DF'>,
#  'Name': 'Dickey-Fuller-Simulation-4526051e-9cee-43c3-bfc3-7797f9e54c95',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}}}

# %%
pdf = Stats.Func.PDF_HIST.apply(df, xmin=-4.0, xmax=8.0)
bar(pdf)
pdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-4526051e-9cee-43c3-bfc3-7797f9e54c95',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '20/06/2022 14:53:22',
#  'Type': <Func.PDF_HIST: 'PDF_HIST'>,
#  'Name': 'PDF_HIST-c95fa397-9caf-47c4-9db8-7224e1c6b886',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %%
cdf = Stats.Func.CDF_HIST.apply(pdf)
bar(cdf, loc="rup")
cdf.attrs
# Out:
# {'SourceType': <Source.DF: 'DF'>,
#  'SourceName': 'Dickey-Fuller-Simulation-4526051e-9cee-43c3-bfc3-7797f9e54c95',
#  'Schema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#  'Date': '20/06/2022 14:53:22',
#  'Type': <Func.CDF_HIST: 'CDF_HIST'>,
#  'Name': 'CDF_HIST-16efd053-fc8d-451e-8b2e-43d407e020fe',
#  'SchemaIterations': None,
#  'DF': {'npts': 10000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'nstep': 100, 'nsim': 10000},
#   'Description': 'Dickey-Fuller Distribution',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {}},
#  'PDF_HIST': {'npts': 50,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'PDF',
#   'ylabel': '$p(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}},
#  'CDF_HIST': {'npts': 49,
#   'DataType': <DataType.DIST: 'DIST'>,
#   'Parameters': {},
#   'Description': 'CDF',
#   'ylabel': '$P(x)$',
#   'xlabel': '$x$',
#   'SourceSchema': DataSchema(xcol=(x), ycol=(p(x)), data_type=(DataType.DIST)),
#   'Formula': '$x \\sim \\frac{\\frac{1}{2}[B^2(1) - 1]}{\\sqrt{\\int_{0}^{1}B^2(s)ds}}$',
#   'Estimates': {},
#   'Tests': {}}}

# %% [markdown]
# ## ADF Test examples

# %%
nsample = 1000

# %% [markdown]
# ### $\text{AR}(1)$
#
# $\delta = 1 - \varphi$

# %%
φ = [0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, lw=1, title=title)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.034       │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.50774e-28 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:23',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-7d074faf-d48e-4956-b9e2-9dc99c44e763',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -17.033987268536357, 'Label': '$t$'},
#       'PValue': {'Value': 1.5077391237644055e-28, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.033987268536357, 'Label': '$t$'},
#       'PValue': {'Value': 1.5077391237644055e-28, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -17.033987268536357, 'Label': '$t$'},
#       'PValue': {'Value': 1.5077391237644055e-28, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -54.2403 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:23',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-05f17100-79c6-4122-afde-d6ebbe3809a9',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-0.5], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -54.24031859273666, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -54.24031859273666, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -54.24031859273666, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -1.88247   │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.0569881 │
# ├────────────────┼─────────────┤
# │ Lags           │   4         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 995         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:23',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-5c2a36cf-fd08-4902-915d-dcd42f69f535',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.8824749805872034, 'Label': '$t$'},
#       'PValue': {'Value': 0.05698807315029934, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567990698719729, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.8824749805872034, 'Label': '$t$'},
#       'PValue': {'Value': 0.05698807315029934, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.941273316956744, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -1.8824749805872034, 'Label': '$t$'},
#       'PValue': {'Value': 0.05698807315029934, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.616555780923252, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.267412 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.588575 │
# ├────────────────┼────────────┤
# │ Lags           │   3        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 996        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:24',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-52eac4e4-8573-42ee-a12e-2e0d9e3ea34f',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.2674115275209248, 'Label': '$t$'},
#       'PValue': {'Value': 0.5885748900207871, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.567988435307495, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.2674115275209248, 'Label': '$t$'},
#       'PValue': {'Value': 0.5885748900207871, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412730391965518, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.2674115275209248, 'Label': '$t$'},
#       'PValue': {'Value': 0.5885748900207871, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165560435054842, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-1.0]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -388.521 │
# ├────────────────┼──────────┤
# │ pvalue         │    0     │
# ├────────────────┼──────────┤
# │ Lags           │    0     │
# ├────────────────┼──────────┤
# │ Number Obs     │  999     │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:24',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(1)-Simulation-45a8e83c-2940-4479-96b0-cb5490932710',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [-1.0], 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -388.5206715480235, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -388.5206715480235, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -388.5206715480235, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$
#
# $\delta = 1 - \varphi_1 - \varphi_2$

# %%
φ = [0.2, 0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -13.3695      │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.59988e-24 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:24',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-93b32685-8e02-4471-9016-af6e92251da6',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -13.369545619455982, 'Label': '$t$'},
#       'PValue': {'Value': 2.5998807645519873e-24, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.369545619455982, 'Label': '$t$'},
#       'PValue': {'Value': 2.5998807645519873e-24, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.369545619455982, 'Label': '$t$'},
#       'PValue': {'Value': 2.5998807645519873e-24, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.3, -0.4]
samples = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(samples, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -13.3695      │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.59988e-24 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:24',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-93b32685-8e02-4471-9016-af6e92251da6',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -13.369545619455982, 'Label': '$t$'},
#       'PValue': {'Value': 2.5998807645519873e-24, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.369545619455982, 'Label': '$t$'},
#       'PValue': {'Value': 2.5998807645519873e-24, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -13.369545619455982, 'Label': '$t$'},
#       'PValue': {'Value': 2.5998807645519873e-24, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.8]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.257853 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.592213 │
# ├────────────────┼────────────┤
# │ Lags           │   2        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 997        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:25',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(2)-Simulation-bc352209-3475-4fbc-95b2-ac88e88f039e',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.8], 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.25785300032191905, 'Label': '$t$'},
#       'PValue': {'Value': 0.5922125046737593, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.25785300032191905, 'Label': '$t$'},
#       'PValue': {'Value': 0.5922125046737593, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.25785300032191905, 'Label': '$t$'},
#       'PValue': {'Value': 0.5922125046737593, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(3)$
#
# $\delta = 1 - \varphi_1 - \varphi_2 - \varphi_3$

# %%
φ = [0.2, 0.3, 0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -6.63849     │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.85866e-10 │
# ├────────────────┼───────────────┤
# │ Lags           │   2           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 997           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:26',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-e9f6a3fa-44a1-45b5-8897-1370d2badd32',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -6.638485375216515, 'Label': '$t$'},
#       'PValue': {'Value': 3.8586641169805664e-10, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -6.638485375216515, 'Label': '$t$'},
#       'PValue': {'Value': 3.8586641169805664e-10, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -6.638485375216515, 'Label': '$t$'},
#       'PValue': {'Value': 3.8586641169805664e-10, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, -0.3]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -19.2189 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   2      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 997      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:26',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-99e37775-d6b1-40f7-b931-e3d411b7fd18',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, -0.3], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -19.21887714405475, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.21887714405475, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -19.21887714405475, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.2, 0.3, 0.5]
df = ARIMA.Source.AR.create(φ=φ, npts=nsample)
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │   0.0600075 │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.703881  │
# ├────────────────┼─────────────┤
# │ Lags           │   2         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 997         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:26',
#  'Type': <Source.AR: 'AR'>,
#  'Name': 'AR(3)-Simulation-23328c8d-75fd-490d-8e45-66f5bcbb0d0d',
#  'SchemaIterations': None,
#  'AR': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3, 0.5], 'σ': 1.0},
#   'Description': 'AR(3)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY: 'STATIONARITY'>,
#     'ImplType': <_TestImpl.ADF: 'ADF'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': 0.06000754919494492, 'Label': '$t$'},
#       'PValue': {'Value': 0.7038812345405742, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.06000754919494492, 'Label': '$t$'},
#       'PValue': {'Value': 0.7038812345405742, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': 0.06000754919494492, 'Label': '$t$'},
#       'PValue': {'Value': 0.7038812345405742, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### AR(1) with Offset

# %%
μ = 1.0
γ = 0.0

# %%
φ = [0.5]
df = ARIMA.Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -18.6236      │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.06031e-30 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:27',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-f5715eb9-8927-48ae-95ff-cb1f0501c38d',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.5], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -18.623577905031805, 'Label': '$t$'},
#       'PValue': {'Value': 2.060311035115559e-30, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.623577905031805, 'Label': '$t$'},
#       'PValue': {'Value': 2.060311035115559e-30, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.623577905031805, 'Label': '$t$'},
#       'PValue': {'Value': 2.060311035115559e-30, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.99]
df = ARIMA.Source.AR_OFFSET.create(φ=φ, μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -5.39178     │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.52449e-06 │
# ├────────────────┼───────────────┤
# │ Lags           │   3           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 996           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43693 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86445 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56832 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:27',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-81b4ea0e-a9a2-4b4a-9b09-ccd10f0ab49e',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.99], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -5.391780126878154, 'Label': '$t$'},
#       'PValue': {'Value': 3.5244891639423543e-06, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369325637409154, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -5.391780126878154, 'Label': '$t$'},
#       'PValue': {'Value': 3.5244891639423543e-06, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.8644462162311934, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -5.391780126878154, 'Label': '$t$'},
#       'PValue': {'Value': 3.5244891639423543e-06, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568317409920808, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR_OFFSET.create(φ=[φ], μ=μ, npts=nsample)
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_OFFSET.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.27452  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.640749 │
# ├────────────────┼────────────┤
# │ Lags           │   6        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 993        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43695 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86446 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56832 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:27',
#  'Type': <Source.AR_OFFSET: 'AR_OFFSET'>,
#  'Name': 'AR(1)-Offset-Simulation-df43f0a7-be11-4419-a7a2-bffe0414c2b2',
#  'SchemaIterations': None,
#  'AR_OFFSET': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_OFFSET': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#     'ImplType': <_TestImpl.ADF_OFFSET: 'ADF_OFFSET'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -1.2745172032273506, 'Label': '$t$'},
#       'PValue': {'Value': 0.6407486075447947, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.4369525024039884, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2745172032273506, 'Label': '$t$'},
#       'PValue': {'Value': 0.6407486075447947, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -2.8644550095200705, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -1.2745172032273506, 'Label': '$t$'},
#       'PValue': {'Value': 0.6407486075447947, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -2.568322093455802, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(1)$ with Drift

# %%
μ = 1.0
γ = 0.01

# %%
φ = [0.5]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -18.3106 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:28',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-36c202c0-ec10-4c1c-9490-7ddc65300f9e',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -18.31056993186088, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.31056993186088, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -18.31056993186088, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [-0.5]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -56.5884 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:28',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-b9f22416-77b6-42a9-a77b-e11946b537db',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[-0.5]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -56.58837275969766, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -56.58837275969766, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -56.58837275969766, 'Label': '$t$'},
#       'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.9]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.95902     │
# ├────────────────┼───────────────┤
# │ pvalue         │   8.88689e-11 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:28',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-0d5b6163-9d4c-48b1-a00a-7e1777af9f0b',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[0.9]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -7.959021291633686, 'Label': '$t$'},
#       'PValue': {'Value': 8.886891324128481e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.959021291633686, 'Label': '$t$'},
#       'PValue': {'Value': 8.886891324128481e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -7.959021291633686, 'Label': '$t$'},
#       'PValue': {'Value': 8.886891324128481e-11, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [1.0]
df = ARIMA.Source.AR_DRIFT.create(φ=[φ], μ=μ, γ=γ, npts=nsample)
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -0.0338034 │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.993874  │
# ├────────────────┼─────────────┤
# │ Lags           │   0         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 999         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:29',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(1)-DRIFT-Simulation-eed8cffe-15b4-40fb-a3ed-21054061dc20',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [[1.0]], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(1)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.03380338050642414, 'Label': '$t$'},
#       'PValue': {'Value': 0.9938744433236205, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.03380338050642414, 'Label': '$t$'},
#       'PValue': {'Value': 0.9938744433236205, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.03380338050642414, 'Label': '$t$'},
#       'PValue': {'Value': 0.9938744433236205, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %% [markdown]
# ### $\text{AR}(2)$ with Drift

# %%
φ = [0.2, 0.3]
df = ARIMA.Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -11.6833      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.29331e-18 │
# ├────────────────┼───────────────┤
# │ Lags           │   5           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 994           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96791 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41492 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12966 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:29',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-DRIFT-Simulation-4ca10b7e-9e94-4a7b-ac0e-df89a1181d87',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.2, 0.3], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': True,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': False,
#       'Statistic': {'Value': -11.683272519147943, 'Label': '$t$'},
#       'PValue': {'Value': 1.2933074267182324e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.967906655308904, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -11.683272519147943, 'Label': '$t$'},
#       'PValue': {'Value': 1.2933074267182324e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414916093024836, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': False,
#       'Statistic': {'Value': -11.683272519147943, 'Label': '$t$'},
#       'PValue': {'Value': 1.2933074267182324e-18, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.1296552025585007, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}

# %%
φ = [0.4, 0.6]
df = ARIMA.Source.AR_DRIFT.create(φ=φ, μ=μ, γ=γ, npts=nsample)
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"
curve(df, title=title, lw=1)

# %%
result = ARIMA.Test.STATIONARITY_DRIFT.perform(df)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.124123 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.992734 │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
df.attrs
# Out:
# {'SourceType': None,
#  'SourceName': None,
#  'Schema': DataSchema(xcol=(t), ycol=(S(t)), data_type=(DataType.TIME_SERIES)),
#  'Date': '20/06/2022 14:53:29',
#  'Type': <Source.AR_DRIFT: 'AR_DRIFT'>,
#  'Name': 'AR(2)-DRIFT-Simulation-71f40deb-84f4-4258-b18c-9b99c13c0888',
#  'SchemaIterations': None,
#  'AR_DRIFT': {'npts': 1000,
#   'DataType': <DataType.TIME_SERIES: 'TIME_SERIES'>,
#   'Parameters': {'φ': [0.4, 0.6], 'μ': 1.0, 'γ': 0.01, 'σ': 1.0},
#   'Description': 'AR(2)',
#   'ylabel': '$S_t$',
#   'xlabel': '$t$',
#   'SourceSchema': None,
#   'Formula': None,
#   'Estimates': {},
#   'Tests': {'STATIONARITY_DRIFT': {'Status': False,
#     'TestHypothesis': <TestHypothesis.LOWER_TAIL: 'LOWER_TAIL'>,
#     'TestType': <Test.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#     'ImplType': <_TestImpl.ADF_DRIFT: 'ADF_DRIFT'>,
#     'Description': 'Stationarity Test',
#     'Distribution': None,
#     'Distribution Params': {},
#     'TestData': [{'Status': True,
#       'Statistic': {'Value': -0.12412324404192718, 'Label': '$t$'},
#       'PValue': {'Value': 0.9927340776178799, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.01, 'Label': '1%'},
#       'Lower Critical Value': {'Value': -3.9678699195021783, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.12412324404192718, 'Label': '$t$'},
#       'PValue': {'Value': 0.9927340776178799, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.05, 'Label': '5%'},
#       'Lower Critical Value': {'Value': -3.414898316296852, 'Label': '$t_L$'},
#       'Upper Critical Value': None},
#      {'Status': True,
#       'Statistic': {'Value': -0.12412324404192718, 'Label': '$t$'},
#       'PValue': {'Value': 0.9927340776178799, 'Label': '$p-value$'},
#       'Parameters': [],
#       'Significance': {'Value': 0.1, 'Label': '10%'},
#       'Lower Critical Value': {'Value': -3.129644744825171, 'Label': '$t_L$'},
#       'Upper Critical Value': None}]}}}}
