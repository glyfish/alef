# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test
#
# The Augmented Dickey-Fuller identifies stationarity in an autoregressive process. This is accomplished by testing for the presence of nonstationarity, called the unit root. For example consider the $\text{AR}(1)$ process,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \varepsilon_t
# \end{align}
# \tag{1}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0,\sigma^2)$ and independent. If $\lvert \varphi \rvert < 1$ it can be shown that $X_t$ is stationary. The unit root,
# $\lvert \varphi \rvert = 1$, is equivalent to brownian motion.
#
# ### Unit Root Form of $\text{AR}(1)$
#
# The unit root form of $\text{AR}(1)$ used in the analysis is constructed as follows. Subtracting $X_{t-1}$ from both sides of the expression
# for $\text{AR}(1)$ gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t
# \end{align}
# \tag{2}
# $
#
# Recall that the lag operator, $L$, is defined by, $L X_t = X_{t-1}, L^2 X_t = X_{t-2}, L^3 X_t = X_{t-3}, \ldots$. The difference operator is then given by
# $\Delta = 1 - L$ and let $\delta = \varphi - 1$. It follows that
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{3}
# $
#
# Stationarity implies that, $\delta < 0$, while nonstationarity, unit root, implies $\delta = 0$. If follows that ADF tests is a lower tail significance test
# with null hypothesis $\delta = 0$ and alternative hypothesis $\delta < 0$. Thus if the test fails $X_t$ is stationary.
#
# The lag polynomial is defined by,
#
# $
# \begin{align}
# \Phi^1(L) = 1 - \varphi L
# \end{align}
# \tag{4}
# $
#
# It follows that,
#
# $
# \begin{align}
# \Phi^1(L)X_t = \varepsilon_t
# \end{align}
# \tag{5}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^1(1) =  -\delta \\
# \Rightarrow& \delta = 1 - \varphi = 0
# \end{align}
# \tag{6}
# $
#
# ### Unit Root Form of $\text{AR}(q)$
#
# Following the procedure used for $\text{AR}(1)$ the unit root form of $\text{AR}(2)$ can be constructed. The $\text{AR}(2)$ lag polynomial is given by,
#
# $
# \begin{align}
# \Phi^2(L) = 1 - \varphi_1 L - \varphi_2 L^2
# \end{align}
# \tag{7}
# $
#
# If follows that,
#
# $
# \begin{align}
# &\Phi^2(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# \tag{8}
# $
#
# To obtain the unit root form subtract $X_{t-1}$ from both sides of $\text{AR}(2)$ to obtain,
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# \tag{9}
# $
#
# Next add and subtract $\varphi_3 X_{t-1}$ to obtain the final result,
#
# $
# \begin{align}
# & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t - \varphi_2 X_{t-1} \\
# \Rightarrow & \Delta X_t = \left( \varphi_2 + \varphi_1 - 1 \right) X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{10}
# $
#
# Let $\delta = \varphi_2 + \varphi_1 - 1$ to obtain the unit root form,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{11}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^2(1) = -\delta \\
# \Rightarrow& \delta = \varphi_1 + \varphi_2 - 1 = 0
# \end{align}
# \tag{12}
# $
#
# This procedure can be repeated for autoregressive processes of arbitrary order. $\text{AR}(q)$ is defined by
#
# $
# \begin{align}
# &\Phi^q(L) = 1 - \varphi_1 L + \varphi_2 L^2 - \cdots - \varphi_q L^q \\
# \Rightarrow & \Phi^q(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \cdots + + \varphi_q X_{t-q} + \varepsilon_t
# \end{align}
# \tag{13}
# $
#
# the unit root form is given by,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + C_1 \Delta X_{t-1} + C_2 \Delta X_{t-2} + \cdots + C_{q-1} \Delta X_{t- \left( q - 1 \right)} + \varepsilon_t
# \end{align}
# \tag{14}
# $
#
# where,
#
# $
# \begin{align}
# &\delta = \varphi_1 + \varphi_2 + \cdots + \varphi_q  -1\\
# &\Phi^q(1) = -\delta \\
# &C_i = -\sum_{j=i+1}^q \varphi_j
# \end{align}
# \tag{15}
# $
#
# ### $\text{AR}(1)$ Test Statistic
#
# The OLS estimate for the $\text{AR}(1)$ coefficient $\varphi$  is given by,
#
# $
# \begin{align}
# \hat{\varphi} = \frac{\sum_{t=1}^T X_t X_{t-1}}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{16}
# $
#
# Using $X_t = \Delta X_t + X_{t-1}$ and $\hat{\delta} = \hat{\varphi} - 1$ gives,
#
# $
# \begin{align}
# \hat{\delta} = \frac{\sum_{t=1}^T X_{t-1} \varepsilon_t}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{17}
# $
#
# From this expression it can be shown that,
#
# $
# \begin{align}
# &\text{E}(\hat{\delta}) = 0 \\
# &\text{Var}(\hat{\delta}) = \frac{\sigma}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{18}
# $
#
# The test statistic is given by,
#
# $
# \begin{align}
# t = \frac{\hat{\delta}}{\sqrt{\text{Var}({\hat{\delta}})}}
# \end{align}
# \tag{19}
# $
#
# The distribution of $t$ is not a standard distribution but has a stochastic integral representation that must be evaluated numerically, namely,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\int_0^1 B(s) dB(s)}{\sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# \tag{20}
# $
#
# where $B(s)$ is a Wiener process. The numerator integral can be evaluated to obtain,
#
# $
# \begin{align}
# \int_0^1 B(s) dB(s) = \frac{1}{2} \left[ B^2(1) - 1 \right]
# \end{align}
# \tag{21}
# $
#
# The final result is given by,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# \tag{22}
# $
#
# The ADF test is a lower tailed hypothesis test. If successful $\delta = 0$ and the time series is brownian motion. If testing a time series for stationarity, for $\delta$ as defined,
# $\delta > 0$ is desired so the test must fail.

# %% [markdown]
# ## Includes

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.plots import curve, bar
from lib.data import arima, adf, stats

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## ADF Distribution
#
# The probability distribution of the ADF test statistic,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# is computed by simulation.

# %%
nstep = 100
nsim = 10000
_, df = adf.create_df_source(nstep=nstep, nsim=nsim)

# %%
title = f"Dickey-Fuller Distribution PDF: nstep={nstep}, nsim={nsim}"
x, pdf = stats.compute_pdf_hist(df, xmin=-4.0, xmax=8.0)
bar(pdf, x, title=title, bar_width=0.9, ylabel=r"$p(x)$", xlabel=r"$x$", alpha=1.0)

# %%
title = f"Dickey-Fuller Distribution PDF: nstep={nstep}, nsim={nsim}"
x, cdf = stats.compute_cdf_hist(x, pdf)
bar(cdf, x, title=title, bar_width=0.9, ylabel=r"$P(x)$", xlabel=r"$x$", alpha=1.0)

# %% [markdown]
# ## ADF Test examples

# %%
nsample = 1000

# %% [markdown]
# ### $\text{AR}(1)$
#
# $\delta = 1 - \varphi$

# %%
φ = [0.5]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.49        │
# ├────────────────┼───────────────┤
# │ pvalue         │   8.36939e-29 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -17.489972571526767,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 8.3693851609775e-29,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "upper": null,
#             "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -17.489972571526767,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 8.3693851609775e-29,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412722092921209,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "upper": null,
#             "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -17.489972571526767,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 8.3693851609775e-29,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165568281300424,
#                 "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#             },
#             "upper": null,
#             "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "69ff9777-6650-4b7c-8f41-3b7533c9a5a9"
# }

# %%
φ = [-0.5]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -51.6573 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -51.657314266119165,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "upper": null,
#             "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -51.657314266119165,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412722092921209,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "upper": null,
#             "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -51.657314266119165,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165568281300424,
#                 "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#             },
#             "upper": null,
#             "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "a8401508-2027-4a2f-b17a-f45834daf99a"
# }

# %%
φ = [0.99]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -2.02785   │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.0407505 │
# ├────────────────┼─────────────┤
# │ Lags           │   0         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 999         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -2.0278494884117704,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.04075046846067018,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "upper": null,
#             "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -2.0278494884117704,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.04075046846067018,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412722092921209,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "upper": null,
#             "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -2.0278494884117704,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.04075046846067018,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165568281300424,
#                 "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#             },
#             "upper": null,
#             "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "1ba75951-77bd-4d3b-b552-a53ef868967a"
# }

# %%
φ = [1.0]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │   0.0940065 │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.714663  │
# ├────────────────┼─────────────┤
# │ Lags           │   0         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 999         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 0.09400650056060704,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.7146628203392345,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "upper": null,
#             "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 0.09400650056060704,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.7146628203392345,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412722092921209,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "upper": null,
#             "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 0.09400650056060704,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.7146628203392345,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165568281300424,
#                 "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#             },
#             "upper": null,
#             "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "ef2ae89c-d27e-493e-9e5b-365df23cf44e"
# }

# %%
φ = [-1.0]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -901.863 │
# ├────────────────┼──────────┤
# │ pvalue         │    0     │
# ├────────────────┼──────────┤
# │ Lags           │    0     │
# ├────────────────┼──────────┤
# │ Number Obs     │  999     │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -901.8634253531325,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "upper": null,
#             "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -901.8634253531325,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412722092921209,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "upper": null,
#             "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -901.8634253531325,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165568281300424,
#                 "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#             },
#             "upper": null,
#             "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "d3c227a5-e07e-4e7f-abd7-444310882f2d"
# }

# %% [markdown]
# ### $\text{AR}(2)$
#
# $\delta = 1 - \varphi_1 - \varphi_2$

# %%
φ = [0.2, 0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -13.9513      │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.19001e-25 │
# ├────────────────┼───────────────┤
# │ Lags           │   2           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 997           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -13.951333931500448,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.1900056135318157e-25,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679861764430703,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "upper": null,
#             "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -13.951333931500448,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.1900056135318157e-25,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412727620001924,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "upper": null,
#             "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -13.951333931500448,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.1900056135318157e-25,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165563055663268,
#                 "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#             },
#             "upper": null,
#             "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "6c99d5cd-241d-46a7-bf56-9b8a0423b8b6"
# }

# %%
φ = [0.3, -0.4]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -29.6515 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   1      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 998      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -29.651499398831028,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679839221127625,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "upper": null,
#             "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -29.651499398831028,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412724853659513,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "upper": null,
#             "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -29.651499398831028,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165565671073312,
#                 "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#             },
#             "upper": null,
#             "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "d1a8075e-4a91-481f-a611-1c2bc28ce0bb"
# }

# %%
φ = [0.2, 0.8]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.913735 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.32318  │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.9137346209722349,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.3231803725421051,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679839221127625,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "upper": null,
#             "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.9137346209722349,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.3231803725421051,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412724853659513,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "upper": null,
#             "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.9137346209722349,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.3231803725421051,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165565671073312,
#                 "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#             },
#             "upper": null,
#             "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "4c60c805-4d5a-4b56-b5d8-4d182121694f"
# }

# %% [markdown]
# ### $\text{AR}(3)$
#
# $\delta = 1 - \varphi_1 - \varphi_2 - \varphi_3$

# %%
φ = [0.2, 0.3, 0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -6.24045     │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.86361e-09 │
# ├────────────────┼───────────────┤
# │ Lags           │   3           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 996           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -6.240454310391839,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 2.8636115881792237e-09,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.567988435307495,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "upper": null,
#             "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -6.240454310391839,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 2.8636115881792237e-09,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412730391965518,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "upper": null,
#             "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -6.240454310391839,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 2.8636115881792237e-09,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165560435054842,
#                 "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#             },
#             "upper": null,
#             "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "836dabbf-b6f9-4014-a904-d0779c37f447"
# }

# %%
φ = [0.2, 0.3, -0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════╕
# │ Test Statistic │ -19.725 │
# ├────────────────┼─────────┤
# │ pvalue         │   0     │
# ├────────────────┼─────────┤
# │ Lags           │   2     │
# ├────────────────┼─────────┤
# │ Number Obs     │ 997     │
# ╘════════════════╧═════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -19.725008769796755,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679861764430703,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "upper": null,
#             "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -19.725008769796755,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412727620001924,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "upper": null,
#             "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -19.725008769796755,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165563055663268,
#                 "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#             },
#             "upper": null,
#             "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "d9ca2063-73d5-4fd0-96d1-e62bfcc79d44"
# }

# %%
φ = [0.2, 0.3, 0.501]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.461574 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.511847 │
# ├────────────────┼────────────┤
# │ Lags           │   2        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 997        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.4615744948688056,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.5118474959430348,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679861764430703,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "upper": null,
#             "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.4615744948688056,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.5118474959430348,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.9412727620001924,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "upper": null,
#             "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.4615744948688056,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.5118474959430348,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -1.6165563055663268,
#                 "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#             },
#             "upper": null,
#             "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
#         }
#     ],
#     "desc": "Stationarity Test",
#     "hyp_test_id": "dae0df27-749b-43bd-8539-011f9dac15cc"
# }

# %% [markdown]
# ### AR(1) with Offset

# %%
μ = 1.0
γ = 0.0

# %%
φ = [0.5]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -18.2019      │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.40463e-30 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_OFFSET",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -18.20194050232524,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 2.4046308345427485e-30,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4369127451400474,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "upper": null,
#             "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -18.20194050232524,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 2.4046308345427485e-30,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.864437475834273,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "upper": null,
#             "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -18.20194050232524,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 2.4046308345427485e-30,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.568312754566378,
#                 "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#             },
#             "upper": null,
#             "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
#         }
#     ],
#     "desc": "Stationarity Test with Constant Offset.",
#     "hyp_test_id": "e8b53ca7-1b34-47e4-a53a-8d1473beb73a"
# }

# %%
φ = [0.99]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.13416     │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.45564e-10 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_OFFSET",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -7.134163313042529,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.455636312473541e-10,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4369127451400474,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "upper": null,
#             "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -7.134163313042529,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.455636312473541e-10,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.864437475834273,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "upper": null,
#             "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -7.134163313042529,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.455636312473541e-10,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.568312754566378,
#                 "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#             },
#             "upper": null,
#             "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
#         }
#     ],
#     "desc": "Stationarity Test with Constant Offset.",
#     "hyp_test_id": "a0dc0c57-611b-4bc0-b50f-fd9f2655ca4d"
# }

# %%
φ = [1.0]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   1.32888  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.996766 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_OFFSET",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 1.3288828760589062,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.996765856760019,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4369127451400474,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "upper": null,
#             "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 1.3288828760589062,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.996765856760019,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.864437475834273,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "upper": null,
#             "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 1.3288828760589062,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.996765856760019,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.568312754566378,
#                 "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#             },
#             "upper": null,
#             "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
#         }
#     ],
#     "desc": "Stationarity Test with Constant Offset.",
#     "hyp_test_id": "364d9122-e494-4e7a-bb31-f06869e39071"
# }

# %% [markdown]
# ### $\text{AR}(1)$ with Drift

# %%
μ = 1.0
γ = 0.01

# %%
φ = [0.5]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -9.69467     │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.04287e-14 │
# ├────────────────┼───────────────┤
# │ Lags           │   9           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 990           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96794 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41493 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12967 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -9.694671379237311,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.0428689136327086e-14,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.967943688919601,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "upper": null,
#             "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -9.694671379237311,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.0428689136327086e-14,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4149340137050537,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "upper": null,
#             "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -9.694671379237311,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.0428689136327086e-14,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.129665744930171,
#                 "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#             },
#             "upper": null,
#             "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
#         }
#     ],
#     "desc": "Stationarity Test with Drift.",
#     "hyp_test_id": "0d55b20d-9b80-414e-b2d1-46aab645e4ab"
# }

# %%
φ = [-0.5]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════╕
# │ Test Statistic │ -54.896 │
# ├────────────────┼─────────┤
# │ pvalue         │   0     │
# ├────────────────┼─────────┤
# │ Lags           │   0     │
# ├────────────────┼─────────┤
# │ Number Obs     │ 999     │
# ╘════════════════╧═════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -54.89602614049201,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.967860781661831,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "upper": null,
#             "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -54.89602614049201,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4148938944043334,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "upper": null,
#             "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -54.89602614049201,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.1296421434972537,
#                 "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#             },
#             "upper": null,
#             "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
#         }
#     ],
#     "desc": "Stationarity Test with Drift.",
#     "hyp_test_id": "dbc2092c-e55e-42cf-bf1c-d785e099799b"
# }

# %%
φ = [0.9]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -8.71594     │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.60524e-12 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -8.715941553138741,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.605242645891798e-12,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.967860781661831,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "upper": null,
#             "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -8.715941553138741,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.605242645891798e-12,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4148938944043334,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "upper": null,
#             "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -8.715941553138741,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.605242645891798e-12,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.1296421434972537,
#                 "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#             },
#             "upper": null,
#             "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
#         }
#     ],
#     "desc": "Stationarity Test with Drift.",
#     "hyp_test_id": "b354f914-753c-4864-8e14-4d894bb4fb1f"
# }

# %%
φ = [1.0]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.345963 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.996443 │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 0.3459626121859765,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.9964431468216483,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.9678699195021783,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "upper": null,
#             "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 0.3459626121859765,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.9964431468216483,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.414898316296852,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "upper": null,
#             "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": 0.3459626121859765,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.9964431468216483,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.129644744825171,
#                 "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#             },
#             "upper": null,
#             "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
#         }
#     ],
#     "desc": "Stationarity Test with Drift.",
#     "hyp_test_id": "f684773f-7ba7-4559-a460-a3ef44c967cb"
# }

# %% [markdown]
# ### $\text{AR}(2)$ with Drift

# %%
φ = [0.2, 0.3]
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -13.3322      │
# ├────────────────┼───────────────┤
# │ pvalue         │   5.35137e-21 │
# ├────────────────┼───────────────┤
# │ Lags           │   2           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 997           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96788 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12965 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -13.332245808477035,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 5.351369203634458e-21,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.9678790757313824,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "upper": null,
#             "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -13.332245808477035,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 5.351369203634458e-21,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4149027470782776,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "upper": null,
#             "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#         },
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -13.332245808477035,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 5.351369203634458e-21,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.1296473513794565,
#                 "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#             },
#             "upper": null,
#             "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
#         }
#     ],
#     "desc": "Stationarity Test with Drift.",
#     "hyp_test_id": "2c9bfec3-8510-4927-bb38-283c0da97509"
# }

# %%
φ = [0.4, 0.6]
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════╕
# │ Test Statistic │  -2.32273 │
# ├────────────────┼───────────┤
# │ pvalue         │   0.42142 │
# ├────────────────┼───────────┤
# │ Lags           │   1       │
# ├────────────────┼───────────┤
# │ Number Obs     │ 998       │
# ╘════════════════╧═══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -2.322731650104134,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.4214195397042315,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.9678699195021783,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "upper": null,
#             "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -2.322731650104134,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.4214195397042315,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "params": [],
#             "sig": {
#                 "label": "5%",
#                 "value": 0.05,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.414898316296852,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "upper": null,
#             "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -2.322731650104134,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.4214195397042315,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "params": [],
#             "sig": {
#                 "label": "10%",
#                 "value": 0.1,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.129644744825171,
#                 "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#             },
#             "upper": null,
#             "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
#         }
#     ],
#     "desc": "Stationarity Test with Drift.",
#     "hyp_test_id": "82aec679-4932-424a-b67f-0bad0a642f54"
# }
