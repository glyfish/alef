# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test
#
# The Augmented Dickey-Fuller identifies stationarity in an autoregressive process. This is accomplished by testing for the presence of nonstationarity, called the unit root. For example consider the $\text{AR}(1)$ process,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \varepsilon_t
# \end{align}
# \tag{1}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0,\sigma^2)$ and independent. If $\lvert \varphi \rvert < 1$ it can be shown that $X_t$ is stationary. The unit root,
# $\lvert \varphi \rvert = 1$, is equivalent to brownian motion.
#
# ### Unit Root Form of $\text{AR}(1)$
#
# The unit root form of $\text{AR}(1)$ used in the analysis is constructed as follows. Subtracting $X_{t-1}$ from both sides of the expression
# for $\text{AR}(1)$ gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t
# \end{align}
# \tag{2}
# $
#
# Recall that the lag operator, $L$, is defined by, $L X_t = X_{t-1}, L^2 X_t = X_{t-2}, L^3 X_t = X_{t-3}, \ldots$. The difference operator is then given by
# $\Delta = 1 - L$ and let $\delta = \varphi - 1$. It follows that
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{3}
# $
#
# Stationarity implies that, $\delta < 0$, while nonstationarity, unit root, implies $\delta = 0$. If follows that ADF tests is a lower tail significance test
# with null hypothesis $\delta = 0$ and alternative hypothesis $\delta < 0$. Thus if the test fails $X_t$ is stationary.
#
# The lag polynomial is defined by,
#
# $
# \begin{align}
# \Phi^1(L) = 1 - \varphi L
# \end{align}
# \tag{4}
# $
#
# It follows that,
#
# $
# \begin{align}
# \Phi^1(L)X_t = \varepsilon_t
# \end{align}
# \tag{5}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^1(1) =  -\delta \\
# \Rightarrow& \delta = 1 - \varphi = 0
# \end{align}
# \tag{6}
# $
#
# ### Unit Root Form of $\text{AR}(q)$
#
# Following the procedure used for $\text{AR}(1)$ the unit root form of $\text{AR}(2)$ can be constructed. The $\text{AR}(2)$ lag polynomial is given by,
#
# $
# \begin{align}
# \Phi^2(L) = 1 - \varphi_1 L - \varphi_2 L^2
# \end{align}
# \tag{7}
# $
#
# If follows that,
#
# $
# \begin{align}
# &\Phi^2(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# \tag{8}
# $
#
# To obtain the unit root form subtract $X_{t-1}$ from both sides of $\text{AR}(2)$ to obtain,
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# \tag{9}
# $
#
# Next add and subtract $\varphi_3 X_{t-1}$ to obtain the final result,
#
# $
# \begin{align}
# & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t - \varphi_2 X_{t-1} \\
# \Rightarrow & \Delta X_t = \left( \varphi_2 + \varphi_1 - 1 \right) X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{10}
# $
#
# Let $\delta = \varphi_2 + \varphi_1 - 1$ to obtain the unit root form,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{11}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^2(1) = -\delta \\
# \Rightarrow& \delta = \varphi_1 + \varphi_2 - 1 = 0
# \end{align}
# \tag{12}
# $
#
# This procedure can be repeated for autoregressive processes of arbitrary order. $\text{AR}(q)$ is defined by
#
# $
# \begin{align}
# &\Phi^q(L) = 1 - \varphi_1 L + \varphi_2 L^2 - \cdots - \varphi_q L^q \\
# \Rightarrow & \Phi^q(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \cdots + + \varphi_q X_{t-q} + \varepsilon_t
# \end{align}
# \tag{13}
# $
#
# the unit root form is given by,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + C_1 \Delta X_{t-1} + C_2 \Delta X_{t-2} + \cdots + C_{q-1} \Delta X_{t- \left( q - 1 \right)} + \varepsilon_t
# \end{align}
# \tag{14}
# $
#
# where,
#
# $
# \begin{align}
# &\delta = \varphi_1 + \varphi_2 + \cdots + \varphi_q  -1\\
# &\Phi^q(1) = -\delta \\
# &C_i = -\sum_{j=i+1}^q \varphi_j
# \end{align}
# \tag{15}
# $
#
# ### $\text{AR}(1)$ Test Statistic
#
# The OLS estimate for the $\text{AR}(1)$ coefficient $\varphi$  is given by,
#
# $
# \begin{align}
# \hat{\varphi} = \frac{\sum_{t=1}^T X_t X_{t-1}}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{16}
# $
#
# Using $X_t = \Delta X_t + X_{t-1}$ and $\hat{\delta} = \hat{\varphi} - 1$ gives,
#
# $
# \begin{align}
# \hat{\delta} = \frac{\sum_{t=1}^T X_{t-1} \varepsilon_t}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{17}
# $
#
# From this expression it can be shown that,
#
# $
# \begin{align}
# &\text{E}(\hat{\delta}) = 0 \\
# &\text{Var}(\hat{\delta}) = \frac{\sigma}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{18}
# $
#
# The test statistic is given by,
#
# $
# \begin{align}
# t = \frac{\hat{\delta}}{\sqrt{\text{Var}({\hat{\delta}})}}
# \end{align}
# \tag{19}
# $
#
# The distribution of $t$ is not a standard distribution but has a stochastic integral representation that must be evaluated numerically, namely,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\int_0^1 B(s) dB(s)}{\sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# \tag{20}
# $
#
# where $B(s)$ is a Wiener process. The numerator integral can be evaluated to obtain,
#
# $
# \begin{align}
# \int_0^1 B(s) dB(s) = \frac{1}{2} \left[ B^2(1) - 1 \right]
# \end{align}
# \tag{21}
# $
#
# The final result is given by,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# \tag{22}
# $
#
# The ADF test is a lower tailed hypothesis test. If successful $\delta = 0$ and the time series is brownian motion. If testing a time series for stationarity, for $\delta$ as defined,
# $\delta > 0$ is desired so the test must fail.

# %% [markdown]
# ## Includes

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.plots import curve, bar
from lib.data import arima, adf, stats

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## ADF Distribution
#
# The probability distribution of the ADF test statistic,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# is computed by simulation.

# %%
nstep = 100
nsim = 10000
_, df = adf.create_df_source(nstep=nstep, nsim=nsim)

# %%
title = f"Dickey-Fuller Distribution PDF: nstep={nstep}, nsim={nsim}"
x, pdf = stats.compute_pdf_hist(df, xmin=-4.0, xmax=8.0)
bar(pdf, x, title=title, bar_width=0.9, ylabel=r"$p(x)$", xlabel=r"$x$", alpha=1.0)

# %%
title = f"Dickey-Fuller Distribution PDF: nstep={nstep}, nsim={nsim}"
x, cdf = stats.compute_cdf_hist(x, pdf)
bar(cdf, x, title=title, bar_width=0.9, ylabel=r"$P(x)$", xlabel=r"$x$", alpha=1.0)

# %% [markdown]
# ## ADF Test examples

# %%
nsample = 1000

# %% [markdown]
# ### $\text{AR}(1)$
#
# $\delta = 1 - \varphi$

# %%
φ = [0.5]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.7613      │
# ├────────────────┼───────────────┤
# │ pvalue         │   6.32665e-29 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -17.76131438558107, 'Label': '$t$'},
#    'PValue': {'Value': 6.326645285533362e-29, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -17.76131438558107, 'Label': '$t$'},
#    'PValue': {'Value': 6.326645285533362e-29, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -17.76131438558107, 'Label': '$t$'},
#    'PValue': {'Value': 6.326645285533362e-29, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [-0.5]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -8.57322   │
# ├────────────────┼─────────────┤
# │ pvalue         │   1.611e-14 │
# ├────────────────┼─────────────┤
# │ Lags           │  10         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 989         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.568   │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61655 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -8.573221647373675, 'Label': '$t$'},
#    'PValue': {'Value': 1.6110042214069153e-14, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5680043754709283, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -8.573221647373675, 'Label': '$t$'},
#    'PValue': {'Value': 1.6110042214069153e-14, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412749954552935, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -8.573221647373675, 'Label': '$t$'},
#    'PValue': {'Value': 1.6110042214069153e-14, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165541943930175, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.99]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════════╕
# │ Test Statistic │  -2.87484    │
# ├────────────────┼──────────────┤
# │ pvalue         │   0.00395941 │
# ├────────────────┼──────────────┤
# │ Lags           │   0          │
# ├────────────────┼──────────────┤
# │ Number Obs     │ 999          │
# ╘════════════════╧══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -2.874844610517216, 'Label': '$t$'},
#    'PValue': {'Value': 0.003959406471567269, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -2.874844610517216, 'Label': '$t$'},
#    'PValue': {'Value': 0.003959406471567269, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -2.874844610517216, 'Label': '$t$'},
#    'PValue': {'Value': 0.003959406471567269, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [1.0]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.205609 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.61183  │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': False,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': True,
#    'Statistic': {'Value': -0.20560880537294723, 'Label': '$t$'},
#    'PValue': {'Value': 0.6118301879587287, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679816723029334, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -0.20560880537294723, 'Label': '$t$'},
#    'PValue': {'Value': 0.6118301879587287, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412722092921209, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -0.20560880537294723, 'Label': '$t$'},
#    'PValue': {'Value': 0.6118301879587287, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165568281300424, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [-1.0]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -21.5464 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   2      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 997      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -21.546360079201055, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -21.546360079201055, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -21.546360079201055, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %% [markdown]
# ### $\text{AR}(2)$
#
# $\delta = 1 - \varphi_1 - \varphi_2$

# %%
φ = [0.2, 0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -11.7955      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.78113e-21 │
# ├────────────────┼───────────────┤
# │ Lags           │   4           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 995           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -11.795459933281077, 'Label': '$t$'},
#    'PValue': {'Value': 1.7811258062919553e-21, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.567990698719729, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -11.795459933281077, 'Label': '$t$'},
#    'PValue': {'Value': 1.7811258062919553e-21, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.941273316956744, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -11.795459933281077, 'Label': '$t$'},
#    'PValue': {'Value': 1.7811258062919553e-21, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.616555780923252, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.3, -0.4]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -29.5379 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   1      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 998      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -29.5378557548916, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -29.5378557548916, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -29.5378557548916, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.2, 0.8]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.723222 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.402825 │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': False,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': True,
#    'Statistic': {'Value': -0.7232223189524707, 'Label': '$t$'},
#    'PValue': {'Value': 0.4028249850120727, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679839221127625, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -0.7232223189524707, 'Label': '$t$'},
#    'PValue': {'Value': 0.4028249850120727, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412724853659513, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -0.7232223189524707, 'Label': '$t$'},
#    'PValue': {'Value': 0.4028249850120727, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165565671073312, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %% [markdown]
# ### $\text{AR}(3)$
#
# $\delta = 1 - \varphi_1 - \varphi_2 - \varphi_3$

# %%
φ = [0.2, 0.3, 0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -6.41757     │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.17962e-09 │
# ├────────────────┼───────────────┤
# │ Lags           │   3           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 996           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -6.417574434253444, 'Label': '$t$'},
#    'PValue': {'Value': 1.1796160591552856e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.567988435307495, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -6.417574434253444, 'Label': '$t$'},
#    'PValue': {'Value': 1.1796160591552856e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412730391965518, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -6.417574434253444, 'Label': '$t$'},
#    'PValue': {'Value': 1.1796160591552856e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165560435054842, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.2, 0.3, -0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -19.2568 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   2      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 997      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -19.25682044513974, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -19.25682044513974, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -19.25682044513974, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.2, 0.3, 0.5]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -1.43068  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.142313 │
# ├────────────────┼────────────┤
# │ Lags           │   2        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 997        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': False,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY: 'STATIONARITY'>,
#  'Description': 'Stationarity Test',
#  'TestData': [{'Status': True,
#    'Statistic': {'Value': -1.4306846903023176, 'Label': '$t$'},
#    'PValue': {'Value': 0.14231262744315704, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -2.5679861764430703, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -1.4306846903023176, 'Label': '$t$'},
#    'PValue': {'Value': 0.14231262744315704, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -1.9412727620001924, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -1.4306846903023176, 'Label': '$t$'},
#    'PValue': {'Value': 0.14231262744315704, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -1.6165563055663268, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %% [markdown]
# ### AR(1) with Offset

# %%
μ = 1.0
γ = 0.0

# %%
φ = [0.5]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.6026      │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.91473e-30 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#  'Description': 'Stationarity Test with Constant Offset.',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -17.602592734315365, 'Label': '$t$'},
#    'PValue': {'Value': 3.914732671659544e-30, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -17.602592734315365, 'Label': '$t$'},
#    'PValue': {'Value': 3.914732671659544e-30, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -17.602592734315365, 'Label': '$t$'},
#    'PValue': {'Value': 3.914732671659544e-30, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.99]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -6.78279     │
# ├────────────────┼───────────────┤
# │ pvalue         │   2.47506e-09 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#  'Description': 'Stationarity Test with Constant Offset.',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -6.78278608665152, 'Label': '$t$'},
#    'PValue': {'Value': 2.4750568173445557e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -6.78278608665152, 'Label': '$t$'},
#    'PValue': {'Value': 2.4750568173445557e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -6.78278608665152, 'Label': '$t$'},
#    'PValue': {'Value': 2.4750568173445557e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [1.0]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.36325  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.980067 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': False,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_OFFSET: 'STATIONARITY_OFFSET'>,
#  'Description': 'Stationarity Test with Constant Offset.',
#  'TestData': [{'Status': True,
#    'Statistic': {'Value': 0.36324984087829193, 'Label': '$t$'},
#    'PValue': {'Value': 0.9800673584185101, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.4369127451400474, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': 0.36324984087829193, 'Label': '$t$'},
#    'PValue': {'Value': 0.9800673584185101, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -2.864437475834273, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': 0.36324984087829193, 'Label': '$t$'},
#    'PValue': {'Value': 0.9800673584185101, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -2.568312754566378, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %% [markdown]
# ### $\text{AR}(1)$ with Drift

# %%
μ = 1.0
γ = 0.01

# %%
φ = [0.5]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════╕
# │ Test Statistic │ -19.119 │
# ├────────────────┼─────────┤
# │ pvalue         │   0     │
# ├────────────────┼─────────┤
# │ Lags           │   0     │
# ├────────────────┼─────────┤
# │ Number Obs     │ 999     │
# ╘════════════════╧═════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#  'Description': 'Stationarity Test with Drift.',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -19.11899923467599, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -19.11899923467599, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -19.11899923467599, 'Label': '$t$'},
#    'PValue': {'Value': 0.0, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [-0.5]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -10.6554      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.03961e-16 │
# ├────────────────┼───────────────┤
# │ Lags           │   9           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 990           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96794 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41493 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12967 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#  'Description': 'Stationarity Test with Drift.',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -10.655404558983957, 'Label': '$t$'},
#    'PValue': {'Value': 1.0396142107986756e-16, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.967943688919601, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -10.655404558983957, 'Label': '$t$'},
#    'PValue': {'Value': 1.0396142107986756e-16, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -3.4149340137050537, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -10.655404558983957, 'Label': '$t$'},
#    'PValue': {'Value': 1.0396142107986756e-16, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -3.129665744930171, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.9]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, report = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.26866     │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.45871e-09 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#  'Description': 'Stationarity Test with Drift.',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -7.26866231466316, 'Label': '$t$'},
#    'PValue': {'Value': 3.4587106713909024e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -7.26866231466316, 'Label': '$t$'},
#    'PValue': {'Value': 3.4587106713909024e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -7.26866231466316, 'Label': '$t$'},
#    'PValue': {'Value': 3.4587106713909024e-09, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [1.0]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, report = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.372452 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.987678 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': False,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#  'Description': 'Stationarity Test with Drift.',
#  'TestData': [{'Status': True,
#    'Statistic': {'Value': -0.37245229224279086, 'Label': '$t$'},
#    'PValue': {'Value': 0.9876777547892774, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.967860781661831, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -0.37245229224279086, 'Label': '$t$'},
#    'PValue': {'Value': 0.9876777547892774, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -3.4148938944043334, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': -0.37245229224279086, 'Label': '$t$'},
#    'PValue': {'Value': 0.9876777547892774, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -3.1296421434972537, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %% [markdown]
# ### $\text{AR}(2)$ with Drift

# %%
φ = [0.2, 0.3]
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, report = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════════╕
# │ Test Statistic │ -13.4859     │
# ├────────────────┼──────────────┤
# │ pvalue         │   3.5896e-21 │
# ├────────────────┼──────────────┤
# │ Lags           │   1          │
# ├────────────────┼──────────────┤
# │ Number Obs     │ 998          │
# ╘════════════════╧══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': True,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#  'Description': 'Stationarity Test with Drift.',
#  'TestData': [{'Status': False,
#    'Statistic': {'Value': -13.485914734788041, 'Label': '$t$'},
#    'PValue': {'Value': 3.589603838646359e-21, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.9678699195021783, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -13.485914734788041, 'Label': '$t$'},
#    'PValue': {'Value': 3.589603838646359e-21, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -3.414898316296852, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': False,
#    'Statistic': {'Value': -13.485914734788041, 'Label': '$t$'},
#    'PValue': {'Value': 3.589603838646359e-21, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -3.129644744825171, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}

# %%
φ = [0.4, 0.6]
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, report = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.630775 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.99701  │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
report.dict
# Out:
# {'Status': False,
#  'HypothesisType': <HypothesisType.LOWER_TAIL: 'LOWER_TAIL'>,
#  'HypothesisTestType': <HypothesisTestType.STATIONARITY_DRIFT: 'STATIONARITY_DRIFT'>,
#  'Description': 'Stationarity Test with Drift.',
#  'TestData': [{'Status': True,
#    'Statistic': {'Value': 0.6307754094993868, 'Label': '$t$'},
#    'PValue': {'Value': 0.9970097628969801, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.01, 'Label': '1%'},
#    'Lower Critical Value': {'Value': -3.9678699195021783, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': 0.6307754094993868, 'Label': '$t$'},
#    'PValue': {'Value': 0.9970097628969801, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.05, 'Label': '5%'},
#    'Lower Critical Value': {'Value': -3.414898316296852, 'Label': '$t_L$'},
#    'Upper Critical Value': None},
#   {'Status': True,
#    'Statistic': {'Value': 0.6307754094993868, 'Label': '$t$'},
#    'PValue': {'Value': 0.9970097628969801, 'Label': '$p-value$'},
#    'Parameters': [],
#    'Significance': {'Value': 0.1, 'Label': '10%'},
#    'Lower Critical Value': {'Value': -3.129644744825171, 'Label': '$t_L$'},
#    'Upper Critical Value': None}]}
