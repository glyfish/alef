# %% [markdown]
# # Augmented Dickey-Fuller (ADF) Test
#
# The Augmented Dickey-Fuller identifies stationarity in an autoregressive process. This is accomplished by testing for the presence of nonstationarity, called the unit root. For example consider the $\text{AR}(1)$ process,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \varepsilon_t
# \end{align}
# \tag{1}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0,\sigma^2)$ and independent. If $\lvert \varphi \rvert < 1$ it can be shown that $X_t$ is stationary. The unit root,
# $\lvert \varphi \rvert = 1$, is equivalent to brownian motion.
#
# ### Unit Root Form of $\text{AR}(1)$
#
# The unit root form of $\text{AR}(1)$ used in the analysis is constructed as follows. Subtracting $X_{t-1}$ from both sides of the expression
# for $\text{AR}(1)$ gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t
# \end{align}
# \tag{2}
# $
#
# Recall that the lag operator, $L$, is defined by, $L X_t = X_{t-1}, L^2 X_t = X_{t-2}, L^3 X_t = X_{t-3}, \ldots$. The difference operator is then given by
# $\Delta = 1 - L$ and let $\delta = \varphi - 1$. It follows that
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi - 1\right) X_{t-1} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{3}
# $
#
# Stationarity implies that, $\delta < 0$, while nonstationarity, unit root, implies $\delta = 0$. If follows that ADF tests is a lower tail significance test
# with null hypothesis $\delta = 0$ and alternative hypothesis $\delta < 0$. Thus if the test fails $X_t$ is stationary.
#
# The lag polynomial is defined by,
#
# $
# \begin{align}
# \Phi^1(L) = 1 - \varphi L
# \end{align}
# \tag{4}
# $
#
# It follows that,
#
# $
# \begin{align}
# \Phi^1(L)X_t = \varepsilon_t
# \end{align}
# \tag{5}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^1(1) =  -\delta \\
# \Rightarrow& \delta = 1 - \varphi = 0
# \end{align}
# \tag{6}
# $
#
# ### Unit Root Form of $\text{AR}(q)$
#
# Following the procedure used for $\text{AR}(1)$ the unit root form of $\text{AR}(2)$ can be constructed. The $\text{AR}(2)$ lag polynomial is given by,
#
# $
# \begin{align}
# \Phi^2(L) = 1 - \varphi_1 L - \varphi_2 L^2
# \end{align}
# \tag{7}
# $
#
# If follows that,
#
# $
# \begin{align}
# &\Phi^2(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# \tag{8}
# $
#
# To obtain the unit root form subtract $X_{t-1}$ from both sides of $\text{AR}(2)$ to obtain,
#
# $
# \begin{align}
# & X_t - X_{t-1} = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t \\
# \Rightarrow & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t
# \end{align}
# \tag{9}
# $
#
# Next add and subtract $\varphi_3 X_{t-1}$ to obtain the final result,
#
# $
# \begin{align}
# & \Delta X_t = \left( \varphi_1 - 1 \right) X_{t-1} + \varphi_2 X_{t-1} + \varphi_2 X_{t-2} + \varepsilon_t - \varphi_2 X_{t-1} \\
# \Rightarrow & \Delta X_t = \left( \varphi_2 + \varphi_1 - 1 \right) X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{10}
# $
#
# Let $\delta = \varphi_2 + \varphi_1 - 1$ to obtain the unit root form,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + \varphi_2 \Delta X_{t-1} + \varepsilon_t
# \end{align}
# \tag{11}
# $
#
# The unit root is defined in terms of the lag polynomial by,
#
# $
# \begin{align}
# &\Phi^2(1) = -\delta \\
# \Rightarrow& \delta = \varphi_1 + \varphi_2 - 1 = 0
# \end{align}
# \tag{12}
# $
#
# This procedure can be repeated for autoregressive processes of arbitrary order. $\text{AR}(q)$ is defined by
#
# $
# \begin{align}
# &\Phi^q(L) = 1 - \varphi_1 L + \varphi_2 L^2 - \cdots - \varphi_q L^q \\
# \Rightarrow & \Phi^q(L) X_t = \varepsilon_t \\
# \Rightarrow & X_t = \varphi_1 X_{t-1} + \varphi_2 X_{t-2} + \cdots + + \varphi_q X_{t-q} + \varepsilon_t
# \end{align}
# \tag{13}
# $
#
# the unit root form is given by,
#
# $
# \begin{align}
# \Delta X_t = \delta X_{t-1} + C_1 \Delta X_{t-1} + C_2 \Delta X_{t-2} + \cdots + C_{q-1} \Delta X_{t- \left( q - 1 \right)} + \varepsilon_t
# \end{align}
# \tag{14}
# $
#
# where,
#
# $
# \begin{align}
# &\delta = \varphi_1 + \varphi_2 + \cdots + \varphi_q  -1\\
# &\Phi^q(1) = -\delta \\
# &C_i = -\sum_{j=i+1}^q \varphi_j
# \end{align}
# \tag{15}
# $
#
# ### $\text{AR}(1)$ Test Statistic
#
# The OLS estimate for the $\text{AR}(1)$ coefficient $\varphi$  is given by,
#
# $
# \begin{align}
# \hat{\varphi} = \frac{\sum_{t=1}^T X_t X_{t-1}}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{16}
# $
#
# Using $X_t = \Delta X_t + X_{t-1}$ and $\hat{\delta} = \hat{\varphi} - 1$ gives,
#
# $
# \begin{align}
# \hat{\delta} = \frac{\sum_{t=1}^T X_{t-1} \varepsilon_t}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{17}
# $
#
# From this expression it can be shown that,
#
# $
# \begin{align}
# &\text{E}(\hat{\delta}) = 0 \\
# &\text{Var}(\hat{\delta}) = \frac{\sigma}{\sum_{t=1}^T X^2_{t-1}}
# \end{align}
# \tag{18}
# $
#
# The test statistic is given by,
#
# $
# \begin{align}
# t = \frac{\hat{\delta}}{\sqrt{\text{Var}({\hat{\delta}})}}
# \end{align}
# \tag{19}
# $
#
# The distribution of $t$ is not a standard distribution but has a stochastic integral representation that must be evaluated numerically, namely,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\int_0^1 B(s) dB(s)}{\sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# \tag{20}
# $
#
# where $B(s)$ is a Wiener process. The numerator integral can be evaluated to obtain,
#
# $
# \begin{align}
# \int_0^1 B(s) dB(s) = \frac{1}{2} \left[ B^2(1) - 1 \right]
# \end{align}
# \tag{21}
# $
#
# The final result is given by,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# \tag{22}
# $
#
# The ADF test is a lower tailed hypothesis test. If successful $\delta = 0$ and the time series is brownian motion. If testing a time series for stationarity, for $\delta$ as defined,
# $\delta > 0$ is desired so the test must fail.

# %% [markdown]
# ## Includes

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.plots import curve, bar
from lib.data import arima, adf, stats

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## ADF Distribution
#
# The probability distribution of the ADF test statistic,
#
# $
# \begin{align}
# T \hat{\delta} \sim \frac{\frac{1}{2} \left[ B^2(1) - 1 \right]}{ \sqrt{\int_0^1 B^2(s) ds}}
# \end{align}
# $
#
# is computed by simulation.

# %%
nstep = 100
nsim = 10000
_, df = adf.create_df_source(nstep=nstep, nsim=nsim)

# %%
title = f"Dickey-Fuller Distribution PDF: nstep={nstep}, nsim={nsim}"
x, pdf = stats.compute_pdf_hist(df, xmin=-4.0, xmax=8.0)
bar(pdf, x, title=title, bar_width=0.9, ylabel=r"$p(x)$", xlabel=r"$x$", alpha=1.0)

# %%
title = f"Dickey-Fuller Distribution PDF: nstep={nstep}, nsim={nsim}"
x, cdf = stats.compute_cdf_hist(x, pdf)
bar(cdf, x, title=title, bar_width=0.9, ylabel=r"$P(x)$", xlabel=r"$x$", alpha=1.0)

# %% [markdown]
# ## ADF Test examples

# %%
nsample = 1000

# %% [markdown]
# ### $\text{AR}(1)$
#
# $\delta = 1 - \varphi$

# %%
φ = [0.5]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s, max_lags=12)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.2861      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.06915e-28 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -18.671161852699644,
#                 "test_id": "67eda706-736c-4de4-9346-43390ee91410"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.6510412708722876e-29,
#                 "test_id": "67eda706-736c-4de4-9346-43390ee91410"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "67eda706-736c-4de4-9346-43390ee91410"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334,
#                 "test_id": "67eda706-736c-4de4-9346-43390ee91410"
#             },
#             "upper": null,
# ...

# %%
φ = [-0.5]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -55.2541 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   0      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 999      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "test_id": "f2d55d75-f9fe-45b5-8fae-f6d1c1808cc4",
#                 "label": "$t$",
#                 "value": -55.74763178904028
#             },
#             "pval": {
#                 "test_id": "f2d55d75-f9fe-45b5-8fae-f6d1c1808cc4",
#                 "label": "$p-value$",
#                 "value": 0.0
#             },
#             "params": [],
#             "sig": {
#                 "test_id": "f2d55d75-f9fe-45b5-8fae-f6d1c1808cc4",
#                 "label": "1%",
#                 "value": 0.01
#             },
#             "lower": {
#                 "test_id": "f2d55d75-f9fe-45b5-8fae-f6d1c1808cc4",
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334
#             },
#             "upper": null,
# ...

# %%
φ = [0.99]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -1.93595   │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.0504895 │
# ├────────────────┼─────────────┤
# │ Lags           │   0         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 999         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "test_id": "877f78bf-6035-4895-a845-3583c62dbfcc",
#                 "label": "$t$",
#                 "value": -1.801646237212409
#             },
#             "pval": {
#                 "test_id": "877f78bf-6035-4895-a845-3583c62dbfcc",
#                 "label": "$p-value$",
#                 "value": 0.06808609127981813
#             },
#             "params": [],
#             "sig": {
#                 "test_id": "877f78bf-6035-4895-a845-3583c62dbfcc",
#                 "label": "1%",
#                 "value": 0.01
#             },
#             "lower": {
#                 "test_id": "877f78bf-6035-4895-a845-3583c62dbfcc",
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334
#             },
#             "upper": null,
# ...

# %%
φ = [1.0]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.484057 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.502665 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -2.4015614898186652,
#                 "test_id": "dc7ef78f-a217-4fdc-b486-5ce665dce979"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.015744722865781328,
#                 "test_id": "dc7ef78f-a217-4fdc-b486-5ce665dce979"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "dc7ef78f-a217-4fdc-b486-5ce665dce979"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.567988435307495,
#                 "test_id": "dc7ef78f-a217-4fdc-b486-5ce665dce979"
#             },
#             "upper": null,
# ...

# %%
φ = [-1.0]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -981.729 │
# ├────────────────┼──────────┤
# │ pvalue         │    0     │
# ├────────────────┼──────────┤
# │ Lags           │    0     │
# ├────────────────┼──────────┤
# │ Number Obs     │  999     │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -1025.8674081674176,
#                 "test_id": "ca2fa450-5cfa-4440-b7cd-377704b252f6"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "test_id": "ca2fa450-5cfa-4440-b7cd-377704b252f6"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "ca2fa450-5cfa-4440-b7cd-377704b252f6"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679816723029334,
#                 "test_id": "ca2fa450-5cfa-4440-b7cd-377704b252f6"
#             },
#             "upper": null,
# ...

# %% [markdown]
# ### $\text{AR}(2)$
#
# $\delta = 1 - \varphi_1 - \varphi_2$

# %%
φ = [0.2, 0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -13.9307      │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.42541e-25 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -11.763766471432856,
#                 "test_id": "e0103645-4259-42f3-b237-1deee5b41351"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 2.0545123570469088e-21,
#                 "test_id": "e0103645-4259-42f3-b237-1deee5b41351"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "e0103645-4259-42f3-b237-1deee5b41351"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679861764430703,
#                 "test_id": "e0103645-4259-42f3-b237-1deee5b41351"
#             },
#             "upper": null,
# ...

# %%
φ = [0.3, -0.4]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -29.1845 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   1      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 998      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56798 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -30.756140964877556,
#                 "test_id": "52fd901b-55db-4c0c-9698-6ae68cf8a8af"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "test_id": "52fd901b-55db-4c0c-9698-6ae68cf8a8af"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "52fd901b-55db-4c0c-9698-6ae68cf8a8af"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679839221127625,
#                 "test_id": "52fd901b-55db-4c0c-9698-6ae68cf8a8af"
#             },
#             "upper": null,
# ...

# %%
φ = [0.2, 0.8]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │   0.428126 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.807852 │
# ├────────────────┼────────────┤
# │ Lags           │   6        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 993        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.568   │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.19460833475269404,
#                 "test_id": "238bca91-f155-4673-9860-3787bfc458d7"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.6159021759671003,
#                 "test_id": "238bca91-f155-4673-9860-3787bfc458d7"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "238bca91-f155-4673-9860-3787bfc458d7"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679839221127625,
#                 "test_id": "238bca91-f155-4673-9860-3787bfc458d7"
#             },
#             "upper": null,
# ...

# %% [markdown]
# ### $\text{AR}(3)$
#
# $\delta = 1 - \varphi_1 - \varphi_2 - \varphi_3$

# %%
φ = [0.2, 0.3, 0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -6.64645     │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.70557e-10 │
# ├────────────────┼───────────────┤
# │ Lags           │   2           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 997           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -6.615954439619405,
#                 "test_id": "5c0cd92a-c937-425a-8348-4ec9803094ed"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 4.3267748278498564e-10,
#                 "test_id": "5c0cd92a-c937-425a-8348-4ec9803094ed"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "5c0cd92a-c937-425a-8348-4ec9803094ed"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679861764430703,
#                 "test_id": "5c0cd92a-c937-425a-8348-4ec9803094ed"
#             },
#             "upper": null,
# ...

# %%
φ = [0.2, 0.3, -0.3]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -19.6449 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   2      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 997      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -18.048704354041305,
#                 "test_id": "9df7dae2-8b50-4f5d-b618-0c81a9914446"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 4.984010863118495e-29,
#                 "test_id": "9df7dae2-8b50-4f5d-b618-0c81a9914446"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "9df7dae2-8b50-4f5d-b618-0c81a9914446"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -2.5679861764430703,
#                 "test_id": "9df7dae2-8b50-4f5d-b618-0c81a9914446"
#             },
#             "upper": null,
# ...

# %%
φ = [0.2, 0.3, 0.501]
title = f"AR(1) ADF Example: φ={φ}, δ={format(1.0-φ[0]-φ[1]-φ[2], '1.2f')}"

t, s = arima.create_ar_source(φ=φ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.689242 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.417142 │
# ├────────────────┼────────────┤
# │ Lags           │   2        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 997        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -2.56799 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -1.94127 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -1.61656 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "test_id": "7841e0d7-4c6f-43f1-a552-52398bd34eba",
#                 "label": "$t$",
#                 "value": -0.6892417023167169
#             },
#             "pval": {
#                 "test_id": "7841e0d7-4c6f-43f1-a552-52398bd34eba",
#                 "label": "$p-value$",
#                 "value": 0.41714230828301796
#             },
#             "params": [],
#             "sig": {
#                 "test_id": "7841e0d7-4c6f-43f1-a552-52398bd34eba",
#                 "label": "1%",
#                 "value": 0.01
#             },
#             "lower": {
#                 "test_id": "7841e0d7-4c6f-43f1-a552-52398bd34eba",
#                 "label": "$t_L$",
#                 "value": -2.5679861764430703
#             },
#             "upper": null,
# ...

# %% [markdown]
# ### AR(1) with Offset

# %%
μ = 1.0
γ = 0.0

# %%
φ = [0.5]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -17.4041      │
# ├────────────────┼───────────────┤
# │ pvalue         │   4.92812e-30 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43692 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_OFFSET",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -20.045428307402954,
#                 "test_id": "90e77b2b-5004-426f-8e2b-bba0b55f2dea"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "test_id": "90e77b2b-5004-426f-8e2b-bba0b55f2dea"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "90e77b2b-5004-426f-8e2b-bba0b55f2dea"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4369127451400474,
#                 "test_id": "90e77b2b-5004-426f-8e2b-bba0b55f2dea"
#             },
#             "upper": null,
# ...

# %%
φ = [0.99]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -6.73434     │
# ├────────────────┼───────────────┤
# │ pvalue         │   3.23603e-09 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_OFFSET",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -6.7343390151154825,
#                 "test_id": "39d7d7fb-abed-4344-bc46-e9cb745a7a68"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 3.236025409643968e-09,
#                 "test_id": "39d7d7fb-abed-4344-bc46-e9cb745a7a68"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "39d7d7fb-abed-4344-bc46-e9cb745a7a68"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4369127451400474,
#                 "test_id": "39d7d7fb-abed-4344-bc46-e9cb745a7a68"
#             },
#             "upper": null,
# ...

# %%
φ = [1.0]
title = f"AR(1) with Offset ADF Example: φ={φ}, μ={μ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_offset_source(φ=φ, μ=μ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_offset_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.452536 │
# ├────────────────┼────────────┤
# │ pvalue         │   0.900951 │
# ├────────────────┼────────────┤
# │ Lags           │   0        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 999        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43691 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86444 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56831 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_OFFSET",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.4525360545781105,
#                 "test_id": "90dbda80-6e0b-4de9-94a3-3654c8baa961"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.9009507386952538,
#                 "test_id": "90dbda80-6e0b-4de9-94a3-3654c8baa961"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "90dbda80-6e0b-4de9-94a3-3654c8baa961"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.4369127451400474,
#                 "test_id": "90dbda80-6e0b-4de9-94a3-3654c8baa961"
#             },
#             "upper": null,
# ...

# %% [markdown]
# ### $\text{AR}(1)$ with Drift

# %%
μ = 1.0
γ = 0.01

# %%
φ = [0.5]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -16.3916 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   1      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 998      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -16.391641219866276,
#                 "test_id": "3f246291-bf23-484b-8b16-445419b5d1ec"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "test_id": "3f246291-bf23-484b-8b16-445419b5d1ec"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "3f246291-bf23-484b-8b16-445419b5d1ec"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.9678699195021783,
#                 "test_id": "3f246291-bf23-484b-8b16-445419b5d1ec"
#             },
#             "upper": null,
# ...

# %%
φ = [-0.5]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤══════════╕
# │ Test Statistic │ -29.4524 │
# ├────────────────┼──────────┤
# │ pvalue         │   0      │
# ├────────────────┼──────────┤
# │ Lags           │   1      │
# ├────────────────┼──────────┤
# │ Number Obs     │ 998      │
# ╘════════════════╧══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -29.452433046242426,
#                 "test_id": "c727b990-8865-4774-9855-6f9092331485"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.0,
#                 "test_id": "c727b990-8865-4774-9855-6f9092331485"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "c727b990-8865-4774-9855-6f9092331485"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.9678699195021783,
#                 "test_id": "c727b990-8865-4774-9855-6f9092331485"
#             },
#             "upper": null,
# ...

# %%
φ = [0.9]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$")

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │  -7.50197     │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.00858e-09 │
# ├────────────────┼───────────────┤
# │ Lags           │   0           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 999           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -7.501967898884877,
#                 "test_id": "d4d5184f-3871-4971-add8-d0d266349aba"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.008581178165369e-09,
#                 "test_id": "d4d5184f-3871-4971-add8-d0d266349aba"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "d4d5184f-3871-4971-add8-d0d266349aba"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.967860781661831,
#                 "test_id": "d4d5184f-3871-4971-add8-d0d266349aba"
#             },
#             "upper": null,
# ...

# %%
φ = [1.0]
title = f"AR(1) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │  -0.0171531 │
# ├────────────────┼─────────────┤
# │ pvalue         │   0.994055  │
# ├────────────────┼─────────────┤
# │ Lags           │   0         │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 999         │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96786 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.41489 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.017153123368661694,
#                 "test_id": "d2fe0af9-c8fd-4fbe-9859-d07a721175c4"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.9940553498225367,
#                 "test_id": "d2fe0af9-c8fd-4fbe-9859-d07a721175c4"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "d2fe0af9-c8fd-4fbe-9859-d07a721175c4"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.967860781661831,
#                 "test_id": "d2fe0af9-c8fd-4fbe-9859-d07a721175c4"
#             },
#             "upper": null,
# ...

# %% [markdown]
# ### $\text{AR}(2)$ with Drift

# %%
φ = [0.2, 0.3]
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤═══════════════╕
# │ Test Statistic │ -14.0029      │
# ├────────────────┼───────────────┤
# │ pvalue         │   1.09084e-21 │
# ├────────────────┼───────────────┤
# │ Lags           │   1           │
# ├────────────────┼───────────────┤
# │ Number Obs     │ 998           │
# ╘════════════════╧═══════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "PASSED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "FAILED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -14.00286603977872,
#                 "test_id": "1aa80bf8-c13c-4f0b-bbf6-fab7b8d0590a"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 1.0908389815620994e-21,
#                 "test_id": "1aa80bf8-c13c-4f0b-bbf6-fab7b8d0590a"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "1aa80bf8-c13c-4f0b-bbf6-fab7b8d0590a"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.9678699195021783,
#                 "test_id": "1aa80bf8-c13c-4f0b-bbf6-fab7b8d0590a"
#             },
#             "upper": null,
# ...

# %%
φ = [0.4, 0.6]
title = f"AR(2) with Drift ADF Example: φ={φ}, μ={μ}, γ={γ}, δ={format(1.0-φ[0]-φ[1], '1.2f')}"

t, s = arima.create_ar_drift_source(φ=φ, μ=μ, γ=γ, npts=nsample)
curve(s, t, lw=1, title=title, xlabel=r"$t$", ylabel=r"$S_t$", title_offset=0.075)

# %%
result, result_model = adf.compute_adf_drift_test(s)
result.summary()
# Out:
# ╒════════════════╤════════════╕
# │ Test Statistic │  -0.31843  │
# ├────────────────┼────────────┤
# │ pvalue         │   0.989083 │
# ├────────────────┼────────────┤
# │ Lags           │   1        │
# ├────────────────┼────────────┤
# │ Number Obs     │ 998        │
# ╘════════════════╧════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.96787 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -3.4149  │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -3.12964 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "STATIONARITY_DRIFT",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "label": "$t$",
#                 "value": -0.3184303643172183,
#                 "test_id": "e50f2109-c392-4ce5-ac67-1cb84e390c33"
#             },
#             "pval": {
#                 "label": "$p-value$",
#                 "value": 0.9890827561082697,
#                 "test_id": "e50f2109-c392-4ce5-ac67-1cb84e390c33"
#             },
#             "params": [],
#             "sig": {
#                 "label": "1%",
#                 "value": 0.01,
#                 "test_id": "e50f2109-c392-4ce5-ac67-1cb84e390c33"
#             },
#             "lower": {
#                 "label": "$t_L$",
#                 "value": -3.9678699195021783,
#                 "test_id": "e50f2109-c392-4ce5-ac67-1cb84e390c33"
#             },
#             "upper": null,
# ...
