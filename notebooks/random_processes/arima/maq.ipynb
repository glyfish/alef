# %% [markdown]
# # MA(q)
#
# The moving average model of order $q$, denoted by $\text{MA}(q)$, is defined by,
#
# $
# \begin{align}
# X_t = \sum_{i=1}^q \vartheta_i \varepsilon_{t-i} + \varepsilon_t
# \end{align}
# \tag{1}
# $
#
# where $\varepsilon_t$ are independent and identically distributed random variables with distribution,
#
# $
# \begin{align}
# \varepsilon_i \sim \text{Normal}(0, \sigma)
# \end{align}
# \tag{2}
# $
#
# It follows that,
#
# $
# \begin{align}
# &\text{E}[\varepsilon_t] = 0 \\
# &\text{E}[\varepsilon_t^2] = \sigma^2 \\
# &\text{E}[\varepsilon_t \varepsilon_s] = \delta_{ts} \sigma^2
# \end{align}
# \tag{3}
# $
#
# For $\text{MA}(q)$ it can be shown that,
#
# $
# \begin{align}
# &\text{E}[X_t] = 0 \\
# &\text{E}[X_t^2] = \nu^q_t = \sigma^2 \left( \sum_{i=1}^q \vartheta_i^2 + 1 \right) \\
# &\text{E}[X_t X_{t+n}] = \sigma^2 \left( \sum_{i=i}^{q-n} \vartheta_i \vartheta_{i+n} + \vartheta_n \right)
# \end{align}
# \tag{4}
# $
#
# The autocorrelation is defined by,
#
# $
# \begin{align}
# \rho_n = \frac{\text{E}[X_t X_{t+n}]}{\text{E}[X_t^2]}
# \end{align}
# \tag{5}
# $
#
# Note that $\gamma_n$ is independent of $t$. This is in contrast to $\text{AR}(1)$ which depends on $t$. Also, for $n \geq q$ it is seen that $\gamma_n=0$.
#
# ### Example $\text{MA}(1)$
#
# First consider $\text{MA}(1)$,
#
# $
# \begin{align}
# X_t = \varepsilon_t + \vartheta_1 \varepsilon_{t-1}
# \end{align}
# \tag{6}
# $
#
# The moments are given by,
#
# $
# \begin{align}
# &\text{E}[X_t] = 0 \\
# &\nu^1_t = \sigma^2 \left( \vartheta_1^2 + 1 \right) \\
# \end{align}
# \tag{7}
# $
#
# For $n=1$,
#
# $
# \begin{align}
# &\text{E}[X_t X_{t+1}] = \sigma^2 \theta_1 \\
# &\rho_1 = \theta_1
# \end{align}
# \tag{8}
# $
#
# and $n > 2$,
#
# $
# \begin{align}
# &\text{E}[X_t X_{t+2}] = 0 \\
# &\rho_n = 0
# \end{align}
# \tag{9}
# $
#
# ### Example $\text{MA}(2)$
#
# Next consider $\text{MA}(2)$,
#
# $
# \begin{align}
# X_t = \varepsilon_t + \vartheta_1 \varepsilon_{t-1} + \vartheta_2 \varepsilon_{t-2}
# \end{align}
# \tag{10}
# $
#
# The moments are given by,
#
# $
# \begin{align}
# &\text{E}[X_t] = 0 \\
# &\nu^2_t = \sigma^2 \left( \vartheta_1^2 + \vartheta_2^2 + 1 \right) \\
# \end{align}
# \tag{11}
# $
#
# For $n=1$,
#
# $
# \begin{align}
# &\text{E}[X_t X_{t+1}] = \sigma^2 \left( \vartheta_1 \vartheta_2 + \vartheta_1 \right) \\
# &\rho_1 = \vartheta_1 \vartheta_2 + \vartheta_1 + \vartheta_2
# \end{align}
# \tag{12}
# $
#
# For $n=2$,
#
# $
# \begin{align}
# &\text{E}[X_t X_{t+1}] = \sigma^2 \vartheta_2 \\
# &\rho_2 = \vartheta_2
# \end{align}
# \tag{13}
# $
#
# and $n>2$,
#
# $
# \begin{align}
# &\text{E}[X_t X_{t+1}] = 0 \\
# &\rho_n = 0
# \end{align}
# \tag{14}
# $
#
# ### Relation to $\text{AR}(1)$
# AR(1) is related to $\text{MA}(\infty)$. To see this consider $\text{AR}(1)$,
#
# $
# \begin{align}
# X_t = \left( 1 - \varphi L \right)^{-1} \varepsilon_t
# \end{align}
# \tag{15}
# $
#
# where $L$ is the lag operator,
#
# $
# \begin{align}
# L X_t &= X_{t-1} \\
# L^2 X_t &= X_{t-2} \\
# L^3 X_t &= X_{t-3} \\
# &\vdots
# \end{align}
# \tag{16}
# $
#
# In the limit $t \to \infty$ it can be shown that for $\lvert \varphi \rvert < 1$,
#
# $
# \begin{align}
# \left( 1 - \varphi L \right)^{-1} = \sum_{i = 0}^{\infty} \varphi^i L^i
# \end{align}
# \tag{17}
# $
#
# It follows that,
#
# $
# \begin{align}
# X_t = \sum_{i=0}^{\infty} \varphi^i L^i \varepsilon_t
# \end{align}
# \tag{18}
# $
#
# which is $\text{MA}(\infty)$ with $\vartheta_i = \varphi^i$.

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.plots import stack, fcurve, fpoints, PlotType
from lib.data import arima, stats
from lib.utils import create_parameter_scan

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## Helpers

# %%
σ = 1
nsample = 1000

def ac_plot(θ, σ, nsample, nlags):
    title = f"MA({len(θ)}) ACF:  $\\theta=${θ}, $\\sigma=${σ}"
    labels=["Simulation", r"$\sigma^2 \left( \sum_{i=i}^{q-n} \vartheta_i \vartheta_{i+n} + \vartheta_n \right)$"]
    t, samples = arima.create_ma_source(θ=θ, σ=σ, npts=nsample)
    lag, acf = stats.compute_acf(t, samples, nlags=nlags)
    _, maq_acf = arima.compute_maq_acf(θ=θ, σ=σ, nlags=nlags)
    fpoints(data=acf, func=maq_acf, x=lag, fx=lag, title=title, labels=labels, xlabel=r"$\tau$", ylabel=r"$\rho_\tau$")

def comparison_plot(θ_vals, ylim, *params):
    title = "MA(q) Comparison Plot"
    labels = [f"θ={val}" for val in θ_vals]
    source = lambda **kwargs : arima.create_ma_source(**kwargs)
    t, scan = create_parameter_scan(source, *params)
    stack(scan, t, ylim=ylim, title=title, labels=labels, ylabels=r"$S_t$", xlabel=r"$t$", figsize=(10, 6))

def cumu_mean_plot(θ, σ, nsample):
    title = f"Convergence of Simulation Mean to $t\\rightarrow\\infty$ Limit:  $\\theta=${θ}, $\\sigma=${σ}"
    t, samples = arima.create_ma_source(θ=θ, σ=σ, npts=nsample)
    _, cumu_mean = stats.compute_cumu_mean(t, samples)
    _, ma_mean = arima.compute_arma_mean(npts=len(t))
    fcurve(data=cumu_mean, func=ma_mean, x=t, fx=t, title_offset=0.025, plot_axis_type=PlotType.XLOG, xlabel=r"$t$", ylabel=r"$\mu_t$",
           labels=["Simulation", r"$\mu_t\rightarrow 0$"], title=title)
    
def cumu_sd_plot(θ, σ, nsample):
    title = f"Convergence of Simulation Mean to $t\\rightarrow\\infty$ Limit:  $\\theta=${θ}, $\\sigma=${σ}"
    t, samples = arima.create_ma_source(θ=θ, σ=σ, npts=nsample)
    _, cumu_sd = stats.compute_cumu_sd(t, samples)
    _, maq_sd = arima.compute_maq_sd(npts=len(t), θ=θ, σ=σ)
    fcurve(data=cumu_sd, func=maq_sd, x=t, fx=t, title_offset=0.025, plot_axis_type=PlotType.XLOG, xlabel=r"$t$", ylabel=r"$\sigma_t$",
           labels=["Simulation", r"$\sigma^2 \left( \sum_{i=1}^q \vartheta_i^2 + 1 \right)$"], title=title)

# %% [markdown]
# ## Simulations

# %%
θ_vals = [[0.2], [0.2, 0.4], [0.2, 0.4, 0.5]]
params = [{"θ": θ, "σ": σ, "npts": nsample} for θ in θ_vals]
comparison_plot(θ_vals, [-3.0, 3.0], *params)

# %%
θ_vals = [[-0.2], [-0.2, -0.4], [0.2, -0.4, -0.5]]
params = [{"θ": θ, "σ": σ, "npts": nsample} for θ in θ_vals]
comparison_plot(θ_vals, [-3.0, 3.0], *params)

# %%
θ_vals = [[2.4], [1.5, -1.5], [1.2, -3.4, -1.5]]
params = [{"θ": θ, "σ": σ, "npts": nsample} for θ in θ_vals]
comparison_plot(θ_vals, [-10.0, 10.0], *params)

# %% [markdown]
# ## Mean

# %%
nsample = 100000
θ = [2.4]
cumu_mean_plot(θ, σ, nsample)

# %%
nsample = 100000
θ = [2.4, -0.9]
cumu_mean_plot(θ, σ, nsample)

# %%
nsample = 100000
θ = [2.4, -0.9, 0.3]
cumu_mean_plot(θ, σ, nsample)

# %% [markdown]
# ## Standard Deviation

# %%
θ = [2.4]
nsample = 100000
cumu_sd_plot(θ, σ, nsample)

# %%
θ = [2.4, -1.2]
nsample = 100000
cumu_sd_plot(θ, σ, nsample)

# %%
θ = [2.4, -1.2, 0.6]
nsample = 100000
cumu_sd_plot(θ, σ, nsample)

# %% [markdown]
# ## Autocorrelation

# %%
θ = [0.2]
lag = 11
nsample = 50000
ac_plot(θ, σ, nsample, lag)

# %%
θ = [-0.2]
lag = 11
nsample = 50000
ac_plot(θ, σ, nsample, lag)

# %%
θ = [0.4, 0.2]
lag = 11
nsample = 100000
ac_plot(θ, σ, nsample, lag)

# %%
θ = [0.2, -0.2]
lag = 10
nsample = 50000
ac_plot(θ, σ, nsample, lag)

# %%
θ = [0.2, 0.3, 0.1]
lag = 10
nsample = 5000000
ac_plot(θ, σ, nsample, lag)

# %%
θ = [0.4, -0.2, -0.1]
lag = 10
nsample = 50000
ac_plot(θ, σ, nsample, lag)
