# %% [markdown]
# # Brownian Motion Ensembles
#
# Ensemble simulations of brownian motion, browninan motion with drift and geometric brownian motion are given.</br>
# Let $B_t$ denote brownian motion and let $dB_t$ denote its inifinitesimal, with </br>
#
# $
# \begin{align}
# &dB_t \sim N(0,dt) \\
# &\text{E}[dB_t ] = 0 \\
# &\text{E} [ ( dB_t )^2 ] = dt
# \end{align}
# \tag{1}
# $
#
# It follows that,
#
# $
# \begin{align}
# &\text{E}(B_t) = 0 \\
# &\text{Var}(B_t) = t
# \end{align}
# \tag{2}
# $
#
# Brownian motion with drift is defined by the stochastic differential equation,</br>
#
# $
# \begin{align}
# dD_t = \mu dt + \sigma dB_t
# \end{align}
# \tag{3}
# $
#
# directly integrating leads to the solution,</br>
#
# $
# \begin{align}
# D_t = D_0 + \mu t + \sigma B_t
# \end{align}
# \tag{4}
# $
#
# The first and second moments are,
#
# $
# \begin{align}
# &\text{E}[D_t] = D_0 + \mu t\\
# &\text{Var}[D_t] = \sigma^2 t
# \end{align}
# \tag{5}
# $
#
# Geometric brownian motion is defined by stochastic differential equation, </br>
#
# $
# \begin{align}
# dS_t = \mu S_t dt + \sigma S_t dB_t
# \end{align}
# \tag{6}
# $
#
# Now consider $\ln{S_t}$, applying Ito's lemma, that is expanding in a Taylor series to second order,</br>
#
# $
# \begin{align}
# d(\ln{S_t}) = \frac{dS_t}{S_t} - \frac{1}{2}\frac{(dS_t)^2}{S_t^2}
# \end{align}
# \tag{7}
# $
#
# From the stochastic differential equation for Brownian motion with drift assume that,
#
# $
# \begin{align}
# \frac{dS_t}{S_t} = \mu dt + \sigma dB_t
# \end{align}
# \tag{8}
# $
#
# It follows that,
#
# $
# \begin{align}
# \frac{(dS_t)^2}{S_t^2} = \sigma^2 dt
# \end{align}
# \tag{8}
# $
#
# Bringing things together gives,
#
# $
# \begin{align}
# d(\ln{S_t}) = \left( \mu - \frac{1}{2}\sigma^2 \right) dt + \sigma dB_t
# \end{align}
# \tag{8}
# $
#
# This equation can be integrated to give the solution,</br>
#
# $
# \begin{align}
# S_t=S_0 e^{\left( \mu - \frac{1}{2} \sigma^2 \right)t + \sigma B_t}
# \end{align}
# \tag{9}
# $
#
# The first and second moments of geometric brownian motion are,</br>
#
# $
# \begin{align}
# &\text{E}[S_t] = S_0 e^{\mu t} \\
# &\text{Var}[S_t] = S_0^2 e^{2\mu t}\left( e^{\sigma^2 t} - 1 \right)
# \end{align}
# \tag{10}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.plots import comparison, fpoints
from lib.data import bm, stats
from lib.utils import create_ensemble

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## Helpers

# %%
Δt = 1.0
npts = 1024
nsim = 1000

# %% [markdown]
# ## Brownian Motion

# %%
title = f"Brownian Motion Ensemble: nsim={nsim} Δt={Δt}"
source = lambda **kwargs : bm.create_bm_source(**kwargs)
time, ensemble = create_ensemble(source, nsim, Δt=Δt, npts=npts)
comparison(ensemble, title=title, lw=1)

# %%
ensemble_time, ensemble_mean = stats.compute_ensemble_mean(time, ensemble)
mean_time, bm_mean = bm.compute_mean(Δt=npts/10, npts=10)

title = f"Brownian Motion Ensemble Mean: nsim={nsim} Δt={Δt}"
fpoints(ensemble_mean, bm_mean, ensemble_time, mean_time, ylim=(-2.0, 2.0), labels=[r"$\langle \mu_t \rangle$", r"$\mu_t$"], title=title)

# %%
ensemble_time, ensemble_mean = stats.compute_ensemble_sd(time, ensemble)
sd_time, bm_sd = bm.compute_sd(Δt=npts/10, npts=10)

title = f"Brownian Motion Ensemble Standard Deviation: nsim={nsim} Δt={Δt}"
fpoints(ensemble_mean, bm_sd, ensemble_time, sd_time, labels=[r"$\langle \sigma_t \rangle$", r"$\sigma_t = \sqrt{\Delta t}\sqrt{t}$"], title=title)

# %% [markdown]
# ## Brownian Motion with Drift

# %%
μ=0.1
σ=1.5
title = f"Brownian Motion Ensemble: nsim={nsim}, μ={μ}, σ={σ}, Δt={Δt}"

source = lambda **kwargs : bm.create_bm_drift_source(**kwargs)
time, ensemble = create_ensemble(source, nsim, μ=μ, σ=σ, Δt=Δt, npts=npts)
comparison(ensemble, title=title, lw=1)

# %%
ensemble_time, ensemble_mean = stats.compute_ensemble_mean(time, ensemble)
mean_time, bm_mean = bm.compute_bm_drift_mean(Δt=npts/10, μ=μ, npts=10)

title = f"Brownian Motion Ensemble Mean: nsim={nsim}, μ={μ}, σ={σ}, Δt={Δt}"
fpoints(ensemble_mean, bm_mean, ensemble_time, mean_time, labels=[r"$\langle \mu_t \rangle$", r"$\mu_t=\mu t$"], title=title)

# %%
ensemble_time, ensemble_sd = stats.compute_ensemble_sd(time, ensemble)
sd_time, bm_sd = bm.compute_sd(Δt=npts/10, npts=10, σ=σ)

title = f"Brownian Motion Ensemble Standard Deviation: nsim={nsim}, μ={μ}, σ={σ}, Δt={Δt}"
fpoints(ensemble_sd, bm_sd, ensemble_time, sd_time, labels=[r"$\langle \sigma_t \rangle$", r"$\sigma_t = \sigma \sqrt{\Delta t}\sqrt{t}$"], title=title)

# %% [markdown]
# ## Geometric Brownian Motion

# %%
npts = 1000
nsim = 1000
μ=0.001
σ=0.01
S0 = 50.0
title = r'Brownian Motion Ensemble: nsim={nsim}, μ={μ}, σ={σ}, $S_0$={S0}'.format(nsim=nsim, μ=μ, σ=σ, S0=S0)

source = lambda **kwargs : bm.create_bm_geometric_source(**kwargs)
time, ensemble = create_ensemble(source, nsim, μ=μ, σ=σ, Δt=Δt, npts=npts, S0=S0)
comparison(ensemble, title=title, lw=1)

# %%
ensemble_time, ensemble_mean = stats.compute_ensemble_mean(time, ensemble)
mean_time, bm_mean = bm.compute_bm_geometric_mean(Δt=npts/10, npts=10, μ=μ, S0=S0)

title = f'Brownian Motion Ensemble Mean\n nsim={nsim}, Δt={Δt}, μ={μ}, σ={σ}, $S_0$={S0}'
fpoints(ensemble_mean, bm_mean, ensemble_time, mean_time, labels=[r"$\langle \mu_t \rangle$", r"$S_0 e^{\mu t}$"], title=title)

# %%
ensemble_time, ensemble_sd = stats.compute_ensemble_sd(time, ensemble)
sd_time, bm_sd = bm.compute_bm_geometric_sd(Δt=npts/10, npts=10, σ=σ, μ=μ, S0=S0)

title = f'Brownian Motion Ensemble Standard Deviation\n nsim={nsim}, Δt={Δt}, μ={μ}, σ={σ}, $S_0$={S0}'
fpoints(ensemble_sd, bm_sd, ensemble_time, sd_time, labels=[r"$\langle \sigma_t \rangle$", r"$\sigma_t = S_0^2 e^{2\mu t}\left( e^{\sigma^2 t} - 1 \right)$"], title=title)
