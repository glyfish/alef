# %% [markdown]
# # Ornstein-Uhlenbeck Process
#
# The $\text{AR}(1)$ process with constant offset is defined by,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \mu^* + \sigma \varepsilon_t
# \end{align}
# \tag{1}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0, 1)$. Subtracting $X_{t-1}$ from both sides gives,
#
# $
# \begin{align}
# \Delta X_t = \left ( \varphi - 1 \right) X_{t-1} + \mu^* + \sigma \varepsilon_t
# \end{align}
# \tag{2}
# $
#
# This can be reparameterized to,
#
# $
# \begin{align}
# \Delta X_t = \lambda \left( \mu - X_{t-1} \right) + \sigma \varepsilon_t
# \end{align}
# \tag{3}
# $
#
# where $\lambda = 1 - \varphi$ and $\mu = \frac{\mu^*}{\lambda}$.
#
# The continuous differential form of this equation is the Ornstein-Uhlenbeck SDE,
#
# $
# \begin{align}
# dX_t = \lambda \left( \mu - X_t \right) dt + \sigma dB_t
# \end{align}
# \tag{4}
# $
#
# where $dB_t \sim \text{Normal}(0, dt)$. The Ornstein-Uhlenbeck SDE models a mean reverting random process and can be solved using the integration factor, $e^{\lambda t}$
#
# $
# \begin{align}
# X_t = X_0 e^{-\lambda t} + \mu \left( 1 - e^{-\lambda t} \right) + \sigma \int_0^t e^{-\lambda\left( t - s \right)} dB_s
# \end{align}
# \tag{5}
# $
#
# ## Mean, Variance and Autocovariance
#
# The mean of $X_t$ as a function of time is obtained by taking expectation of equation $(5)$ and noting that since the last term is a martingale,
#
# $
# \begin{align}
# \text{E}\left[ \int_0^t e^{-\lambda\left( s - t \right)} dB_s \right] = 0
# \end{align}
# \tag{6}
# $
#
# thus,
#
# $
# \begin{align}
# \text{E}\left[ X_t \right] = X_0 e^{-\lambda t} + \mu \left( 1 - e^{-\lambda t} \right)
# \end{align}
# \tag{7}
# $
#
# The variance is given by,
#
# $
# \begin{align}
# \text{Var}(X_t) &= \text{E}\left[\left( X_t - E\left( X_t \right) \right)^2 \right]
# \end{align}
# \tag{8}
# $
#
# Since,
#
# $
# \begin{align}
# X_t - \text{E}(X_t) = \sigma \int_0^t e^{-\lambda \left( t - s \right) } dB_s
# \end{align}
# \tag{9}
# $
#
# and Itô isometery implies that,
#
# $
# \begin{align}
# \text{Var}(X_t) &= \text{E} \left[ \sigma^2  \left( \int_0^t e^{-\lambda \left( t - s \right)} \right)^2 \right] \\
# &= \sigma^2 \text{E} \left[ \int_0^t e^{-2\lambda \left( t - s \right) } ds \right] \\
# &= \frac{\sigma^2}{2\lambda} \left( 1 - e^{-2\lambda t} \right)
# \end{align}
# \tag{10}
# $
#
# Similarly the autocovariance for $t>s$ is given by,
#
# $
# \begin{align}
# \text{Cov}\left( X_s X_t \right) = \frac{\sigma^2}{2\lambda} \left[ e^{-\lambda \left( t-s \right)} - e^{-\lambda \left( t+s \right)} \right]
# \end{align}
# \tag{11}
# $
#
# ## Limiting Values of Mean, Variance and Autocovariance
#
# The limits of equations $(7)$, $(10)$ and $(11)$ as $t \to \infty$ require $\lambda > 0$. Making this assumption it follows that,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}\left( X_t \right) = \mu \\
# &\lim_{t \to \infty} \text{Var} \left( X_t \right) = \frac{\sigma^2}{2\lambda} \\
# &\lim_{t \to \infty} \text{Cov} \left( X_t X_s \right) = 0
# \end{align}
# \tag{12}
# $
#
# This limit is equivalent to stationarity in the $\text{AR}(1)$ model so it is interesting to compare the results for the mean and variance. Recall that for $\text{AR}(1)$ with an offset $\mu^*$,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}(X_t) = \frac{\mu^*}{1 - \varphi} \\
# &\lim_{t \to \infty} \text{Var}(X_t) = \frac{\sigma^2}{1 - \varphi^2}
# \end{align}
# \tag{13}
# $
#
# Using the relations $\lambda = 1 - \varphi$ and $\mu = \frac{\mu^*}{\lambda}$, the $\text{AR}(1)$ limit of $\text{E}(X_t)$ becomes,
#
# $
# \begin{align}
# &\lim_{t \to \infty} \text{E}(X_t) = \mu \\
# \end{align}
# \tag{14}
# $
#
# The results are the same while for the variance they differ. It will later be seen that this is a consequence of taking the continuous limit and that for a discrete limit the result is recovered.
#
# ## Half Life of Mean Decay
#
# Previously it was shown that,
#
# $
# \begin{align}
# \text{E}\left[ X_t \right] = X_0 e^{-\lambda t} + \mu \left( 1 - e^{-\lambda t} \right)
# \end{align}
# \tag{15}
# $
#
# and for the limit $t \to \infty$,
#
# $
# \begin{align}
# \text{E}\left[ X_t \right] = \mu
# \end{align}
# \tag{16}
# $
#
# The half life of mean decay is the time to reach $\frac{1}{2}$ the $t \to \infty$ value from the initial value. This defines the timescale of the Ornstein-Uhlenbeck process. If $t_H$ denotes the half life. It follows that,
#
# $
# \begin{align}
# X_{t_H} = X_0 + \frac{1}{2}\left( \mu - X_0 \right)
# \end{align}
# \tag{17}
# $
#
# Solving the equation,
#
# $
# \begin{align}
# X_0 e^{-\lambda t_H} + \mu \left( 1 - e^{-\lambda t_H} \right) = X_0 + \frac{1}{2}\left( \mu - X_0 \right)
# \end{align}
# \tag{18}
# $
#
# gives
#
# $
# \begin{align}
# t_H = \frac{\ln{2}}{\lambda}
# \end{align}
# \tag{19}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.data import ou, stats
from lib.plots import comparison, fcurve, fpoints, curve
from lib.utils import create_ensemble, create_parameter_scan

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## Helpers

# %%
def ensemble_mean_plot(**params):
    title = f"Ornstein-Uhlenbeck Process Mean: μ: {params['μ']}, λ:  {params['λ']}, x0:  {params['x0']}, Δt:  {params['Δt']}"
    source = lambda **kwargs: ou.create_source(**kwargs) 
    t, ensemble = create_ensemble(source, 500, **params)
    mean_t, mean = stats.compute_ensemble_mean(t, ensemble)
    params["Δt"] = t[-1] / 10
    params["npts"] = 11
    labels = [r"$\mu_t$", r"$X_0 e^{-\lambda t} + \mu \left( 1 - e^{-\lambda t} \right)$"]
    ou_mean_t, ou_mean = ou.compute_mean(**params)
    fpoints(data=mean, func=ou_mean, x=mean_t, fx=ou_mean_t, title=title, labels=labels, xlabel=r"$t$", ylabel=r"$\mu_t$")
    
def asymptotic_mean_plot(**params):
    title = f"Ornstein-Uhlenbeck Asymptotic Mean: μ: {params['μ']}, λ:  {params['λ']}, x0:  {params['x0']}, Δt:  {params['Δt']}"
    t, xt = ou.create_source(**params) 
    _, cumu_mean = stats.compute_cumu_mean(t, xt)
    _, mean = ou.compute_mean_limit(**params)
    fcurve(data=cumu_mean, func=mean, x=t, fx=t, title_offset=0.025, xlabel=r"$t$", ylabel=r"$\mu_t$",
           labels=[r"$\mu_t$", r"$\mu_t \rightarrow \mu$"], title=title)
    
def ensemble_var_plot(**params):
    title = f"Ornstein-Uhlenbeck Process variance:  σ: {params['σ']}, λ:  {params['λ']}, Δt:  {params['Δt']}"
    source = lambda **kwargs: ou.create_source(**kwargs)
    t, ensemble = create_ensemble(source, 1000, **params)
    var_t, var = stats.compute_ensemble_var(t, ensemble, Δt=params['Δt'])
    params["Δt"] = t[-1] / 10
    params["npts"] = 11
    ou_var_t, ou_var = ou.compute_var(**params)
    labels = [r"$\sigma^2_t$", r"$\frac{\sigma^2}{2\lambda} \left( 1 - e^{-2\lambda t} \right)$"]
    fpoints(data=var, func=ou_var, x=var_t, fx=ou_var_t, title=title, labels=labels, xlabel=r"$t$", ylabel=r"$\mu_t$")
    
def asymptotic_var_plot(**params):
    title = f"Ornstein-Uhlenbeck Asymptotic Variance: σ: {params['σ']}, λ:  {params['λ']}, Δt:  {params['Δt']}"
    t, xt = ou.create_source(**params)
    _, cumu_var = stats.compute_cumu_var(t, xt, Δt=params['Δt'])
    _, var = ou.compute_var_limit(**params)
    fcurve(data=cumu_var, func=var, x=t, fx=t, title_offset=0.025, xlabel=r"$t$", ylabel=r"$\mu_t$",
           labels=[r"$\sigma^2_t$", r"$\sigma^2_t \rightarrow \frac{\sigma^2}{2\lambda}$"], title=title)

# %% [markdown]
# ## Mean
#
# The mean as a function time for the Ornstein-Uhlenbeck process is given by,
#
# $
# \begin{align}
# \mu_t = X_0 e^{-\lambda t} + \mu \left( 1 - e^{-\lambda t} \right)
# \end{align}
# $
#
# Here a scan of parameters is performed.

# %%
μ_vals = [-4.0, -2.0, 0.0, 2.0, 4.0]
λ = 1.0
x0 = 0.0
npts = 500
Δt = 0.01
labels = [f"μ={val}" for val in μ_vals]
params = [{"μ": μ, "λ": λ, "x0": x0, "npts": npts, "Δt": Δt} for μ in μ_vals]
title = f"Ornstein-Uhlenbeck Process Mean μ Scan: λ={λ}, x0={x0}"

func = lambda **kwargs: ou.compute_mean(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels)

# %%
x0_vals = [-4.0, -2.0, 0.0, 2.0, 4.0]
λ = 1.0
μ = 0.0
npts = 500
Δt = 0.01
labels = [f"$X_0$={val}" for val in x0_vals]
params = [{"μ": μ, "λ": λ, "x0": x0, "npts": npts, "Δt": Δt} for x0 in x0_vals]
title = f"Ornstein-Uhlenbeck Process Mean $X_0$ Scan: λ={λ}, μ={μ}"

func = lambda **kwargs: ou.compute_mean(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels)

# %%
λ_vals = [0.0, 0.1, 0.25, 0.5, 1.0, 2.0, 3.0, 4.0]
μ = 1.0
x0 = 0.0
npts = 500
Δt = 0.01
labels = [f"λ={val}" for val in λ_vals]
params = [{"μ": μ, "λ": λ, "x0": x0, "npts": npts, "Δt": Δt} for λ in λ_vals]
title = f"Ornstein-Uhlenbeck Process Mean λ Scan: μ={μ}, x0={x0}"

func = lambda **kwargs: ou.compute_mean(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels)

# %%
λ_vals = [0.0, 0.1, 0.25, 0.5, 1.0, 2.0, 3.0, 4.0]
μ = 0.0
x0 = 1.0
npts = 500
Δt = 0.01
labels = [f"λ={val}" for val in λ_vals]
params = [{"μ": μ, "λ": λ, "x0": x0, "npts": npts, "Δt": Δt} for λ in λ_vals]
title = f"Ornstein-Uhlenbeck Process Mean λ Scan: μ={μ}, x0={x0}"

func = lambda **kwargs: ou.compute_mean(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels)

# %% [markdown]
# ### Mean Validation
#
# The expression obtained for the mean is compared with the result obtained from an ensemble simulation for a range of parameters,
#
# $
# \begin{align}
# \mu_t = X_0 e^{-\lambda t} + \mu \left( 1 - e^{-\lambda t} \right)
# \end{align}
# $

# %%
Δt = 0.01
μ = 1.0
λ = 1.0
x0 = 0.0
npts = 1000
params = {"μ": μ, "λ": λ, "x0": x0, "npts": npts, "Δt": Δt}
ensemble_mean_plot(**params)

# %%
Δt = 0.01
μ = 1.0
λ = 1.0
σ = 1.0
x0 = 2.0
npts = 1000
params = {"μ": μ, "λ": λ, "σ": σ, "x0": x0, "npts": npts, "Δt": Δt, "Δx": Δt}
ensemble_mean_plot(**params)

# %%
Δt = 0.01
μ = 2.0
λ = 4.0
σ = 1.0
x0 = 1.0
npts = 500
params = {"μ": μ, "λ": λ, "σ": σ, "x0": x0, "npts": npts, "Δt": Δt}
ensemble_mean_plot(**params)

# %% [markdown]
# ### Convergence to Time Asymptotic Mean
#
# The time asymptotic mean is given by,
#
# $
# \begin{align}
# \lim_{t \to \infty} \mu_t = \mu
# \end{align}
# $
#
# This expression is verified for a range of parameters.

# %%
Δt = 0.025
μ = 2.0
λ = 1.0
σ = 1.0
x0 = 0.0
npts = 10000
params = {"μ": μ, "λ": λ, "σ": σ, "x0": x0, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_mean_plot(**params)

# %%
Δt = 0.1
μ = 2.0
λ = 0.1
σ = 2.0
x0 = 0.0
npts = 10000
params = {"μ": μ, "λ": λ, "σ": σ, "x0": x0, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_mean_plot(**params)

# %%
Δt = 0.1
μ = 2.0
λ = 2.0
σ = 1.0
x0 = 3.0
npts = 1000
params = {"μ": μ, "λ": λ, "σ": σ, "x0": x0, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_mean_plot(**params)

# %% [markdown]
# ## Variance
#
# The variance as a function time for the Ornstein-Uhlenbeck process is given by,
#
# $
# \begin{align}
# \sigma^2_t = \frac{\sigma^2}{2\lambda} \left( 1 - e^{-2\lambda t} \right)
# \end{align}
# $
#
# Here a parameter scan is performed.

# %%
λ_vals = [0.1, 0.25, 0.5, 1.0, 2.0, 3.0, 4.0]
σ = 1.0
npts = 500
Δt = 0.1
labels = [f"λ={val}" for val in λ_vals]
params = [{"λ": λ, "σ": σ, "npts": npts, "Δt": Δt} for λ in λ_vals]
title = f"Ornstein-Uhlenbeck Process Variance λ Scan: σ={σ}"

func = lambda **kwargs: ou.compute_var(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels)

# %%
σ_vals = [0.1, 0.5, 1.0, 2.0, 4.0]
λ = 1.0
npts = 500
Δt = 0.01
labels = [f"σ={val}" for val in σ_vals]
params = [{"λ": λ, "σ": σ, "npts": npts, "Δt": Δt} for σ in σ_vals]
title = f"Ornstein-Uhlenbeck Process Variance σ Scan: λ={λ}"

func = lambda **kwargs: ou.compute_var(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels)

# %% [markdown]
# ### Variance Validation
#
# The expression obtained for the variance is compared with the result obtained from an ensemble simulation for a range of parameters,
#
# $
# \begin{align}
# \sigma^2_t = \frac{\sigma^2}{2\lambda} \left( 1 - e^{-2\lambda t} \right)
# \end{align}
# $

# %%
Δt = 0.01
λ = 1.0
σ = 1.0
npts = 500
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
ensemble_var_plot(**params)

# %%
Δt = 0.01
λ = 0.1
σ = 1.0
npts = 500
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
ensemble_var_plot(**params)

# %%
Δt = 0.01
λ = 2.0
σ = 1.0
npts = 500
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
ensemble_var_plot(**params)

# %%
Δt = 0.01
λ = 1.0
σ = 0.25
npts = 500
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
ensemble_var_plot(**params)

# %%
Δt = 0.01
λ = 1.0
σ = 2.0
npts = 500
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
ensemble_var_plot(**params)

# %% [markdown]
# ### Convergence to Time Asymptotic Variance
#
# The time asymptotic mean is given by,
#
# $
# \begin{align}
# \lim_{t \to \infty} \text{Var} \left( X_t \right) = \frac{\sigma^2}{2\lambda}
# \end{align}
# $
#
# This expression is verified for a range of parameters.

# %%
Δt = 0.01
λ = 1.0
σ = 1.0
npts = 100000
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_var_plot(**params)

# %%
Δt = 0.01
λ = .1
σ = 1.0
npts = 1000000
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_var_plot(**params)

# %%
Δt = 0.01
λ = 2.0
σ = 1.0
npts = 100000
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_var_plot(**params)

# %%
Δt = 0.01
λ = 1.0
σ = .1
npts = 100000
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_var_plot(**params)

# %%
Δt = 0.01
λ = 1.0
σ = 5.0
npts = 100000
params = {"λ": λ, "σ": σ, "npts": npts, "Δt": Δt, "Δx": Δt}
asymptotic_var_plot(**params)

# %% [markdown]
# ## Autocovariance
#
# The autocovariance as a function time for the Ornstein-Uhlenbeck process is given by,
#
# $
# \begin{align}
# \text{Cov}\left( X_s X_t \right) = \frac{\sigma^2}{2\lambda} \left[ e^{-\lambda \left( t-s \right)} - e^{-\lambda \left( t+s \right)} \right]
# \end{align}
# $
#
# Here a parameter scan is performed.

# %%
s_vals = [1.0, 2.0, 4.0, 6.0]
λ = 1.0
σ = 1.0
npts = 1000
Δt = 0.01
labels = [f"s={val}" for val in s_vals]
params = [{"λ": λ, "σ": σ, "s": s, "npts": npts, "Δx": Δt, "Δt": Δt} for s in s_vals]
title = f"Ornstein-Uhlenbeck Process Autocovariance s Scan: σ={σ}, λ={λ}"
func = lambda **kwargs: ou.compute_cov(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels, ylabel=r"Cov$\left(X_s, X_t \right)$", xlabel=r"$t$")

# %%
λ_vals = [0.25, 0.5, 1.0, 2.0, 5.0]
s = 1.0
σ = 1.0
npts = 1000
Δt = 0.01
labels = [f"λ={val}" for val in λ_vals]
params = [{"λ": λ, "σ": σ, "s": s, "npts": npts, "Δx": Δt, "Δt": Δt} for λ in λ_vals]
title = f"Ornstein-Uhlenbeck Process Autocovariance λ Scan: σ={σ}, s={s}"
func = lambda **kwargs: ou.compute_cov(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels, ylabel=r"Cov$\left(X_s, X_t \right)$", xlabel=r"$t$")

# %%
σ_vals = [0.5, 1.0, 2.0, 4.0]
s = 1.0
λ = 1.0
npts = 1000
Δt = 0.01
labels = [f"σ={val}" for val in σ_vals]
params = [{"λ": λ, "σ": σ, "s": s, "npts": npts, "Δx": Δt, "Δt": Δt} for σ in σ_vals]
title = f"Ornstein-Uhlenbeck Process Autocovariance σ Scan: λ={λ}, s={s}"
func = lambda **kwargs: ou.compute_cov(**kwargs)
t, scan = create_parameter_scan(func, *params)
comparison(scan, t, title=title, labels=labels, ylabel=r"Cov$\left(X_s, X_t \right)$", xlabel=r"$t$")
