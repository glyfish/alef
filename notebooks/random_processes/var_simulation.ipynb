# %% [markdown]
# # Vector Autoregression (VAR)
#
# The Vector Auto Regressive Process is a generalization of the single variable Autoregressive (AR) process to multiple variables. The $\text{VAR}(n)$ </br>
# is defined by,
#
# $
# \begin{align}
# X_t = \mathcal{M} + \Phi_1 X_{t-1} \Phi_2 X_{t-2} + \cdots + \Phi_n X_{t-n} + \mathcal{E}_t
# \end{align}
# $
#
# where $t = 1, 2, 3, \ldots, T$, $X_t$ is column vector of length $m$ representing the time series, $\mathcal{M}$ is a $m$ element constant offset column vector, </br>
# $\Phi_t$ are $m \times m$ matrices denoting constant coefficients and $\mathcal{E}_t$ an a random column normal vector with zero mean and covariance matrix $\Omega$,
#
# $
# \begin{align}
# \mathcal{E}_t \sim \text{Normal}(0, \Omega)
# \end{align}
# $
#
# The $\mathcal{E}_t$ are assumed uncorrelated,
#
# $
# \begin{align}
# \text{Cov}(\mathcal{E}_t, \mathcal{E}_s) = \left\{
#     \begin{array}{ll}
#      \Omega  & \mbox{if } t = s \\
#     0& \mbox{if } t \ne s
#     \end{array}
# \right.
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \Omega = \text{E}(\mathcal{E}_t \mathcal{E}_t^\prime)
# \end{align}
# $
#
# with $\mathcal{E}_t^\prime$ denoting the transpose of $\mathcal{E}_t$. Explicitly the matrices are given by,
#
# $
# \begin{align}
# X_t =
# \begin{bmatrix}
# x^1_t \\
# x^2_t \\
# \vdots \\
# x^m_t \\
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \mathcal{M} =
# \begin{bmatrix}
# \mu_1 \\
# \mu_2 \\
# \vdots \\
# \mu_m \\
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \mathcal{E}_t =
# \begin{bmatrix}
# \varepsilon^1_t \\
# \varepsilon^2_t \\
# \vdots \\
# \varepsilon^m_t \\
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \Phi_i =
# \begin{bmatrix}
# \phi^i_{11} & \phi^i_{12} & \cdots & \phi^i_{1m} \\
# \phi^i_{12} & \phi^i_{22} & \cdots & \phi^i_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# \phi^i_{1m} & \phi^i_{1m} & \cdots & \phi^i_{mm} \\
# \end{bmatrix}
# \end{align}
# $
#
# ## Examples
#
# ### $\text{VAR}(1)$
#
# $\text{VAR}(1)$ is given by,
#
# $
# \begin{align}
# X_t = \mathcal{M} + \Phi_1 X_{t-1} + \mathcal{E}_t
# \end{align}
# $
#
# where $X_t$, $\mathcal{M}$ and $\mathcal{E}$ are given by the column vector of length $m$ from the previous section and,
#
# $
# \begin{align}
# \Phi_1 =
# \begin{bmatrix}
# \phi^1_{11} & \phi^1_{12} & \cdots & \phi^1_{1m} \\
# \phi^1_{12} & \phi^1_{22} & \cdots & \phi^1_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# \phi^1_{1m} & \phi^1_{1m} & \cdots & \phi^1_{mm} \\
# \end{bmatrix}
# \end{align}
# $
#
# ### $\text{VAR}(2)$
#
# $\text{VAR}(2)$ is given by,
#
# $
# \begin{align}
# X_t = \mathcal{M} + \Phi_1 X_{t-1} + \Phi_2 X_{t-2} + \mathcal{E}_t
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \Phi_1 =
# \begin{bmatrix}
# \phi^1_{11} & \phi^1_{12} & \cdots & \phi^1_{1m} \\
# \phi^1_{12} & \phi^1_{22} & \cdots & \phi^1_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# \phi^1_{1m} & \phi^1_{1m} & \cdots & \phi^1_{mm} \\
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \Phi_2 =
# \begin{bmatrix}
# \phi^2_{11} & \phi^2_{12} & \cdots & \phi^2_{1m} \\
# \phi^2_{12} & \phi^2_{22} & \cdots & \phi^2_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# \phi^2_{1m} & \phi^2_{1m} & \cdots & \phi^2_{mm} \\
# \end{bmatrix}
# \end{align}
# $
#
# ### $\text{VAR}(3)$
#
# Finally $\text{VAR}(3)$ is given by,
#
# $
# \begin{align}
# X_t = \mathcal{M} + \Phi_1 X_{t-1} + \Phi_2 X_{t-2} + \Phi_3 X_{t-3} + \mathcal{E}_t
# \end{align}
# $
#
# where,
#
# $
# \begin{align}
# \Phi_1 =
# \begin{bmatrix}
# \phi^1_{11} & \phi^1_{12} & \cdots & \phi^1_{1m} \\
# \phi^1_{12} & \phi^1_{22} & \cdots & \phi^1_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# \phi^1_{1m} & \phi^1_{1m} & \cdots & \phi^1_{mm} \\
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \Phi_2 =
# \begin{bmatrix}
# \phi^2_{11} & \phi^2_{12} & \cdots & \phi^2_{1m} \\
# \phi^2_{12} & \phi^2_{22} & \cdots & \phi^2_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# \phi^2_{1m} & \phi^2_{1m} & \cdots & \phi^2_{mm} \\
# \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# \Phi_3 =
# \begin{bmatrix}
# \phi^3_{11} & \phi^3_{12} & \cdots & \phi^3_{1m} \\
# \phi^3_{12} & \phi^3_{22} & \cdots & \phi^3_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# \phi^3_{1m} & \phi^3_{1m} & \cdots & \phi^3_{mm} \\
# \end{bmatrix}
# \end{align}
# $
#
# ## Simulation of VAR Process
#
# The Cholesky method is used to simulate correlated Gaussian processes, $\mathbb{Z}_n$ as a liner transformation of independent unit normal random variables. </br>
# Let $\mathbb{B}_n$ denote a column vector of $n$ independent unit normal random variables,
#
# $
# \begin{align}
# \mathbb{B}_n =
# \begin{bmatrix}
# B_1 \\
# B_2 \\
# \vdots \\
# B_n \\
# \end{bmatrix}
# \end{align}
# $
#
# where $B_i \sim \text{Normal}(0, 1)$. Let $L_n$ denote an $n\times n$ matrix where,
#
# $
# \begin{align}
# \mathbb{Z}_n = L_n \mathbb{B}_n
# \end{align}
# $
#
# Let $\Omega_n$ denote the covariance of the random vector $\mathbb{Z}_n$ and $\mathbb{Z}_n^\prime$ its transpose. It follows that,</br>
#
# $
# \begin{align}
# \text{E}\left(\mathbb{Z}_n, \mathbb{Z}_n^\prime \right) = \Omega_n
# \end{align}
# $
#
# Since the elements of $\mathbb{B}_n$ are unit normal random variables,
#
# $
# \begin{align}
# \text{E}\left( \mathbb{B}_n \mathbb{B}_n^\prime\right) = \mathbb{1}_n
# \end{align}
# $
#
# where $\mathbb{1}_n $ is an $n\times n$ identity matrix. From the definition of the covariance matrix it is easy to show that it is symmetric, $\Omega = \Omega^\prime$, and that</br>
# it is positive definite $X_n^\prime \Omega_n^{-1}X_n \ge 0$ for any real vector $X_n$. It follows that,
#
# $
# \begin{align}
# \Omega &= \text{E}\left(\mathbb{Z}_n, \mathbb{Z}_n^\prime \right) \\
# &= \text{E}\left[\left(L_n \mathbb{B}_n\right)  \left(L_n \mathbb{B}_n \right)^\prime  \right] \\
# & = \text{E}\left( L_n \mathbb{B}_n \mathbb{B}_n^\prime L^\prime \right)
# \end{align}
# $
#
# recall that $\text{E}\left( \mathbb{B}_b \mathbb{B}_n^\prime \right) = \mathbb{1}_n$ so it follows that,
#
# $
# \begin{align}
# \Omega_n &= L_n\text{E}\left( \mathbb{B}_n \mathbb{B}_n^\prime \right) L_n^\prime \\
# &= L_n L_n^\prime
# \end{align}
# $
#
# Recall Cholesky decomposition is a method for factorization of a symmetric positive definite matrix into the product of a lower diagonal matrix and its transpose. </br>
# Since $\Omega_n =L_n L_n^\prime$ Cholesky decomposition can be used to compute $L_n$ by assuming it is a lower triangular matrix. It follows that the simulated Gaussian process </br>
# $\mathbb{Z}_n$ can be computed from,
#
# $
# \begin{align}
# \mathbb{Z}_n = L_n\mathbb{B}_n
# \end{align}
# $
#
# where $\mathbb{B}_n \sim \text{Normal}(0,n)$ and $\mathbb{Z}_n \sim \text{Normal}(0, \Omega)$. Thus the procedure for simulation of a correlated Gaussian process is to assume a </br>
# correlation matrix $\Omega$ then compute $L_n$ using Cholesky decomposition then the simulated vector is given by, $\mathbb{Z}_n = L_n \mathbb{B}_n$. </br>
# It has been assumed that the simulated process has zero mean. A mean value can be incorporated in the following matter. If the mean column vector is given by,
#
# $
# \begin{align}
# \mathcal{M}_n =
# \begin{bmatrix}
# \mu_1 \\
# \mu_2 \\
# \vdots \\
# \mu_n \\
# \end{bmatrix}
# \end{align}
# $
#
# Then,
#
# $
# \begin{align}
# \mathbb{Z}_n - \mathcal{M}_n = L_n \mathbb{B}_n
# \end{align}
# $
#
# After generating the random component using the Cholesky method a step in $\text{VAR}(n)$ process is computed using,
#
# $
# \begin{align}
# X_t = \mathcal{M} + \Phi_1 X_{t-1} \Phi_2 X_{t-2} + \cdots + \Phi_n X_{t-n} + \mathcal{E}_t
# \end{align}
# $

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
from matplotlib import pyplot
import numpy

sys.path.insert(0, os.path.abspath('../..'))

# import local modules
from lib import config
from lib import (VAR, Stats, PlotType)
from lib import (stack, fpoints, fcurve)

# Config Plot Style
pyplot.style.use(config.glyfish_style)
# Out:
# /Users/troy/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Helpers

# %%
npts = 2
m = 2
μ = numpy.matrix([0.0, 0.0]).T
x0 = numpy.matrix([0.0, 0.0]).T
Ω = numpy.matrix(numpy.eye(m))
Φ = [numpy.matrix([[0.2, 0.1],
                   [0.1, 0.3]])]
df = VAR.Source.VAR.create(Φ=Φ, Ω=Ω, μ=μ, x0=x0, npts=npts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hc/xc94zvls2pq_pw366sdbqlhr0000gn/T/ipykernel_1707/3776976814.py in <module>
#       6 Φ = [numpy.matrix([[0.2, 0.1],
#       7                    [0.1, 0.3]])]
# ----> 8 df = VAR.Source.VAR.create(Φ=Φ, Ω=Ω, μ=μ, x0=x0, npts=npts)
#
# ~/Develop/gly.fish/alef/lib/data/source.py in create(self, **kwargs)
#      31             x = create_space(**kwargs)
#      32         source = self._create_data_source(x, **kwargs)
# ---> 33         return source.create()
#      34
#      35     def create_parameter_scan(self, *args):
#
# ~/Develop/gly.fish/alef/lib/data/source.py in create(self)
#      91     def create(self):
#      92         y = self.f(self.x)
# ---> 93         df = self.schema.create_data_frame(self.x, y)
#      94         DataSchema.set_source_type(df, None)
#      95         DataSchema.set_source_name(df, None)
#
# ~/Develop/gly.fish/alef/lib/data/schema.py in create_data_frame(self, x, y)
#      53
#      54     def create_data_frame(self, x, y):
# ---> 55         df = DataFrame({
#      56             self.xcol: x,
#      57             self.ycol: y
#
# ~/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      83
#      84         # don't force copy because getting jammed in an ndarray anyway
# ---> 85         arrays = _homogenize(arrays, index, dtype)
#      86
#      87         columns = ensure_index(columns)
#
# ~/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     353                     val = dict(val)
#     354                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 355             val = sanitize_array(
#     356                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     357             )
#
# ~/.pyenv/versions/gly.fish.3.9.2/lib/python3.9/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     527     elif subarr.ndim > 1:
#     528         if isinstance(data, np.ndarray):
# --> 529             raise ValueError("Data must be 1-dimensional")
#     530         else:
#     531             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# ValueError: Data must be 1-dimensional

# %% [markdown]
# ## $\text{VAR}(1)$ Simulations
