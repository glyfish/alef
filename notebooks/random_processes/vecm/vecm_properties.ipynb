# %% [markdown]
# # Vector Error Correction Model (VECM) Properties
#
# ## Derivation
#
# Recall that the Vector Auto Regressive Process of order $\text{VAR}(n)$
# is defined by,
#
# $
# \begin{align}
# X_t = \mathcal{M} + \Phi_1 X_{t-1} \Phi_2 X_{t-2} + \cdots + \Phi_n X_{t-n} + \mathcal{E}_t
# \end{align}
# \tag{1}
# $
#
# where $t = 1, 2, 3, \ldots, T$, $X_t$ is column vector of length $m$ representing the time series, $\mathcal{M}$ is a $m$ element constant offset column vector, $\Phi_t$ are $m \times m$ matrices denoting constant coefficients and $\mathcal{E}_t$ an a random column normal vector with zero mean and covariance matrix $\Omega$,
#
# $
# \begin{align}
# \mathcal{E}_t \sim \text{Normal}(0, \Omega)
# \end{align}
# \tag{2}
# $
#
# The $\mathcal{E}_t$ are assumed uncorrelated,
#
# $
# \begin{align}
# \text{Cov}(\mathcal{E}_t, \mathcal{E}_t) &= \Omega \\
# \text{Cov}(\mathcal{E}_s, \mathcal{E}_t) &=  0\ \text{if}\ t \ne s
# \end{align}
# \tag{3}
# $
#
# where,
#
# $
# \begin{align}
# \Omega = \text{E}(\mathcal{E}_t \mathcal{E}_t^\prime)
# \end{align}
# \tag{4}
# $
#
# with $\mathcal{E}_t^\prime$ denoting the transpose of $\mathcal{E}_t$.</br>
#
# The derivation is similar to the derivation of the ECM. As an illustration consider $\text{VAR}(2)$ and assume that the components of $X_t$ have integration order 1 and $\mathcal{M}= \mathcal{0}$, it follows that,
#
# $
# \begin{align}
# x_{m,t} \sim \text{I}(1)
# \end{align}
# \tag{5}
# $
#
# where,
#
# $
# \begin{align}
# X_t =
# \begin{bmatrix}
# x_{1,t} \\
# x_{2,t} \\
# \vdots \\
# x_{m,t}
# \end{bmatrix}
# \end{align}
# \tag{6}
# $
#
# so $X_t \sim \text{I}(1)$. $\text{VAR}(2)$ is given by,
#
# $
# \begin{align}
# X_t = \Phi_1 X_{t-1} + \Phi_2 X_{t-2} + \mathcal{E}_t
# \end{align}
# \tag{7}
# $
#
# Subtracting $X_{t-1}$ from both sides gives,
#
# $
# \begin{align}
# X_t - X_{t-1} = \left( \Phi_1 - \mathbb{1} \right)  X_{t-1} + \Phi_2 X_{t-2} + \mathcal{E}_t
# \end{align}
# \tag{8}
# $
#
# where $\mathbb{1}$ is the identity matrix. Let,
#
# $
# \begin{align}
# \Delta X_t = X_t - X_{t-1}
# \end{align}
# \tag{9}
# $
#
# Adding and subtracting $\Phi_2 X_{t-1}$ gives,
#
# $
# \begin{align}
# \Delta X_t = \left(\Phi_1 + \Phi_2 - \mathbb{1} \right) X_{t-1} - \Phi_2 \Delta X_{t-1} + \mathcal{E}_t
# \end{align}
# \tag{9}
# $
#
# Let,
#
# $
# \begin{align}
# A_1 &= \Phi_1 + \Phi_2 - \mathbb{1} \\
# A_2 &= -\Phi_2
# \end{align}
# \tag{10}
# $
#
# then,
#
# $
# \begin{align}
# \Delta X_t = A_1  X_{t-1} + A_2 X_{t-1} + \mathcal{E}_t
# \end{align}
# \tag{11}
# $
#
# Following this procedure $n$ times gives the error correction model,
#
# $
# \begin{align}
# \Delta X_t &= A_1  X_{t-1} + A_2 X_{t-1}+ \cdots + A_n \Delta X_{t - n + 1}  + \mathcal{E}_t \\
#            &= A_1 X_{t-1} + \sum_{i=2}^n A_n \Delta X_{t - n + 1}  + \mathcal{E}_t
# \end{align}
# \tag{12}
# $
#
# where,
#
# $
# \begin{align}
# A_1 &= \sum_{i=1}^n \Phi_i - \mathbb{1} \\
# A_j &= -\sum_{i=j}^n \Phi_i
# \end{align}
# \tag{13}
# $
#
# This form is similar to the ECM if $A_1  X_{t-1}$ is the error correction term.
#
# ## Cointegration
#
# Since the elements of $X_{t}\sim\text{I}(1)$ it follows that the elements of $\Delta X_{t-1}\sim\text{I}(0)$. Recall that the rank of a square matrix is defined as the number of linearly independent columns. For a $k \times k$ matrix with rank $k$ all columns are linearly independent. If the rank $m$ satisfies $m\lt k$ only $m$ columns are linearly independent. So, $k-m$ columns are linear combinations of the $m$ linearly independent vectors. Since a $k\times k$ matrix is invertable only if all its columns are linearly independent so that its rank is $k$. It follows that if the rank is less than $k$ the matrix is not invertable.
#
# Cointegration implies that all the terms in equation $(12)$ are $I(0)$. Assume that $A_1$ is invertable then from the VECM defined by equation $(12)$ it follows that,
#
# $
# \begin{align}
# A_1^{-1} \Delta X_t = X_{t-1} + A_1^{-1} \left[ \sum_{i=2}^n A_n \Delta X_{t - n + 1}  + \mathcal{E}_t \right]
# \end{align}
# \tag{14}
# $
#
# Since all terms in this equation are $I(0)$ while $X_{t-1} \sim I(1)$ and since a finite sum of scalar multiples of $I(0)$ terms is also $I(0)$ this equation invalid. It follows that $A_1$ cannot be invertable thus,
#
# $
# \begin{align}
# rank(A_1) = m < k
# \end{align}
# \tag{15}
# $
#
# with $A_1 X_{t-1} \sim I(0)$ for cointegration to exist.
#
# Now for any $k\times k$ matrix, $A_1$ with $rank(A_1) = m < k$ a factorization exists where
#
# $
# \begin{align}
# A_1 = \lambda \beta^\prime
# \end{align}
# \tag{16}
# $
#
# Here $\lambda$ is an $k\times m$ and $\beta^\prime$, the transpose of $\beta$, is a $n\times k$ matrix. It follows that the VECM is given by,
#
# $
# \begin{align}
# \Delta X_t = \lambda \beta^\prime X_{t-1} + \sum_{i=2}^n A_n \Delta X_{t - n + 1}  + \mathcal{E}_t
# \end{align}
# \tag{17}
# $
#
# where the cointegration relation is defined by,
#
# $
# \begin{align}
# \beta^\prime X_t = \varepsilon_t \sim I(0)
# \end{align}
# \tag{18}
# $
#
# where $\beta$ is the cointegrating vector, analogous to the $\beta$ term in the ECM, $\varepsilon_t$ is the vector form of the ECM residual and the $\lambda$ vector is analogous $\lambda$ ECM damping factor.
#
# The cointegration of the components of a vector of $X_t$ can be stated as,
#
# > A time series vector $X_t$ is cointegrated if a linear combination of the components exist that are $I(0)$.
#
# Since $X_t \sim I(1)$ its variance will grow linearly with time but $\varepsilon_t \sim I(0)$ is stationary and has a constant variance. It follows that for large times the $I(1)$ terms dominate so,
#
# $
# \begin{align}
# \beta^\prime X_t \approx 0
# \end{align}
# \tag{19}
# $
#
# ## Examples of Cointegrating Vectors
#
# ### One Cointegrating Vector
#
# Consider the vector,
#
# $
# \begin{align}
# X_t = \left[x_{1,t},\ x_{2,t},\ \ldots,\ x_{k,t}\right]^\prime
# \end{align}
# \tag{20}
# $
#
# and the cointegrating vector is given by,
#
# $
# \begin{align}
# \beta = \left[\beta_1,\ \beta_2,\ \ldots,\ \beta_k\right]^\prime
# \end{align}
# \tag{21}
# $
#
# The cointegration relationship is given by,
#
# $
# \begin{align}
# \beta^\prime X_t = \sum_{i=1}^k \beta_i x_{i,t} \sim I(0)
# \end{align}
# \tag{22}
# $
#
# The cointegration vector is not unique since for any scalar constant $c$,
#
# $
# \begin{align}
# c \beta^\prime X_t = \sim I(0)
# \end{align}
# \tag{23}
# $
#
# To uniquely identify a cointegrating vector a normalization is required. A common normalization is to divide by $\beta_1$,
#
# $
# \begin{align}
# \beta = \left[1,\ -\beta_2,\ -\beta_3,\ \ldots,\ -\beta_k\right]^\prime
# \end{align}
# \tag{24}
# $
#
# so that,
#
# $
# \begin{align}
# \beta^\prime X_t = x_{1,t} - \beta_2 x_{2,t} - \beta_3 x_{3,t} - \cdots - \beta_k x_{k,t} \sim I(0)
# \end{align}
# \tag{25}
# $
#
# Time asymptotically this becomes,
#
# $
# \begin{align}
# &\beta^\prime X_t = x_{1,t} - \beta_2 x_{2,t} - \beta_3 x_{3,t} - \cdots - \beta_k x_{k,t} = 0 \\
# \implies & x^1_t = \beta_2 x^2_t + \beta_3 x^3_t + \cdots + \beta_k x^k_t
# \end{align}
# \tag{26}
# $
#
# From this equation the components of $\beta$ can be found using OLS. If the estimate obtained using OLS is denoted by $\hat{\beta}$ the residual,
#
# $
# \begin{align}
# \varepsilon = \hat{\beta}^\prime X_t
# \end{align}
# \tag{27}
# $
#
# can be tested for stationarity using the ADF test to verify cointegration.
#
# ### Multiple Cointegrating Vectors
#
# If $X_t$ has $k$ components there can be at most $k-1$ cointegrating vectors. If $k=3$ then there are two cointegrating vectors,
#
# $
# \begin{align}
# \beta_1 &= \left[\beta_{11},\ \beta_{12},\ \beta_{13}\right]^\prime \\
# \beta_2 &= \left[\beta_{21},\ \beta_{22},\ \beta_{23}\right]^\prime
# \end{align}
# \tag{28}
# $
#
# Let,
#
# $
# \begin{align}
# \mathcal{B} =
# \begin{bmatrix}
# \beta_{11}\ & \beta_{12}\ & \beta_{13} \\
# \beta_{21}\ & \beta_{22}\ & \beta_{23}
# \end{bmatrix}
# \end{align}
# \tag{29}
# $
#
# Time asymptotically the cointegrating relationship becomes,
#
# $
# \begin{align}
# \mathcal{B}^\prime X_t = 0
# \end{align}
# \tag{30}
# $
#
# This leads to the system of equations for the cointegrating vectors,
#
# $
# \begin{align}
# \beta_{11} x_{1,t} + \beta_{12} x_{2,t} + \beta_{13} x_{3,t} &= 0 \\
# \beta_{21} x_{1,t} + \beta_{22} x_{2,t} + \beta_{23} x_{3,t} &= 0
# \end{align}
# \tag{31}
# $
#
# The solution to this system of equations requires more sophisticated methods.
#
# ## Common Trends
#
# If the time series vector $X_t$ has $k$ elements that are cointegrated with rank $r < k$ then then there are $k-r$ common $I(1)$
# stochastic trends. For example for $k=2$,
#
# $
# \begin{align}
# X_t &= \left[x_{1,t},\ x_{2,t}\right] \sim I(1) \\
# \varepsilon_t &= \left[\varepsilon_{1,t},\ \varepsilon_{2,t},\ \varepsilon_{3,t}\right] \sim I(0)
# \end{align}
# \tag{32}
# $
#
# and a single cointegrating vector,
#
# $
# \begin{align}
# X_t &= \left[x_{1,t},\ x_{2,t}\right] \sim I(1) \\
# \varepsilon_t &= \left[\varepsilon_{1,t},\ \varepsilon_{2,t},\ \varepsilon_{3,t}\right] \sim I(0)
# \end{align}
# \tag{33}
# $
#
# It follows that there is 1 common stochastic trend. Consider,
#
# $
# \begin{align}
# x_{1,t} &= \beta_2 \sum_{i=1}^t \varepsilon_{1, i} + \varepsilon_{3,t} \\
# x_{2,t} &= \sum_{i=1}^t \varepsilon_{1, i} + \varepsilon_{2,t}
# \end{align}
# \tag{34}
# $
#
# here the common stochastic trend is,
#
# $
# \begin{align}
# \sum_{i=1}^t \varepsilon_{1, i}
# \end{align}
# \tag{35}
# $
#
# and the cointegration relationship is given by,
#
# $
# \begin{align}
# \beta^\prime X_t &= x_{1,t} - \beta_2 x_{2,t} \\
# &= \beta_2 \sum_{i=1}^t \varepsilon_{1, i} + \varepsilon_{3,t} - \beta_2 \sum_{i=1}^t \varepsilon_{1, i} - \beta_2 \varepsilon_{2,t} \\
# &= \varepsilon_{3,t} - \beta_2 \varepsilon_{2,t} \sim I(0)
# \end{align}
# \tag{36}
# $
#
# It is seen that the cointegration relationship removed the common trend.
#
# ## Philips Triangular Representation
#
# ### Bivariate System
#
# Cointegrated systems can be modeled using the Philips triangular representation. Consider the bivariate system,
#
# $
# \begin{align}
# X_t &= \left[x_{1,t},\ x_{2,t}\right]^\prime \\
# \beta &= \left[1,\ -\beta_2\right]^\prime
# \end{align}
# \tag{37}
# $
#
# Assuming cointegration gives, $\beta^\prime X_t \sim I(0)$ It follows that,
#
# $
# \begin{align}
# &x_{1,t} - \beta_2 x_{2,t} = u_t \\
# \implies & x_{1,t} = \beta_2 x_{2,t} + u_t
# \end{align}
# \tag{38}
# $
#
# where $u_t \sim I(0)$ so it can be modeled as a stationary $\text{AR}(1)$ process, namely,
#
# $
# \begin{align}
# u_t = \varphi u_{t-1} + \varepsilon_t
# \end{align}
# \tag{39}
# $
#
# with $|\varphi| < 1$ and $\varepsilon_t \sim \text{Normal}(0, \sigma^2)$ and serially uncorrelated with distribution,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}\left(0, \sigma^2 \right)
# \end{align}
# \tag{40}
# $
#
# Now $x_{2,t} \sim I(1)$, so let,
#
# $
# \begin{align}
# x_{2,t} &= \sum_{i=1}^t \upsilon_t = x_{2, t-1} + \upsilon_t
# \end{align}
# \tag{41}
# $
#
# where $\upsilon_t$ are serially independent identically distributed random variables with distribution,
#
# $
# \begin{align}
# \upsilon_t \sim \text{Normal}\left(0, \sigma^2 \right)
# \end{align}
# \tag{42}
# $
#
# thus $x_{2,t}$ is modeled as Brownian Motion. It follows that,
#
# $
# \begin{align}
# x_{1,t} &= \beta_2 x_{2,t} + u_t \\
# x_{2,t} &= \sum_{i=1}^t \upsilon_t = x_{2, t-1} + \upsilon_t
# \end{align}
# \tag{43}
# $
#
# Note that $x_{2,t}$ is a common stochastic trend. The Phillips triangular representation of a bivariate cointegrated is given by,
#
# $
# \begin{align}
# x_{1,t} &= \beta_2 x_{2,t} + u_t \\
# x_{2,t} &= x_{2, t-1} + \upsilon_t \\
# u_t &= \varphi u_{t-1} + \varepsilon_t
# \end{align}
# \tag{44}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t &\sim \text{Normal}\left(0, \sigma_1^2 \right) \\
# \upsilon_t &\sim \text{Normal}\left(0, \sigma_2^2 \right)
# \end{align}
# \tag{45}
# $
#
# which are serially uncorrelated.
#
# ### Trivariate System with One Cointegrating Vector
#
# Next consider a cointegrated trivariate system with one cointegrating vector, namely,
#
# $
# \begin{align}
# X_t &= \left[x_{1,t},\ x_{2,t},\ x_{3,t}\right]^\prime \\
# \beta &= \left[1,\ -\beta_1,\ -\beta_2\right]^\prime
# \end{align}
# \tag{46}
# $
#
# So that,
#
# $
# \begin{align}
# \beta^\prime X_t \sim I(0)
# \end{align}
# \tag{47}
# $
#
# It follows that
#
# $
# \begin{align}
# &x_{1,t} - \beta_1 x_{2,t} - \beta_2 x_{3,t} = u_t \\
# \implies & x_{1,t} = \beta_1 x_{2,t} + \beta_2 x_{3,t} + u_t
# \end{align}
# \tag{48}
# $
#
# where $u_t \sim I(0)$ so that,
#
# $
# \begin{align}
# u_t = \varphi u_{t-1} + \varepsilon_t
# \end{align}
# \tag{49}
# $
#
# with $|\varphi| < 1$ and $\varepsilon_t \sim \text{Normal}(0, \sigma^2)$ and serially uncorrelated with distribution,
#
# $
# \begin{align}
# \varepsilon_t \sim \text{Normal}\left(0, \sigma^2 \right)
# \end{align}
# \tag{50}
# $
#
# Since $x_{2,t}$ and $x_{3,t}$ are $I(1)$ let,
#
# $
# \begin{align}
# x_{2,t} &= \sum_{i=1}^t \upsilon_t = x_{2, t-1} + \upsilon_t \\
# x_{3,t} &= \sum_{i=1}^t \omega_t = x_{2, t-1} + \omega_t
# \end{align}
# \tag{51}
# $
#
# where both $\upsilon_t$ and $\omega_t$ serially uncorrelated and independent with distribution,
#
# $
# \begin{align}
# \upsilon_t &\sim \text{Normal}\left(0, \sigma_2^2 \right) \\
# \omega_t &\sim \text{Normal}\left(0, \sigma_3^2 \right) \\
# \end{align}
# \tag{52}
# $
#
# thus $x_{2,t}$ and $x_{3,t}$ are modeled as independent Brownian motion curves. It follows that the Phillips triangular representation of
# of a trivariate cointegrated system with a single cointegrating vector is given by,
#
# $
# \begin{align}
# x_{1,t} &= \beta_1 x_{2,t} + \beta_2 x_{3,t} + u_t \\
# x_{2,t} &= x_{2, t-1} + \upsilon_t \\
# x_{3,t} &= x_{3, t-1} + \omega_t \\
# u_t &= \varphi u_{t-1} + \varepsilon_t
# \end{align}
# \tag{53}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t &\sim \text{Normal}\left(0, \sigma_1^2 \right) \\
# \upsilon_t &\sim \text{Normal}\left(0, \sigma_2^2 \right) \\
# \omega_t &\sim \text{Normal}\left(0, \sigma_3^2 \right)
# \end{align}
# \tag{54}
# $
#
# Note that for this case both $x_{2,t}$ and $x_{3,t}$ are common stochastic trends.
#
# ### Trivariate System with Two Cointegrating Vectors
#
# Next consider a cointegrated trivariate system with two cointegrating vectors, namely,
#
# $
# \begin{align}
# X_t &= \left[x_{1,t},\ x_{2,t},\ x_{3,t}\right]^\prime \\
# \beta_1 &= \left[1,\ 0,\ -\beta_{13}\right]^\prime \\
# \beta_2 &= \left[0,\ 1,\ -\beta_{23}\right]^\prime \\
# \beta &= \left[\beta_1, \beta_2\right]^\prime
# \end{align}
# \tag{55}
# $
#
# Since $\beta^\prime X_t \sim I(0)$ it follows that,
#
# $
# \begin{align}
# \begin{bmatrix}
# 1 & 0 & -\beta_{13}\\
# 0 & 1 & -\beta_23
# \end{bmatrix}
# \begin{bmatrix}
# x_{1,t} \\
# x_{2,t} \\
# x_{3,t}
# \end{bmatrix}
# \sim I(0)
# \end{align}
# \tag{56}
# $
#
# This results in the system of equations,
#
# $
# \begin{align}
# x_{1,t} - \beta_{13} x_{3,t} &= u_t \\
# x_{1,t} - \beta_{13} x_{3,t} &= \upsilon_t
# \end{align}
# \tag{57}
# $
#
# where $u_t \sim I(0)$ and $\upsilon_t \sim I(0)$. It follows that,
#
# $
# \begin{align}
# u_t &= \varphi u_{t-1} + \varepsilon_t \\
# v_t &= \vartheta v_{t-1} + \eta_t
# \end{align}
# \tag{58}
# $
#
# with $|\varphi| < 1$ and $|\vartheta| < 1$ where $\varepsilon_t \sim \text{Normal}(0, \sigma_1^2)$ and $\eta_t \sim \text{Normal}(0, \sigma_2^2)$. Since $x_{3,t} \sim I(1)$ assume that it can be modeled by Brownian Motion,
#
# $
# \begin{align}
# x_{3,t} &= \sum_{i=1}^t \omega_i \\
#  &= x_{3,t-1} + \omega_t
# \end{align}
# \tag{59}
# $
#
# where $\omega_t \sim \text{Normal}(0, \sigma_3^2)$. Finally the Phillips triangular representation for a trivariate cointegrated system with two cointegrating vectors is given by,
#
# $
# \begin{align}
# x_{1,t} &= \beta_{13} x_{3,t} + u_t \\
# x_{2,t} &= \beta_{23} x_{3,t} + v_t \\
# x_{3,t} &= x_{3,t} + \omega_t \\
# u_t &= \varphi u_{t-1} + \varepsilon_t \\
# v_t &= \varphi v_{t-1} + \eta_t \\
# \end{align}
# \tag{60}
# $
#
# where,
#
# $
# \begin{align}
# \varepsilon_t &\sim \text{Normal}\left(0, \sigma_1^2 \right) \\
# \upsilon_t &\sim \text{Normal}\left(0, \sigma_2^2 \right) \\
# \omega_t &\sim \text{Normal}\left(0, \sigma_3^2 \right)
# \end{align}
# \tag{54}
# $
#
# For this system $x_{3,t}$ is the common trend.
